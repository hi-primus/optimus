# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %%
from optimus import Optimus

# %% [markdown]
# ### Load optimus local or in a cluster

# %%
# Create optimus
op = Optimus(master="local", app_name= "optimus", verbose = True)
# Out:
# Just check that Spark and all necessary environments vars are present...
# -----
# SPARK_HOME=C:\opt\spark\spark-2.3.1-bin-hadoop2.7
# HADOOP_HOME=C:\opt\spark\spark-2.3.1-bin-hadoop2.7
# You don't have PYSPARK_PYTHON set
# You don't have PYSPARK_DRIVER_PYTHON set
# JAVA_HOME=C:\Program Files\Java\jdk1.8.0_181
# Pyarrow Installed
# -----
# Starting or getting SparkSession and SparkContext...
#
#                              ____        __  _
#                             / __ \____  / /_(_)___ ___  __  _______
#                            / / / / __ \/ __/ / __ `__ \/ / / / ___/
#                           / /_/ / /_/ / /_/ / / / / / / /_/ (__  )
#                           \____/ .___/\__/_/_/ /_/ /_/\__,_/____/
#                               /_/
#
# Transform and Roll out...
# Optimus successfully imported. Have fun :).

# %% [markdown]
# ### Get the spark session

# %%
op.spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-H46MBKF:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>optimus</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Get the spark context

# %%
op.sc
# Out:
# <SparkContext master=local appName=optimus>

# %%
from pyspark.sql.types import StructType, StructField, StringType, BooleanType, IntegerType, ArrayType

df = op.create.df(
    [
                ("words", "str", True),
                ("num", "int", True),
                ("animals", "str", True),
                ("thing", StringType(), True),
                ("two strings", StringType(), True),
                ("filter", StringType(), True),
                ("num 2", "string", True),
                ("date", "string", True),
                ("num 3", "string", True)
                
            ],[
                ("  I like     fish  ", 1, "dog", "&^%$#housé", "cat-car", "a","1", "20150510", "3"),
                ("    zombies", 2, "cat", "tv", "dog-tv", "b","2", "20160510", "3"),
                ("simpsons   cat lady", 2, "frog", "table","eagle-tv-plus","1","3", "20170510", "4"),
                (None, 3, "eagle", "glass", "lion-pc", "c","4", "20180510", "5"),
    
            ]
            )

df.table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 4 of 4</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">words</div>
#             <div class="data_type">1 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">num</div>
#             <div class="data_type">2 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">animals</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">thing</div>
#             <div class="data_type">4 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">two strings</div>
# ...

# %% [markdown]
# ## concat dataframes
#
# Concat dataframes two or multiple dataframes in a row or column way
#
# ### Spark
# No available in Spark Vanilla
#
# ### Pandas
# Almost the same functionlity

# %%
op.concat([df,df], like="rows").table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#
# </style>
# <div>Viewing 8 of 8</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">words</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">num</div>
#             <div class="data_type">(int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">animals</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">thing</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">two strings</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">filter</div>
# ...

# %% [markdown]
# ### Melt
# Like the pandas Melt

# %%
import pandas as pd

pdf = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})

sdf = op.spark.createDataFrame(pdf)
sdf.table()

df.melt(sdf, id_vars=['A'], value_vars=['B', 'C']).table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#
# </style>
# <div>Viewing 3 of 3</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">A</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">B</div>
#             <div class="data_type">(bigint)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">C</div>
#             <div class="data_type">(bigint)</div>
#
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             a
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             2
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             b
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             4
# ...

# %% [markdown]
# ## IO Operations

# %% [markdown]
# ### Load from file

# %%
df_csv =op.load.csv("data/foo.csv").table(5)
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 5 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
# ...

# %%
df_json =op.load.json("data/foo.json").table(5)
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 5 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">1 (bigint)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">4 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">id</div>
# ...

# %%
df_parquet =op.load.parquet("data/foo.parquet").table(5)
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 5 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
# ...

# %%
df_avro =op.load.avro("data/foo.avro").table(5)
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 5 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
# ...

# %% [markdown]
# ### Load from URL

# %%
df_csv =op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/foo.csv")
df_csv.table()
# Out:
# ...
# Downloaded 967 bytes
# Creating DataFrame for foo.csv. Please wait...
# Successfully created DataFrame for 'foo.csv'
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 19 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#
# ...

# %%
df_json =op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/feature/load_save_improvements/examples/data/foo.json", "json")
df_json.table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 19 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">1 (bigint)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">4 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">id</div>
# ...

# %%
df_parquet =op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/feature/load_save_improvements/examples/data/foo.parquet", "parquet")
df_parquet.table()
# Out:
# ...
# Downloaded 2839 bytes
# Creating DataFrame for foo.parquet. Please wait...
# Successfully created DataFrame for 'foo.parquet'
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 19 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#
# ...

# %%
df_avro =op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/feature/load_save_improvements/examples/data/foo.avro", "avro")
df_avro.table()
# Out:
# ...
# Downloaded 1317 bytes
# Creating DataFrame for foo.avro. Please wait...
# Successfully created DataFrame for 'foo.avro'
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 19 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#
# ...

# %%
df_geojson =op.load.url("https://api.github.com/users/mralexgray/repos", "geojson")
df_geojson.table()

# %% [markdown]
# ### Save to file

# %%
df_csv.save.csv("test.csv")

# %%
df_csv.save.json("test.json")

# %%
df_csv.save.parquet("test.parquet")

# %%
df_csv.save.avro("test.avro")
