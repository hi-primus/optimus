# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("..")

# %%
from optimus import Optimus

# %% [markdown]
# ### Load optimus local or in a cluster

# %%
# Create optimus
op = Optimus(master="local", app_name= "optimus", verbose = True , dl =True)
# Out:
# Just check that Spark and all necessary environments vars are present...
# -----
# SPARK_HOME=C:\opt\spark\spark-2.3.1-bin-hadoop2.7
# HADOOP_HOME=C:\opt\spark\spark-2.3.1-bin-hadoop2.7
# You don't have PYSPARK_PYTHON set
# You don't have PYSPARK_DRIVER_PYTHON set
# JAVA_HOME=C:\Program Files\Java\jdk1.8.0_181
# --packages databricks:spark-deep-learning:1.1.0-spark2.3-s_2.11 pyspark-shell
# Pyarrow Installed
# -----
# Starting or getting SparkSession and SparkContext...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-641b9ffde2b8> in <module>()
#       1 # Create optimus
# ----> 2 op = Optimus(master="local", app_name= "optimus", verbose = True , dl =True)
#
# ~\Documents\Optimus\optimus\optimus.py in __init__(self, master, app_name, checkpoint, path, file_system, verbose, dl)
#      39
#      40             Spark.instance = Spark(master, app_name)
# ---> 41             from optimus.dl.models import DL
#      42             self.dl = DL()
#      43         else:
#
# ~\Documents\Optimus\optimus\dl\models.py in <module>()
#       2 from pyspark.ml import Pipeline
#       3 from pyspark.ml.image import ImageSchema
# ----> 4 from sparkdl import DeepImageFeaturizer
#       5 from pyspark.ml.evaluation import MulticlassClassificationEvaluator
#       6 from sparkdl import DeepImagePredictor
#
# ~\AppData\Local\Temp\spark-82c5d549-eab4-45b9-87d5-d0e97ae1a492\userFiles-fbb7d255-86b5-48fb-8a38-c24129aa35ab\databricks_spark-deep-learning-1.1.0-spark2.3-s_2.11.jar\sparkdl\__init__.py in <module>()
#      13 # limitations under the License.
#      14 #
# ---> 15 from .graph.input import TFInputGraph
#      16 from .transformers.keras_image import KerasImageFileTransformer
#      17 from .transformers.named_image import DeepImagePredictor, DeepImageFeaturizer
#
# ~\AppData\Local\Temp\spark-82c5d549-eab4-45b9-87d5-d0e97ae1a492\userFiles-fbb7d255-86b5-48fb-8a38-c24129aa35ab\databricks_spark-deep-learning-1.1.0-spark2.3-s_2.11.jar\sparkdl\graph\input.py in <module>()
#      15 from __future__ import absolute_import, division, print_function
#      16
# ---> 17 import tensorflow as tf
#      18 from tensorflow.core.protobuf import meta_graph_pb2  # pylint: disable=no-name-in-module
#      19
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\__init__.py in <module>()
#      20
#      21 # pylint: disable=g-bad-import-order
# ---> 22 from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#      23 from . import app
#      24 from . import bitwise
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\__init__.py in <module>()
#      79 # Bring in subpackages.
#      80 from tensorflow.python import data
# ---> 81 from tensorflow.python import keras
#      82 from tensorflow.python.estimator import estimator_lib as estimator
#      83 from tensorflow.python.feature_column import feature_column_lib as feature_column
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\__init__.py in <module>()
#      22 from __future__ import print_function
#      23
# ---> 24 from tensorflow.python.keras import activations
#      25 from tensorflow.python.keras import applications
#      26 from tensorflow.python.keras import backend
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\activations\__init__.py in <module>()
#      20
#      21 # Activation functions.
# ---> 22 from tensorflow.python.keras._impl.keras.activations import elu
#      23 from tensorflow.python.keras._impl.keras.activations import hard_sigmoid
#      24 from tensorflow.python.keras._impl.keras.activations import linear
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\__init__.py in <module>()
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.python.keras._impl.keras import activations
#      22 from tensorflow.python.keras._impl.keras import applications
#      23 from tensorflow.python.keras._impl.keras import backend
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\activations.py in <module>()
#      21 import six
#      22
# ---> 23 from tensorflow.python.keras._impl.keras import backend as K
#      24 from tensorflow.python.keras._impl.keras.utils.generic_utils import deserialize_keras_object
#      25 from tensorflow.python.layers.base import Layer
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\_impl\keras\backend.py in <module>()
#      35 from tensorflow.python.framework import ops
#      36 from tensorflow.python.framework import sparse_tensor
# ---> 37 from tensorflow.python.layers import base as tf_base_layers
#      38 from tensorflow.python.ops import array_ops
#      39 from tensorflow.python.ops import clip_ops
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\layers\base.py in <module>()
#      23 from tensorflow.python.framework import dtypes
#      24 from tensorflow.python.framework import ops
# ---> 25 from tensorflow.python.keras.engine import base_layer
#      26 from tensorflow.python.ops import variable_scope as vs
#      27 from tensorflow.python.ops import variables as tf_variables
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\__init__.py in <module>()
#      19 from __future__ import print_function
#      20
# ---> 21 from tensorflow.python.keras.engine.base_layer import InputSpec
#      22 from tensorflow.python.keras.engine.base_layer import Layer
#      23 from tensorflow.python.keras.engine.input_layer import Input
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in <module>()
#      31 from tensorflow.python.framework import tensor_shape
#      32 from tensorflow.python.framework import tensor_util
# ---> 33 from tensorflow.python.keras import backend
#      34 from tensorflow.python.keras import constraints
#      35 from tensorflow.python.keras import initializers
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\keras\backend\__init__.py in <module>()
#      20
#      21 # pylint: disable=redefined-builtin
# ---> 22 from tensorflow.python.keras._impl.keras.backend import abs
#      23 from tensorflow.python.keras._impl.keras.backend import all
#      24 from tensorflow.python.keras._impl.keras.backend import any
#
# ImportError: cannot import name 'abs'

# %% [markdown]
# ### Get the spark session

# %%
op.spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-H46MBKF:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.3.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>optimus</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Get the spark context

# %%
op.sc
# Out:
# <SparkContext master=local appName=optimus>

# %%
from pyspark.sql.types import StructType, StructField, StringType, BooleanType, IntegerType, ArrayType

df = op.create.df(
    [
                ("words", "str", True),
                ("num", "int", True),
                ("animals", "str", True),
                ("thing", StringType(), True),
                ("two strings", StringType(), True),
                ("filter", StringType(), True),
                ("num 2", "string", True),
                ("date", "string", True),
                ("num 3", "string", True)
                
            ],[
                ("  I like     fish  ", 1, "dog", "&^%$#housé", "cat-car", "a","1", "20150510", "3"),
                ("    zombies", 2, "cat", "tv", "dog-tv", "b","2", "20160510", "3"),
                ("simpsons   cat lady", 2, "frog", "table","eagle-tv-plus","1","3", "20170510", "4"),
                (None, 3, "eagle", "glass", "lion-pc", "c","4", "20180510", "5"),
    
            ]
            )

df.table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 4 of 4</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">words</div>
#             <div class="data_type">1 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">num</div>
#             <div class="data_type">2 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">animals</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">thing</div>
#             <div class="data_type">4 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">two strings</div>
#             <div class="data_type">5 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">filter</div>
#             <div class="data_type">6 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">num 2</div>
#             <div class="data_type">7 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">date</div>
#             <div class="data_type">8 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">num 3</div>
#             <div class="data_type">9 (string)</div>
#
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             ⸱⸱I⸱like⸱⸱⸱⸱⸱fish⸱⸱
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             dog
#         </td>
#
#         <td>
#             &amp;^%$#housé
#         </td>
#
#         <td>
#             cat-car
#         </td>
#
#         <td>
#             a
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             20150510
#         </td>
#
#         <td>
#             3
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             ⸱⸱⸱⸱zombies
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             cat
#         </td>
#
#         <td>
#             tv
#         </td>
#
#         <td>
#             dog-tv
#         </td>
#
#         <td>
#             b
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             20160510
#         </td>
#
#         <td>
#             3
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             simpsons⸱⸱⸱cat⸱lady
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             frog
#         </td>
#
#         <td>
#             table
#         </td>
#
#         <td>
#             eagle-tv-plus
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             20170510
#         </td>
#
#         <td>
#             4
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             None
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             eagle
#         </td>
#
#         <td>
#             glass
#         </td>
#
#         <td>
#             lion-pc
#         </td>
#
#         <td>
#             c
#         </td>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             20180510
#         </td>
#
#         <td>
#             5
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
# <div class="info_items">Viewing 4 of 4</div>

# %% [markdown]
# ## concat dataframes
#
# Concat dataframes two or multiple dataframes in a row or column way
#
# ### Spark
# No available in Spark Vanilla
#
# ### Pandas
# Almost the same functionlity

# %%
op.concat([df,df], like="rows").table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#
# </style>
# <div>Viewing 8 of 8</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">words</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">num</div>
#             <div class="data_type">(int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">animals</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">thing</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">two strings</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">filter</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">num 2</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">date</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">num 3</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             ⸱⸱I⸱like⸱⸱⸱⸱⸱fish⸱⸱
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             dog
#         </td>
#
#         <td>
#             &amp;^%$#housé
#         </td>
#
#         <td>
#             cat-car
#         </td>
#
#         <td>
#             a
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             20150510
#         </td>
#
#         <td>
#             3
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             ⸱⸱⸱⸱zombies
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             cat
#         </td>
#
#         <td>
#             tv
#         </td>
#
#         <td>
#             dog-tv
#         </td>
#
#         <td>
#             b
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             20160510
#         </td>
#
#         <td>
#             3
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             simpsons⸱⸱⸱cat⸱lady
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             frog
#         </td>
#
#         <td>
#             table
#         </td>
#
#         <td>
#             eagle-tv-plus
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             20170510
#         </td>
#
#         <td>
#             4
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             None
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             eagle
#         </td>
#
#         <td>
#             glass
#         </td>
#
#         <td>
#             lion-pc
#         </td>
#
#         <td>
#             c
#         </td>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             20180510
#         </td>
#
#         <td>
#             5
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             ⸱⸱I⸱like⸱⸱⸱⸱⸱fish⸱⸱
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             dog
#         </td>
#
#         <td>
#             &amp;^%$#housé
#         </td>
#
#         <td>
#             cat-car
#         </td>
#
#         <td>
#             a
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             20150510
#         </td>
#
#         <td>
#             3
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             ⸱⸱⸱⸱zombies
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             cat
#         </td>
#
#         <td>
#             tv
#         </td>
#
#         <td>
#             dog-tv
#         </td>
#
#         <td>
#             b
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             20160510
#         </td>
#
#         <td>
#             3
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             simpsons⸱⸱⸱cat⸱lady
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             frog
#         </td>
#
#         <td>
#             table
#         </td>
#
#         <td>
#             eagle-tv-plus
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             20170510
#         </td>
#
#         <td>
#             4
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             None
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             eagle
#         </td>
#
#         <td>
#             glass
#         </td>
#
#         <td>
#             lion-pc
#         </td>
#
#         <td>
#             c
#         </td>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             20180510
#         </td>
#
#         <td>
#             5
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
# <div>Viewing 8 of 8</div>

# %% [markdown]
# ### Melt
# Like the pandas Melt

# %%
import pandas as pd

pdf = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})

sdf = op.spark.createDataFrame(pdf)
sdf.table()

df.melt(sdf, id_vars=['A'], value_vars=['B', 'C']).table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#
# </style>
# <div>Viewing 3 of 3</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">A</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">B</div>
#             <div class="data_type">(bigint)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">C</div>
#             <div class="data_type">(bigint)</div>
#
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             a
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             2
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             b
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             4
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             c
#         </td>
#
#         <td>
#             5
#         </td>
#
#         <td>
#             6
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
# <div>Viewing 3 of 3</div>
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#
# </style>
# <div>Viewing 6 of 6</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">A</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">variable</div>
#             <div class="data_type">(string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">value</div>
#             <div class="data_type">(bigint)</div>
#
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             a
#         </td>
#
#         <td>
#             B
#         </td>
#
#         <td>
#             1
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             a
#         </td>
#
#         <td>
#             C
#         </td>
#
#         <td>
#             2
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             b
#         </td>
#
#         <td>
#             B
#         </td>
#
#         <td>
#             3
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             b
#         </td>
#
#         <td>
#             C
#         </td>
#
#         <td>
#             4
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             c
#         </td>
#
#         <td>
#             B
#         </td>
#
#         <td>
#             5
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             c
#         </td>
#
#         <td>
#             C
#         </td>
#
#         <td>
#             6
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
# <div>Viewing 6 of 6</div>

# %% [markdown]
# ## IO Operations

# %% [markdown]
# ### Load

# %%
df_csv =op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/foo.csv")
df_csv.table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 19 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
#             <div class="data_type">5 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">price</div>
#             <div class="data_type">6 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">7 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">8 (string)</div>
#
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             Luis
#         </td>
#
#         <td>
#             Alvarez$$%!
#         </td>
#
#         <td>
#             123
#         </td>
#
#         <td>
#             Cake
#         </td>
#
#         <td>
#             10
#         </td>
#
#         <td>
#             1980/07/07
#         </td>
#
#         <td>
#             never
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             André
#         </td>
#
#         <td>
#             Ampère
#         </td>
#
#         <td>
#             423
#         </td>
#
#         <td>
#             piza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1950/07/08
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             NiELS
#         </td>
#
#         <td>
#             Böhr//((%%
#         </td>
#
#         <td>
#             551
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1990/07/09
#         </td>
#
#         <td>
#             give
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             PAUL
#         </td>
#
#         <td>
#             dirac$
#         </td>
#
#         <td>
#             521
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1954/07/10
#         </td>
#
#         <td>
#             you
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             5
#         </td>
#
#         <td>
#             Albert
#         </td>
#
#         <td>
#             Einstein
#         </td>
#
#         <td>
#             634
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1990/07/11
#         </td>
#
#         <td>
#             up
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             6
#         </td>
#
#         <td>
#             Galileo
#         </td>
#
#         <td>
#             ⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI
#         </td>
#
#         <td>
#             672
#         </td>
#
#         <td>
#             arepa
#         </td>
#
#         <td>
#             5
#         </td>
#
#         <td>
#             1930/08/12
#         </td>
#
#         <td>
#             never
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             7
#         </td>
#
#         <td>
#             CaRL
#         </td>
#
#         <td>
#             Ga%%%uss
#         </td>
#
#         <td>
#             323
#         </td>
#
#         <td>
#             taco
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             1970/07/13
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             David
#         </td>
#
#         <td>
#             H$$$ilbert
#         </td>
#
#         <td>
#             624
#         </td>
#
#         <td>
#             taaaccoo
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             1950/07/14
#         </td>
#
#         <td>
#             let
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             Johannes
#         </td>
#
#         <td>
#             KEPLER
#         </td>
#
#         <td>
#             735
#         </td>
#
#         <td>
#             taco
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             1920/04/22
#         </td>
#
#         <td>
#             you
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             10
#         </td>
#
#         <td>
#             JaMES
#         </td>
#
#         <td>
#             M$$ax%%well
#         </td>
#
#         <td>
#             875
#         </td>
#
#         <td>
#             taco
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             1923/03/12
#         </td>
#
#         <td>
#             down
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             11
#         </td>
#
#         <td>
#             Isaac
#         </td>
#
#         <td>
#             Newton
#         </td>
#
#         <td>
#             992
#         </td>
#
#         <td>
#             pasta
#         </td>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             1999/02/15
#         </td>
#
#         <td>
#             never⸱
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             12
#         </td>
#
#         <td>
#             Emmy%%
#         </td>
#
#         <td>
#             Nöether$
#         </td>
#
#         <td>
#             234
#         </td>
#
#         <td>
#             pasta
#         </td>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             1993/12/08
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             13
#         </td>
#
#         <td>
#             Max!!!
#         </td>
#
#         <td>
#             Planck!!!
#         </td>
#
#         <td>
#             111
#         </td>
#
#         <td>
#             hamburguer
#         </td>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             1994/01/04
#         </td>
#
#         <td>
#             run⸱
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             14
#         </td>
#
#         <td>
#             Fred
#         </td>
#
#         <td>
#             Hoy&amp;&amp;&amp;le
#         </td>
#
#         <td>
#             553
#         </td>
#
#         <td>
#             pizzza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1997/06/27
#         </td>
#
#         <td>
#             around
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>

# %%
df_json =op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/feature/load_save_improvements/examples/data/foo.json", "json")
df_json.table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 19 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">1 (bigint)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">4 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">5 (bigint)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">6 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">price</div>
#             <div class="data_type">7 (bigint)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
#             <div class="data_type">8 (string)</div>
#
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             123
#         </td>
#
#         <td>
#             1980/07/07
#         </td>
#
#         <td>
#             never
#         </td>
#
#         <td>
#             Luis
#         </td>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             Alvarez$$%!
#         </td>
#
#         <td>
#             10
#         </td>
#
#         <td>
#             Cake
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             423
#         </td>
#
#         <td>
#             1950/07/08
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#         <td>
#             André
#         </td>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             Ampère
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             piza
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             551
#         </td>
#
#         <td>
#             1990/07/09
#         </td>
#
#         <td>
#             give
#         </td>
#
#         <td>
#             NiELS
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             Böhr//((%%
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             521
#         </td>
#
#         <td>
#             1954/07/10
#         </td>
#
#         <td>
#             you
#         </td>
#
#         <td>
#             PAUL
#         </td>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             dirac$
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             634
#         </td>
#
#         <td>
#             1990/07/11
#         </td>
#
#         <td>
#             up
#         </td>
#
#         <td>
#             Albert
#         </td>
#
#         <td>
#             5
#         </td>
#
#         <td>
#             Einstein
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             672
#         </td>
#
#         <td>
#             1930/08/12
#         </td>
#
#         <td>
#             never
#         </td>
#
#         <td>
#             Galileo
#         </td>
#
#         <td>
#             6
#         </td>
#
#         <td>
#             ⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI
#         </td>
#
#         <td>
#             5
#         </td>
#
#         <td>
#             arepa
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             323
#         </td>
#
#         <td>
#             1970/07/13
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#         <td>
#             CaRL
#         </td>
#
#         <td>
#             7
#         </td>
#
#         <td>
#             Ga%%%uss
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             taco
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             624
#         </td>
#
#         <td>
#             1950/07/14
#         </td>
#
#         <td>
#             let
#         </td>
#
#         <td>
#             David
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             H$$$ilbert
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             taaaccoo
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             735
#         </td>
#
#         <td>
#             1920/04/22
#         </td>
#
#         <td>
#             you
#         </td>
#
#         <td>
#             Johannes
#         </td>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             KEPLER
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             taco
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             875
#         </td>
#
#         <td>
#             1923/03/12
#         </td>
#
#         <td>
#             down
#         </td>
#
#         <td>
#             JaMES
#         </td>
#
#         <td>
#             10
#         </td>
#
#         <td>
#             M$$ax%%well
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             taco
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             992
#         </td>
#
#         <td>
#             1999/02/15
#         </td>
#
#         <td>
#             never⸱
#         </td>
#
#         <td>
#             Isaac
#         </td>
#
#         <td>
#             11
#         </td>
#
#         <td>
#             Newton
#         </td>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             pasta
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             234
#         </td>
#
#         <td>
#             1993/12/08
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#         <td>
#             Emmy%%
#         </td>
#
#         <td>
#             12
#         </td>
#
#         <td>
#             Nöether$
#         </td>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             pasta
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             111
#         </td>
#
#         <td>
#             1994/01/04
#         </td>
#
#         <td>
#             run⸱
#         </td>
#
#         <td>
#             Max!!!
#         </td>
#
#         <td>
#             13
#         </td>
#
#         <td>
#             Planck!!!
#         </td>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             hamburguer
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             553
#         </td>
#
#         <td>
#             1997/06/27
#         </td>
#
#         <td>
#             around
#         </td>
#
#         <td>
#             Fred
#         </td>
#
#         <td>
#             14
#         </td>
#
#         <td>
#             Hoy&amp;&amp;&amp;le
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             pizzza
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <t

# %%
df_parquet =op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/feature/load_save_improvements/examples/data/foo.parquet", "parquet")
df_parquet.table()
# Out:
# <style>
#     .data_type{
#         font-size: 0.8em;
#         font-weight:normal;
#     }
#     .column_name{
#         font-size: 1.2em;
#     }
#     .info_items{
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
# </style>
# <div class="info_items">Viewing 19 of 19</div>
# <table>
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
#             <div class="data_type">5 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">price</div>
#             <div class="data_type">6 (int)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">7 (string)</div>
#
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">8 (string)</div>
#
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             1
#         </td>
#
#         <td>
#             Luis
#         </td>
#
#         <td>
#             Alvarez$$%!
#         </td>
#
#         <td>
#             123
#         </td>
#
#         <td>
#             Cake
#         </td>
#
#         <td>
#             10
#         </td>
#
#         <td>
#             1980/07/07
#         </td>
#
#         <td>
#             never
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             2
#         </td>
#
#         <td>
#             André
#         </td>
#
#         <td>
#             Ampère
#         </td>
#
#         <td>
#             423
#         </td>
#
#         <td>
#             piza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1950/07/08
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             NiELS
#         </td>
#
#         <td>
#             Böhr//((%%
#         </td>
#
#         <td>
#             551
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1990/07/09
#         </td>
#
#         <td>
#             give
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             PAUL
#         </td>
#
#         <td>
#             dirac$
#         </td>
#
#         <td>
#             521
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1954/07/10
#         </td>
#
#         <td>
#             you
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             5
#         </td>
#
#         <td>
#             Albert
#         </td>
#
#         <td>
#             Einstein
#         </td>
#
#         <td>
#             634
#         </td>
#
#         <td>
#             pizza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1990/07/11
#         </td>
#
#         <td>
#             up
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             6
#         </td>
#
#         <td>
#             Galileo
#         </td>
#
#         <td>
#             ⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI
#         </td>
#
#         <td>
#             672
#         </td>
#
#         <td>
#             arepa
#         </td>
#
#         <td>
#             5
#         </td>
#
#         <td>
#             1930/08/12
#         </td>
#
#         <td>
#             never
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             7
#         </td>
#
#         <td>
#             CaRL
#         </td>
#
#         <td>
#             Ga%%%uss
#         </td>
#
#         <td>
#             323
#         </td>
#
#         <td>
#             taco
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             1970/07/13
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             David
#         </td>
#
#         <td>
#             H$$$ilbert
#         </td>
#
#         <td>
#             624
#         </td>
#
#         <td>
#             taaaccoo
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             1950/07/14
#         </td>
#
#         <td>
#             let
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             Johannes
#         </td>
#
#         <td>
#             KEPLER
#         </td>
#
#         <td>
#             735
#         </td>
#
#         <td>
#             taco
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             1920/04/22
#         </td>
#
#         <td>
#             you
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             10
#         </td>
#
#         <td>
#             JaMES
#         </td>
#
#         <td>
#             M$$ax%%well
#         </td>
#
#         <td>
#             875
#         </td>
#
#         <td>
#             taco
#         </td>
#
#         <td>
#             3
#         </td>
#
#         <td>
#             1923/03/12
#         </td>
#
#         <td>
#             down
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             11
#         </td>
#
#         <td>
#             Isaac
#         </td>
#
#         <td>
#             Newton
#         </td>
#
#         <td>
#             992
#         </td>
#
#         <td>
#             pasta
#         </td>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             1999/02/15
#         </td>
#
#         <td>
#             never⸱
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             12
#         </td>
#
#         <td>
#             Emmy%%
#         </td>
#
#         <td>
#             Nöether$
#         </td>
#
#         <td>
#             234
#         </td>
#
#         <td>
#             pasta
#         </td>
#
#         <td>
#             9
#         </td>
#
#         <td>
#             1993/12/08
#         </td>
#
#         <td>
#             gonna
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             13
#         </td>
#
#         <td>
#             Max!!!
#         </td>
#
#         <td>
#             Planck!!!
#         </td>
#
#         <td>
#             111
#         </td>
#
#         <td>
#             hamburguer
#         </td>
#
#         <td>
#             4
#         </td>
#
#         <td>
#             1994/01/04
#         </td>
#
#         <td>
#             run⸱
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             14
#         </td>
#
#         <td>
#             Fred
#         </td>
#
#         <td>
#             Hoy&amp;&amp;&amp;le
#         </td>
#
#         <td>
#             553
#         </td>
#
#         <td>
#             pizzza
#         </td>
#
#         <td>
#             8
#         </td>
#
#         <td>
#             1997/06/27
#         </td>
#
#         <td>
#             around
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>

# %%
df_csv.save.avro("foo.avro")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\py4j\protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o66.save.
# : org.apache.spark.sql.AnalysisException: Failed to find data source: com.databricks.spark.avro. Please find an Avro package at http://spark.apache.org/third-party-projects.html;
# 	at org.apache.spark.sql.execution.datasources.DataSource$.lookupDataSource(DataSource.scala:630)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:241)
# 	at org.apache.spark.sql.DataFrameWriter.save(DataFrameWriter.scala:225)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
#
#
# During handling of the above exception, another exception occurred:
#
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-10-bf3dbd5f0265> in <module>()
# ----> 1 df_csv.save.avro("foo.avro")
#
# ~\Documents\Optimus\optimus\helpers\decorators.py in wrapper(*args, **kwargs)
#      24         @wraps(func)
#      25         def wrapper(*args, **kwargs):
# ---> 26             return func(*args, **kwargs)
#      27
#      28         setattr(cls, func.__name__, wrapper)
#
# ~\Documents\Optimus\optimus\io\save.py in avro(path, mode, num_partitions)
#      92                 .write.format("com.databricks.spark.avro") \
#      93                 .mode(mode) \
# ---> 94                 .save(path)
#      95         except IOError as e:
#      96             logging.error(e)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyspark\sql\readwriter.py in save(self, path, format, mode, partitionBy, **options)
#     703             self._jwrite.save()
#     704         else:
# --> 705             self._jwrite.save(path)
#     706
#     707     @since(1.4)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#      67                                              e.java_exception.getStackTrace()))
#      68             if s.startswith('org.apache.spark.sql.AnalysisException: '):
# ---> 69                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#      70             if s.startswith('org.apache.spark.sql.catalyst.analysis'):
#      71                 raise AnalysisException(s.split(': ', 1)[1], stackTrace)
#
# AnalysisException: 'Failed to find data source: com.databricks.spark.avro. Please find an Avro package at http://spark.apache.org/third-party-projects.html;'

# %%
df_avro =op.load.url("https://api.github.com/users/mralexgray/repos", "avro")
df_avro.table()

# %%
df_geojson =op.load.url("https://api.github.com/users/mralexgray/repos", "geojson")
df_geojson.table()

# %% [markdown]
# ### Save

# %%
df_csv.save.csv("test.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-19a553bba374> in <module>()
# ----> 1 df_csv.save.csv("test.csv")
#
# NameError: name 'df_csv' is not defined

# %%
df_json.save.json("test.json")

# %%
df_csv.save.parquet("test.parquet")

# %%
df_csv.save.avro("test.parquet")
