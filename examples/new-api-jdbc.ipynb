# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("..")
from optimus import Optimus

# Create optimus
op = Optimus(master="local", app_name= "optimus", verbose = True)

# %%
# Put your db credentials here
db =  op.JDBC(
    db_type="xxxx",
    url="xxxx", 
    database= "xxxx", 
    user= "xxxx", 
    password = "xxxx", 
    port="xxxx")

# %%
db.tables()
# Out:
# <style>
#     .data_type {
#         font-size: 0.8em;
#         font-weight: normal;
#     }
#
#     .column_name {
#         font-size: 1.2em;
#     }
#
#     .info_items {
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
#
#     .optimus_table tr:nth-child(even) {
#         background-color: #f2f2f2 !important;
#     }
#
#     .optimus_table tr:nth-child(odd) {
#         background-color: #ffffff !important;
#     }
#
#     .optimus_table thead {
#         border-bottom: 1px solid black;
#     }
#     .optimus_table{
#         font-size: 12px;
#     }
#
# </style>
#
#
#
#
# <div class="info_items">Viewing 27 of 27 rows / 2 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">table_name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">count</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='offers_shows'>offers_shows</div>
#         </td>
#
#         <td>
#             <div title='106964512'>106964512</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhcustomer_offers_shows'>dwhcustomer_offers_shows</div>
#         </td>
#
#         <td>
#             <div title='5945536'>5945536</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='customer_places'>customer_places</div>
#         </td>
#
#         <td>
#             <div title='4741838'>4741838</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='offers_views'>offers_views</div>
#         </td>
#
#         <td>
#             <div title='3952336'>3952336</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='customer_push_notifications'>customer_push_notifications</div>
#         </td>
#
#         <td>
#             <div title='1869935'>1869935</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='beacon_monitoring_log'>beacon_monitoring_log</div>
#         </td>
#
#         <td>
#             <div title='1723150'>1723150</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhcustomer_offers_views'>dwhcustomer_offers_views</div>
#         </td>
#
#         <td>
#             <div title='1634275'>1634275</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhcustomers'>dwhcustomers</div>
#         </td>
#
#         <td>
#             <div title='1193658'>1193658</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='log_searches'>log_searches</div>
#         </td>
#
#         <td>
#             <div title='674975'>674975</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='offers_rating'>offers_rating</div>
#         </td>
#
#         <td>
#             <div title='301290'>301290</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='offers_taken'>offers_taken</div>
#         </td>
#
#         <td>
#             <div title='211838'>211838</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhcustomer_interactions'>dwhcustomer_interactions</div>
#         </td>
#
#         <td>
#             <div title='196440'>196440</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='offers_favorites'>offers_favorites</div>
#         </td>
#
#         <td>
#             <div title='52921'>52921</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='customer_heart_beat'>customer_heart_beat</div>
#         </td>
#
#         <td>
#             <div title='22532'>22532</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='offers_deletes'>offers_deletes</div>
#         </td>
#
#         <td>
#             <div title='21869'>21869</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhcommerces'>dwhcommerces</div>
#         </td>
#
#         <td>
#             <div title='14271'>14271</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhoffers'>dwhoffers</div>
#         </td>
#
#         <td>
#             <div title='7409'>7409</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='offers_reported'>offers_reported</div>
#         </td>
#
#         <td>
#             <div title='2082'>2082</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='places_interest_categories'>places_interest_categories</div>
#         </td>
#
#         <td>
#             <div title='2051'>2051</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='places_interest_keywords'>places_interest_keywords</div>
#         </td>
#
#         <td>
#             <div title='1163'>1163</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhbeacons_offers'>dwhbeacons_offers</div>
#         </td>
#
#         <td>
#             <div title='900'>900</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhusers'>dwhusers</div>
#         </td>
#
#         <td>
#             <div title='840'>840</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='dwhbeacons'>dwhbeacons</div>
#         </td>
#
#         <td>
#             <div title='697'>697</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='malls'>malls</div>
#         </td>
#
#         <td>
#             <div title='460'>460</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='places_interest'>places_interest</div>
#         </td>
#
#         <td>
#             <div title='246'>246</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='audience_types'>audience_types</div>
#         </td>
#
#         <td>
#             <div title='49'>49</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='report_reason'>report_reason</div>
#         </td>
#
#         <td>
#             <div title='4'>4</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
# <div class="info_items">Viewing 27 of 27 rows / 2 columns</div>
# <div class="info_items">1 partition(s)</div>

# %%
df = db.table_to_df("places_interest", limit=None)

# %%
df.table()
# Out:
# <style>
#     .data_type {
#         font-size: 0.8em;
#         font-weight: normal;
#     }
#
#     .column_name {
#         font-size: 1.2em;
#     }
#
#     .info_items {
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
#
#     .optimus_table tr:nth-child(even) {
#         background-color: #f2f2f2 !important;
#     }
#
#     .optimus_table tr:nth-child(odd) {
#         background-color: #ffffff !important;
#     }
#
#     .optimus_table thead {
#         border-bottom: 1px solid black;
#     }
#     .optimus_table{
#         font-size: 12px;
#     }
#
# </style>
#
#
#
#
# <div class="info_items">Viewing 100 of 246 rows / 15 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id_place_interest</div>
#             <div class="data_type">1 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">address_l1</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">address_l2</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">city</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">id_state</div>
#             <div class="data_type">6 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">zip_code</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">polygon</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">id_category</div>
#             <div class="data_type">9 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">latitude</div>
#             <div class="data_type">10 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">longitude</div>
#             <div class="data_type">11 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">created_at</div>
#             <div class="data_type">12 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">updated_at</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">created_by</div>
#             <div class="data_type">14 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">updated_by</div>
#             <div class="data_type">15 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='6'>6</div>
#         </td>
#
#         <td>
#             <div title='Feria⸱de⸱puebla'>Feria⸱de⸱puebla</div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title='19.05648,-98.181816;19.055547,-98.181118;19.0572,-98.178801;19.058102,-98.179531;19.058183,-98.179402;19.058802,-98.179906;19.058406,-98.180485;19.059005,-98.180968;19.05868,-98.181472;19.057433,-98.180485'>19.05648,-98.181816;19.055547,-98.181118;19.0572,-98.178801;19.058102,-98.179531;19.058183,-98.179402;19.058802,-98.179906;19...</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#         <td>
#             <div title='19.057276'>19.057276</div>
#         </td>
#
#         <td>
#             <div title='-98.180308'>-98.180308</div>
#         </td>
#
#         <td>
#             <div title='2017-08-24⸱21:27:22'>2017-08-24⸱21:27:22</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='141455.0'>141455.0</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='4'>4</div>
#         </td>
#
#         <td>
#             <div title='Parque⸱Ecologico'>Parque⸱Ecologico</div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title='19.036116,-98.182347;19.034249,-98.179128;19.022159,-98.190029;19.023336,-98.191874;19.031166,-98.187068'>19.036116,-98.182347;19.034249,-98.179128;19.022159,-98.190029;19.023336,-98.191874;19.031166,-98.187068</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='19.029137'>19.029137</div>
#         </td>
#
#         <td>
#             <div title='-98.185501'>-98.185501</div>
#         </td>
#
#         <td>
#             <div title='2017-08-24⸱21:12:19'>2017-08-24⸱21:12:19</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='141455.0'>141455.0</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='8'>8</div>
#         </td>
#
#         <td>
#             <div title='Museo⸱de⸱la⸱No⸱Intervención⸱Fuerte⸱de⸱Loreto'>Museo⸱de⸱la⸱No⸱Intervención⸱Fuerte⸱de⸱Loreto</div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </td>
#
#         <td>
#             <div title=''></div>
#         </t
