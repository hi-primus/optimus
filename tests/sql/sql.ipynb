# %%
# If you modify Optimus or any library this code is going to reload it
# %load_ext autoreload
# %autoreload

# %%
# If you are in the example folder. This is the way to find optimus
import sys

# %%
sys.path.append("../..")

# %%
import os
os.environ["SPARK_HOME"] = "/home/arpit/spark-2.4.3-bin-hadoop2.7/"

# %%
from optimus import Optimus
op = Optimus(verbose=True)
# Out:
# INFO:optimus:Operative System:Linux
# INFO:optimus:Just check that Spark and all necessary environments vars are present...
# INFO:optimus:-----
# INFO:optimus:SPARK_HOME=/home/arpit/spark-2.4.3-bin-hadoop2.7/
# INFO:optimus:HADOOP_HOME is not set
# INFO:optimus:PYSPARK_PYTHON=/home/arpit/.virtualenvs/optimus-prime/bin/python
# INFO:optimus:PYSPARK_DRIVER_PYTHON is not set
# INFO:optimus:PYSPARK_SUBMIT_ARGS=--jars "file:///home/arpit/.virtualenvs/optimus-prime/lib/python3.6/site-packages/optimuspyspark-2.2.9-py3.6.egg/optimus/jars/RedshiftJDBC42-1.2.16.1027.jar,file:///home/arpit/.virtualenvs/optimus-prime/lib/python3.6/site-packages/optimuspyspark-2.2.9-py3.6.egg/optimus/jars/mysql-connector-java-8.0.16.jar,file:///home/arpit/.virtualenvs/optimus-prime/lib/python3.6/site-packages/optimuspyspark-2.2.9-py3.6.egg/optimus/jars/ojdbc8.jar,file:///home/arpit/.virtualenvs/optimus-prime/lib/python3.6/site-packages/optimuspyspark-2.2.9-py3.6.egg/optimus/jars/postgresql-42.2.5.jar" --driver-class-path "/home/arpit/.virtualenvs/optimus-prime/lib/python3.6/site-packages/optimuspyspark-2.2.9-py3.6.egg/optimus/jars/RedshiftJDBC42-1.2.16.1027.jar:/home/arpit/.virtualenvs/optimus-prime/lib/python3.6/site-packages/optimuspyspark-2.2.9-py3.6.egg/optimus/jars/mysql-connector-java-8.0.16.jar:/home/arpit/.virtualenvs/optimus-prime/lib/python3.6/site-packages/optimuspyspark-2.2.9-py3.6.egg/optimus/jars/ojdbc8.jar:/home/arpit/.virtualenvs/optimus-prime/lib/python3.6/site-packages/optimuspyspark-2.2.9-py3.6.egg/optimus/jars/postgresql-42.2.5.jar" --conf "spark.sql.catalogImplementation=hive" pyspark-shell
# INFO:optimus:JAVA_HOME is not set
# INFO:optimus:Pyarrow Installed
# INFO:optimus:-----
# INFO:optimus:Starting or getting SparkSession and SparkContext...
# INFO:optimus:Spark Version:2.4.3
# INFO:optimus:
#                              ____        __  _
#                             / __ \____  / /_(_)___ ___  __  _______
#                            / / / / __ \/ __/ / __ `__ \/ / / / ___/
#                           / /_/ / /_/ / /_/ / / / / / / /_/ (__  )
#                           \____/ .___/\__/_/_/ /_/ /_/\__,_/____/
#                               /_/
#
# INFO:optimus:Transform and Roll out...
# INFO:optimus:Optimus successfully imported. Have fun :).
# INFO:optimus:Config.ini not found
# <style> /* Tables*/
#
#  .data_type {
#         font-size: 0.8em;
#         font-weight: normal;
#     }
#
#     .column_name {
#         font-size: 1.2em;
#     }
#
#     .info_items {
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
#
#     .optimus_table td {
#         border: 0px;
#     }
#
#     .optimus_table tr:nth-child(even) {
#         background-color: #f2f2f2 !important;
#     }
#
#     .optimus_table tr:nth-child(odd) {
#         background-color: #ffffff !important;
#     }
#
#     .optimus_table thead {
#         border-bottom: 1px solid black;
#     }
#     .optimus_table{
#         font-size: 12px;
#     }
#
#     .optimus_table tbody{
#         font-family: monospace;
#         border-bottom: 1px solid #cccccc;
#     }
#
#     /* Profiler */
#         .main{
#         width:100%;
#         overflow:auto;
#         border-bottom:1px solid #eeeeee;
#         padding: 10px 0;
#     }
#     .panel_profiler{
#         margin-right:2%;
#         float:left;
#         padding-bottom:2%;
#     }
#     .panel_profiler tbody{
#         font-family:monospace;
#     }
#     .title_profiler{
#         padding:20px;
#         background-color: #eeeeee
#     }
#     .info{
#         overflow: auto
#     }
#     .main td, main th{
#         padding:0em
#     }
#     .panel_profiler td {
#         padding:0.2em
#     }
#     .none, .true{
#         color:#0000ff
#     }
#     .optimus_table th {
#         font-family:sans-serif;
#     }
#
#     .info_items{
#         font-family:sans-serif;
#         font-size:10px;
#     }
# </style>

# %%
import records

# %% [markdown]
# ## Oracle

# %% [markdown]
# ## Mysql

# %%
host = "127.0.0.1"
port= 3306
driver = "mysql"
user = "SA"
password = "SA123"
db_name = "optimus"

db = records.Database('{DRIVER}://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}'.format(DRIVER=driver, USER=user, PASSWORD=password, HOST=host, PORT=port,DB=db_name))

db.query_file('main.sql')
db.query_file('secondary.sql')
# Out:
# <RecordCollection size=0 pending=True>

# %%
# Put your db credentials here
db_mysql =  op.connect(
    db_type="mysql",
    host=host,
    database= db_name,
    user= user,
    password = password,
    port=port)
# Out:
# INFO:optimus:jdbc:mysql://127.0.0.1:3306/optimus?currentSchema=public

# %%
# Get all tables

# %%
a= db_mysql.tables()
# Out:
# INFO:optimus:(SELECT table_name, table_rows FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_SCHEMA = 'optimus' LIMIT 10) AS t
# INFO:optimus:jdbc:mysql://127.0.0.1:3306/optimus?currentSchema=public
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">TABLE_NAME</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">TABLE_ROWS</div>
#             <div class="data_type">2 (decimal(20,0))</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='main'>main
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1000'>1000
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='secondary'>secondary
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='500'>500
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">1 partition(s)</div>

# %%
a.table()
# Out:
# +----------+----------+
# |TABLE_NAME|TABLE_ROWS|
# +----------+----------+
# |      main|      1000|
# | secondary|       500|
# +----------+----------+
#
# {"TABLE_NAME":"main","TABLE_ROWS":1000}
# {"TABLE_NAME":"secondary","TABLE_ROWS":500}
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">TABLE_NAME</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">TABLE_ROWS</div>
#             <div class="data_type">2 (decimal(20,0))</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='main'>main
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1000'>1000
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='secondary'>secondary
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='500'>500
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">1 partition(s)</div>

# %% [markdown]
# ## Postgres

# %%
host = "127.0.0.1"
port= 5432
driver = "postgresql"
user = "SA"
password = "SA123"
db_name = "optimus"
db = "postgres"

db = records.Database('{DRIVER}://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}'.format(DRIVER=driver, USER=user, PASSWORD=password, HOST=host, PORT=port,DB=db_name))

db.query_file('main.sql')
db.query_file('secondary.sql')
# Out:
# <RecordCollection size=0 pending=True>

# %%
# Put your db credentials here
db =  op.connect(
    db_type="postgres",
    host=host,
    database= db_name,
    user= user,
    password = password,
    port=port)
# Out:
# postgresql
# INFO:optimus:jdbc:postgresql://127.0.0.1:5432/optimus?currentSchema=public

# %%
db.url
# Out:
# 'jdbc:postgresql://127.0.0.1:5432/optimus?currentSchema=public'

# %%
a= db.table.show('main')
# Out:
# Total Tables:1
# INFO:optimus:SELECT * FROM main
# INFO:optimus:(SELECT * FROM main LIMIT 10) AS t
# INFO:optimus:jdbc:postgresql://127.0.0.1:5432/optimus?currentSchema=public
# <h1>main</h1>
#
#
#
#
#
# <div class="info_items">Viewing 10 of 10 rows / 8 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last_name</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">email</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">gender</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">color</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">nulls</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">booleans</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">words</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='MacGuiness'>MacGuiness
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='amacguiness0@123-reg.co.uk'>amacguiness0@123-reg.co.uk
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Male'>Male
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Fuscia'>Fuscia
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='true'>true
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='ultrices&#8901;phasellus&#8901;id&#8901;sapien&#8901;in&#8901;sapien&#8901;iaculis&#8901;congue&#8901;vivamus&#8901;metus'>ultrices&#8901;phasellus&#8901;id&#8901;sapien&#8901;in&#8901;sapien&#8901;iaculis&#8901;congue&#8901;vivamus&#8901;metus
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Davidovitch'>Davidovitch
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='adavidovitch1@jiathis.com'>adavidovitch1@jiathis.com
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Male'>Male
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Puce'>Puce
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='true'>true
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='commodo&#8901;vulputate&#8901;justo&#8901;in&#8901;blandit&#8901;ultrices&#8901;enim&#8901;lorem&#8901;ipsum&#8901;dolor&#8901;sit&#8901;amet&#8901;consectetuer&#8901;adipiscing&#8901;elit&#8901;proin&#8901;interdum'>commodo&#8901;vulputate&#8901;justo&#8901;in&#8901;blandit&#8901;ultrices&#8901;enim&#8901;lorem&#8901;ipsum&#8901;dolor&#890...
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='3'>3
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Diggar'>Diggar
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='cdiggar2@europa.eu'>cdiggar2@europa.eu
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Male'>Male
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Maroon'>Maroon
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='false'>false
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='ultrices&#8901;erat&#8901;tortor&#8901;sollicitudin&#8901;mi&#8901;sit&#8901;amet&#8901;lobortis&#8901;sapien&#8901;sapien&#8901;non'>ultrices&#8901;erat&#8901;tortor&#8901;sollicitudin&#8901;mi&#8901;sit&#8901;amet&#8901;lobortis&#8901;sapien&#8901;sapien&#8901;non
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='4'>4
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Bryenton'>Bryenton
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='jbryenton3@godaddy.com'>jbryenton3@godaddy.com
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Female'>Female
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Pink'>Pink
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='true'>true
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='interdum&#8901;mauris&#8901;ullamcorper&#8901;purus&#8901;sit&#8901;amet&#8901;nulla&#8901;quisque&#8901;arcu&#8901;libero&#8901;rutrum&#8901;ac&#8901;lobortis&#8901;vel&#8901;dapibus&#8901;at&#8901;diam&#8901;nam&#8901;tristique'>interdum&#8901;mauris&#8901;ullamcorper&#8901;purus&#8901;sit&#8901;amet&#8901;nulla&#8901;quisque&#8901;arcu&#8901;libero&#8...
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='5'>5
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Thornley'>Thornley
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='gthornley4@whitehouse.gov'>gthornley4@whitehouse.gov
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Female'>Female
#             </div>

# %% [markdown]
# ## Redshift

# %%
# !sudo pip install redshift-sqlalchemy
# Out:
# [sudo] password for argenis:

# %%
port= 5439
driver = "postgres"
user = "SA"
password = "SA123"
db = "optimus"

connection ='{DRIVER}://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}'.format(DRIVER=driver, USER=user, PASSWORD=password, HOST=host, PORT=port,DB=db)
print(connection)
db = records.Database(connection)

db.query_file('main.sql')
db.query_file('secondary.sql')
# Out:
# postgres://SA:SA123@127.0.0.1:5439/optimus
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     293         """
# --> 294         return _ConnectionFairy._checkout(self)
#     295
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     137                 with util.safe_reraise():
# --> 138                     self._dec_overflow()
#     139         else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     134             try:
# --> 135                 return self._create_connection()
#     136             except:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#
# ~/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "SA"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-69-77997ba37de3> in <module>
#       9 db = records.Database(connection)
#      10
# ---> 11 db.query_file('main.sql')
#      12 db.query_file('secondary.sql')
#
# ~/anaconda3/lib/python3.7/site-packages/records.py in query_file(self, path, fetchall, **params)
#     309         """Like Database.query, but takes a filename to load a query from."""
#     310
# --> 311         with self.get_connection() as conn:
#     312             return conn.query_file(path, fetchall, **params)
#     313
#
# ~/anaconda3/lib/python3.7/site-packages/records.py in get_connection(self)
#     290             raise exc.ResourceClosedError('Database closed.')
#     291
# --> 292         return Connection(self._engine.connect())
#     293
#     294     def query(self, query, fetchall=False, **params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2191         """
#    2192
# -> 2193         return self._connection_cls(self, **kwargs)
#    2194
#    2195     @util.deprecated(
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2291         """
#    2292         return self._wrap_pool_connect(
# -> 2293             self.pool.unique_connection, _connection
#    2294         )
#    2295
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2264             if connection is None:
#    2265                 Connection._handle_dbapi_exception_noconnection(
# -> 2266                     e, dialect, self
#    2267                 )
#    2268             else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2260         dialect = self.dialect
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#    2264             if connection is None:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     292
#     293         """
# --> 294         return _ConnectionFairy._checkout(self)
#     295
#     296     def _create_connection(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     749     def _checkout(cls, pool, threadconns=None, fairy=None):
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#     753             fairy._pool = pool
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     481     @classmethod
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#     485             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             except:
#     137                 with util.safe_reraise():
# --> 138                     self._dec_overflow()
#     139         else:
#     140             return self._do_get()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     127         if value.__traceback__ is not tb:
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#     131     def u(s):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     133         if self._inc_overflow():
#     134             try:
# --> 135                 return self._create_connection()
#     136             except:
#     137                 with util.safe_reraise():
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     297         """Called by subclasses to create a new ConnectionRecord."""
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#     301     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     426         self.__pool = pool
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#     430
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     628         try:
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#     632             self.connection = connection
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     451
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#     455     def create_connect_args(self, url):
#
# ~/anaconda3/lib/python3.7/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "SA"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# Put your db credentials here
db =  op.connect(
    db_type="redshift",
    host="yopter.ccyy9l6xansm.us-east-1.redshift.amazonaws.com",
    database= "yopterdwh",
    user= "yopterrs",
    password = "wDY9nkAET8Af",
    port="5439")
# Out:
# redshift
# INFO:optimus:jdbc:redshift://yopter.ccyy9l6xansm.us-east-1.redshift.amazonaws.com:5439/yopterdwh?currentSchema=public

# %%
a= db.tables()
# Out:
# INFO:optimus:(
#             SELECT relname as table_name,cast (reltuples as integer) AS count
#             FROM pg_class C LEFT JOIN pg_namespace N ON (N.oid = C.relnamespace)
#             WHERE nspname IN ('yopterdwh') AND relkind='r' ORDER BY reltuples DESC) AS t
# INFO:optimus:jdbc:redshift://yopter.ccyy9l6xansm.us-east-1.redshift.amazonaws.com:5439/yopterdwh?currentSchema=public

# %%
a.show()
# Out:
# +----------+-----+
# |table_name|count|
# +----------+-----+
# +----------+-----+

# %% [markdown]
# ## Mysql server

# %%
port= 1433
driver = "mssql+pyodbc"
user = "SA"
password = "SA123"
db = "optimus"

# port 1433

connection = '{DRIVER}://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB}'.format(DRIVER=driver, USER=user, PASSWORD=password, HOST=host, PORT=port,DB=db)
print(connection)
db = records.Database(connection)
# rows = db.query('select * from active_users')    # or 
db.query_file('main.sql')
db.query_file('secondary.sql')
# Out:
# mssql+pyodbc://SA:SA123@127.0.0.1:1433/optimus
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     293         """
# --> 294         return _ConnectionFairy._checkout(self)
#     295
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     137                 with util.safe_reraise():
# --> 138                     self._dec_overflow()
#     139         else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     134             try:
# --> 135                 return self._create_connection()
#     136             except:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#
# InterfaceError: ('IM002', '[IM002] [unixODBC][Driver Manager]Data source name not found and no default driver specified (0) (SQLDriverConnect)')
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-70-9d6a30f04801> in <module>
#      11 db = records.Database(connection)
#      12 # rows = db.query('select * from active_users')    # or
# ---> 13 db.query_file('main.sql')
#      14 db.query_file('secondary.sql')
#
# ~/anaconda3/lib/python3.7/site-packages/records.py in query_file(self, path, fetchall, **params)
#     309         """Like Database.query, but takes a filename to load a query from."""
#     310
# --> 311         with self.get_connection() as conn:
#     312             return conn.query_file(path, fetchall, **params)
#     313
#
# ~/anaconda3/lib/python3.7/site-packages/records.py in get_connection(self)
#     290             raise exc.ResourceClosedError('Database closed.')
#     291
# --> 292         return Connection(self._engine.connect())
#     293
#     294     def query(self, query, fetchall=False, **params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2191         """
#    2192
# -> 2193         return self._connection_cls(self, **kwargs)
#    2194
#    2195     @util.deprecated(
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#     101                 connection
#     102                 if connection is not None
# --> 103                 else engine.raw_connection()
#     104             )
#     105             self.__transaction = None
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2291         """
#    2292         return self._wrap_pool_connect(
# -> 2293             self.pool.unique_connection, _connection
#    2294         )
#    2295
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2264             if connection is None:
#    2265                 Connection._handle_dbapi_exception_noconnection(
# -> 2266                     e, dialect, self
#    2267                 )
#    2268             else:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1534             util.raise_from_cause(newraise, exc_info)
#    1535         elif should_wrap:
# -> 1536             util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1537         else:
#    1538             util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2260         dialect = self.dialect
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#    2264             if connection is None:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in unique_connection(self)
#     292
#     293         """
# --> 294         return _ConnectionFairy._checkout(self)
#     295
#     296     def _create_connection(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     749     def _checkout(cls, pool, threadconns=None, fairy=None):
#     750         if not fairy:
# --> 751             fairy = _ConnectionRecord.checkout(pool)
#     752
#     753             fairy._pool = pool
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     481     @classmethod
#     482     def checkout(cls, pool):
# --> 483         rec = pool._do_get()
#     484         try:
#     485             dbapi_connection = rec.get_connection()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     136             except:
#     137                 with util.safe_reraise():
# --> 138                     self._dec_overflow()
#     139         else:
#     140             return self._do_get()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.reraise(exc_type, exc_value, exc_tb)
#      69         else:
#      70             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     127         if value.__traceback__ is not tb:
#     128             raise value.with_traceback(tb)
# --> 129         raise value
#     130
#     131     def u(s):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     133         if self._inc_overflow():
#     134             try:
# --> 135                 return self._create_connection()
#     136             except:
#     137                 with util.safe_reraise():
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     297         """Called by subclasses to create a new ConnectionRecord."""
#     298
# --> 299         return _ConnectionRecord(self)
#     300
#     301     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     426         self.__pool = pool
#     427         if connect:
# --> 428             self.__connect(first_connect_check=True)
#     429         self.finalize_callback = deque()
#     430
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/pool/base.py in __connect(self, first_connect_check)
#     628         try:
#     629             self.starttime = time.time()
# --> 630             connection = pool._invoke_creator(self)
#     631             pool.logger.debug("Created new connection %r", connection)
#     632             self.connection = connection
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     451
#     452     def connect(self, *cargs, **cparams):
# --> 453         return self.dbapi.connect(*cargs, **cparams)
#     454
#     455     def create_connect_args(self, url):
#
# InterfaceError: (pyodbc.InterfaceError) ('IM002', '[IM002] [unixODBC][Driver Manager]Data source name not found and no default driver specified (0) (SQLDriverConnect)')
# (Background on this error at: http://sqlalche.me/e/rvf5)
