# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../..")

# %%
from optimus import Optimus
from optimus.helpers.test import Test
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\socks.py:58: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Callable
#
#     You are using PySparkling of version 2.4.10, but your PySpark is of
#     version 2.3.1. Please make sure Spark and PySparkling versions are compatible.

# %%
op = Optimus(master='local', verbose=True)
# Out:
# INFO:optimus:Operative System:Windows
# INFO:optimus:Just check that Spark and all necessary environments vars are present...
# INFO:optimus:-----
# INFO:optimus:SPARK_HOME=C:\opt\spark\spark-2.3.1-bin-hadoop2.7
# INFO:optimus:HADOOP_HOME=C:\opt\hadoop-2.7.7
# INFO:optimus:PYSPARK_PYTHON=C:\Users\argenisleon\Anaconda3\python.exe
# INFO:optimus:PYSPARK_DRIVER_PYTHON=jupyter
# INFO:optimus:PYSPARK_SUBMIT_ARGS=--jars "file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/RedshiftJDBC42-1.2.16.1027.jar,file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/mysql-connector-java-8.0.16.jar,file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/ojdbc8.jar,file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/postgresql-42.2.5.jar" --driver-class-path "C:/Users/argenisleon/Documents/Optimus/optimus/jars/RedshiftJDBC42-1.2.16.1027.jar;C:/Users/argenisleon/Documents/Optimus/optimus/jars/mysql-connector-java-8.0.16.jar;C:/Users/argenisleon/Documents/Optimus/optimus/jars/ojdbc8.jar;C:/Users/argenisleon/Documents/Optimus/optimus/jars/postgresql-42.2.5.jar" --conf "spark.sql.catalogImplementation=hive" pyspark-shell
# INFO:optimus:JAVA_HOME=C:\java
# INFO:optimus:Pyarrow Installed
# INFO:optimus:-----
# INFO:optimus:Starting or getting SparkSession and SparkContext...
# INFO:optimus:Spark Version:2.3.1
# INFO:optimus:
#                              ____        __  _
#                             / __ \____  / /_(_)___ ___  __  _______
#                            / / / / __ \/ __/ / __ `__ \/ / / / ___/
#                           / /_/ / /_/ / /_/ / / / / / / /_/ (__  )
#                           \____/ .___/\__/_/_/ /_/ /_/\__,_/____/
#                               /_/
#
# INFO:optimus:Transform and Roll out...
# INFO:optimus:Optimus successfully imported. Have fun :).
# INFO:optimus:Config.ini not found
# <style> /* Tables*/
#
#  .data_type {
#         font-size: 0.8em;
#         font-weight: normal;
#     }
#
#     .column_name {
#         font-size: 1.2em;
#     }
#
#     .info_items {
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
#
#     .optimus_table td {
#         border: 0px;
#     }
#
#     .optimus_table tr:nth-child(even) {
#         background-color: #f2f2f2 !important;
#     }
#
#     .optimus_table tr:nth-child(odd) {
#         background-color: #ffffff !important;
#     }
#
#     .optimus_table thead {
#         border-bottom: 1px solid black;
#     }
#     .optimus_table{
#         font-size: 12px;
#     }
#
#     .optimus_table tbody{
#         font-family: monospace;
#         border-bottom: 1px solid #cccccc;
#     }
#
#     /* Profiler */
#         .main{
#         width:100%;
#         overflow:auto;
#         border-bottom:1px solid #eeeeee;
#         padding: 10px 0;
#     }
#     .panel_profiler{
#         margin-right:2%;
#         float:left;
#         padding-bottom:2%;
#     }
#     .panel_profiler tbody{
#         font-family:monospace;
#     }
#     .title_profiler{
#         padding:20px;
#         background-color: #eeeeee
#     }
#     .info{
#         overflow: auto
#     }
#     .main td, main th{
#         padding:0em
#     }
#     .panel_profiler td {
#         padding:0.2em
#     }
#     .none, .true{
#         color:#0000ff
#     }
#     .optimus_table th {
#         font-family:sans-serif;
#     }
#
#     .info_items{
#         font-family:sans-serif;
#         font-size:10px;
#     }
# </style>

# %%
# Import Vectors
from pyspark.ml.linalg import Vectors

data = [
(0,1,2, Vectors.dense([1.0, 0.5, -1.0]),),
(1,2,3, Vectors.dense([2.0, 1.0, 1.0]),),
(2,3,4, Vectors.dense([4.0, 10.0, 2.0]),)]

source_df = op.spark.createDataFrame(data,["id","x", "y", "features"])

# %%
t = Test(op, df, "df_ml_2", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                        "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F",
                                        "from optimus.ml import feature as fe"], path = "df_ml_2", final_path="..")

# %% [markdown]
# ## Normalizer

# %%
from optimus.ml import feature as fe
t.create(fe, "normalizer", None, 'df', None, source_df, input_cols=["features"], p=2.0)
# Out:
# Creating test_normalizer() test function...
# INFO:optimus:test_normalizer()
# <div class="info_items">Viewing 3 of 3 rows / 5 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">x</div>
#             <div class="data_type">2 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">y</div>
#             <div class="data_type">3 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">features</div>
#             <div class="data_type">4 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">features***NORMALIZED</div>
#             <div class="data_type">5 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='0'>0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[1.0,0.5,-1.0]'>[1.0,0.5,-1.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[0.6666666666666666,0.3333333333333333,-0.6666666666666666]'>[0.6666666666666666,0.3333333333333333,-0.6666666666666666]
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='3'>3
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[2.0,1.0,1.0]'>[2.0,1.0,1.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[0.8164965809277261,0.4082482904638631,0.4082482904638631]'>[0.8164965809277261,0.4082482904638631,0.4082482904638631]
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='3'>3
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4'>4
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[4.0,10.0,2.0]'>[4.0,10.0,2.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[0.3651483716701107,0.9128709291752769,0.18257418583505536]'>[0.3651483716701107,0.9128709291752769,0.18257418583505536]
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 3 of 3 rows / 5 columns</div>
# <div class="info_items">1 partition(s)</div>

# %% [markdown]
# ## Vector Assembler

# %%
t.create(fe, "vector_assembler", None, 'df', None, source_df, input_cols=["id", "x", "y"])
# Out:
# Creating test_vector_assembler() test function...
# INFO:optimus:test_vector_assembler()
# <div class="info_items">Viewing 3 of 3 rows / 5 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">x</div>
#             <div class="data_type">2 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">y</div>
#             <div class="data_type">3 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">features</div>
#             <div class="data_type">4 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">id_x_y***_VECTOR_ASSEMBLER</div>
#             <div class="data_type">5 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='0'>0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[1.0,0.5,-1.0]'>[1.0,0.5,-1.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[0.0,1.0,2.0]'>[0.0,1.0,2.0]
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='3'>3
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[2.0,1.0,1.0]'>[2.0,1.0,1.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[1.0,2.0,3.0]'>[1.0,2.0,3.0]
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='3'>3
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4'>4
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[4.0,10.0,2.0]'>[4.0,10.0,2.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[2.0,3.0,4.0]'>[2.0,3.0,4.0]
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 3 of 3 rows / 5 columns</div>
# <div class="info_items">1 partition(s)</div>

# %% [markdown]
# ## Onehot encoder

# %%
# Creating DataFrame
data = [
(0, "a"),
(1, "b"),
(2, "c"),
(3, "a"),
(4, "a"),
(5, "c")
]
df = op.spark.createDataFrame(data,["id", "category"])

# %%
t.create(fe, "one_hot_encoder", None, 'df', None, source_df, input_cols=["id"])
# Out:
# Creating test_one_hot_encoder() test function...
# INFO:optimus:test_one_hot_encoder()
# <div class="info_items">Viewing 3 of 3 rows / 5 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">x</div>
#             <div class="data_type">2 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">y</div>
#             <div class="data_type">3 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">features</div>
#             <div class="data_type">4 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">id***ONE_HOT_ENCODER</div>
#             <div class="data_type">5 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='0'>0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[1.0,0.5,-1.0]'>[1.0,0.5,-1.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='(2,[0],[1.0])'>(2,[0],[1.0])
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='3'>3
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[2.0,1.0,1.0]'>[2.0,1.0,1.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='(2,[1],[1.0])'>(2,[1],[1.0])
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='2'>2
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='3'>3
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4'>4
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[4.0,10.0,2.0]'>[4.0,10.0,2.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='(2,[],[])'>(2,[],[])
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 3 of 3 rows / 5 columns</div>
# <div class="info_items">1 partition(s)</div>

# %%
t.run()
# Out:
# Creating file ../test_df_ml_2.py
# Done
