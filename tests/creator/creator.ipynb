# %% [markdown]
# ### All this cell must be run to executed the tests

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys

# %%
sys.path.append("../..")

# %%
from optimus import Optimus
from optimus.helpers.test import Test

# %%
op = Optimus(master='local')
# Out:
# <style> /* Tables*/
#
#  .data_type {
#         font-size: 0.8em;
#         font-weight: normal;
#     }
#
#     .column_name {
#         font-size: 1.2em;
#     }
#
#     .info_items {
#         margin: 10px 0;
#         font-size: 0.8em;
#     }
#
#     .optimus_table td {
#         padding: 2px;
#         border-left: 1px solid #cccccc;
#         border-right: 1px solid #cccccc;
#     }
#
#     .optimus_table tr:nth-child(even) {
#         background-color: #f2f2f2 !important;
#     }
#
#     .optimus_table tr:nth-child(odd) {
#         background-color: #ffffff !important;
#     }
#
#     .optimus_table thead {
#         border-bottom: 1px solid black;
#     }
#     .optimus_table{
#         font-size: 12px;
#     }
#
#     .optimus_table tbody{
#         font-family: monospace;
#         border-bottom: 1px solid #cccccc;
#     }
#
#     /* Profiler */
#         .main{
#         width:100%;
#         overflow:auto;
#         border-bottom:1px solid #eeeeee;
#         padding: 10px 0;
#     }
#     .panel_profiler{
#         margin-right:2%;
#         float:left;
#         padding-bottom:2%;
#     }
#     .panel_profiler tbody{
#         font-family:monospace;
#     }
#     .title_profiler{
#         padding:20px;
#         background-color: #eeeeee
#     }
#     .info{
#         overflow: auto
#     }
#     .main td, main th{
#         padding:0em
#     }
#     .panel_profiler td {
#         padding:0.2em
#     }
#     .none{
#         color:#0000ff
#     }
# </style>

# %%
import pandas as pd
from pyspark.sql.types import *
from datetime import date, datetime


cols = [
        ("names", "str"),
        ("height(ft)", ShortType()),
        ("function", "str"),
        ("rank", ByteType()),
        ("age", "int"),
        ("weight(t)", "float"),
        "japanese name",
        "last position seen",
        "date arrival",
        "last date seen",
        ("attributes", ArrayType(FloatType())),
        ("Date Type", DateType()),
        ("Tiemstamp", TimestampType()),
        ("Cybertronian", BooleanType()),
        ("function(binary)", BinaryType()),
        ("NullType", NullType())

    ]

rows = [
        ("Optim'us", -28, "Leader", 10, 5000000, 4.30, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
         "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True, bytearray("Leader", "utf-8"),
         None),
        ("bumbl#ebéé  ", 17, "Espionage", 7, 5000000, 2.0, ["Bumble", "Goldback"], "10.642707,-71.612534", "1980/04/10",
         "2015/08/10", [5.334, 2000.0], date(2015, 8, 10), datetime(2014, 6, 24), True, bytearray("Espionage", "utf-8"),
         None),
        ("ironhide&", 26, "Security", 7, 5000000, 4.0, ["Roadbuster"], "37.789563,-122.400356", "1980/04/10",
         "2014/07/10", [7.9248, 4000.0], date(2014, 6, 24), datetime(2014, 6, 24), True, bytearray("Security", "utf-8"),
         None),
        ("Jazz", 13, "First Lieutenant", 8, 5000000, 1.80, ["Meister"], "33.670666,-117.841553", "1980/04/10",
         "2013/06/10", [3.9624, 1800.0], date(2013, 6, 24), datetime(2014, 6, 24), True,
         bytearray("First Lieutenant", "utf-8"), None),
        ("Megatron", None, "None", 10, 5000000, 5.70, ["Megatron"], None, "1980/04/10", "2012/05/10", [None, 5700.0],
         date(2012, 5, 10), datetime(2014, 6, 24), True, bytearray("None", "utf-8"), None),
        ("Metroplex_)^$", 300, "Battle Station", 8, 5000000, None, ["Metroflex"], None, "1980/04/10", "2011/04/10",
         [91.44, None], date(2011, 4, 10), datetime(2014, 6, 24), True, bytearray("Battle Station", "utf-8"), None),
        (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),

    ]
source_df = op.create.df(cols ,rows)
source_df.table()
# Out:
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""

# %% [markdown]
# ### End Init Section

# %% [markdown]
# # Test

# %% [markdown]
# ## Optimus Test

# %%
from pyspark.ml.linalg import Vectors

# %%
t = Test(op, None, "create_df", imports=["import datetime",
                                "from pyspark.sql import functions as F"], path = "..", final_path="..")

# %%
one_column = {"rows":["Argenis", "Favio", "Matthew"], "cols":["name"]}
plain = {"rows":[("BOB", 1),("JoSe", 2)],"cols":["name","age"]}
plain_infer_false = {"rows":[("BOB", 1),("JoSe", 2)],"cols":["name","age"],"infer_schema":False}
with_data_types = {"rows":[("BOB", 1),("JoSe", 2)],"cols":[("name", StringType(), True),("age", IntegerType(), False)]}
nullable = {"rows":[("BOB", 1),("JoSe", 2)],"cols":[("name", StringType()),("age", IntegerType())]}

df1 = op.create.df(**one_column)
df2 = op.create.df(**plain)
df3 = op.create.df(**plain_infer_false)
df4 = op.create.df(**with_data_types)
df5 = op.create.df(**nullable)

# %%
t.create(df1, None, "one_column", "df", **one_column)
# Out:
# Creating test_create_df_one_column() test function...
# <div class="info_items">Viewing 3 of 3 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Argenis'>Argenis</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Favio'>Favio</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Matthew'>Matthew</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 3 of 3 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(df2, None, "plain", "df", **plain)
# Out:
# Creating test_create_df_plain() test function...
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='BOB'>BOB</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='JoSe'>JoSe</div>
#         </td>
#
#         <td>
#             <div title='2'>2</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(df3, None, "plain_infer_false", "df", **plain_infer_false)
# Out:
# Creating test_create_df_plain_infer_false() test function...
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='BOB'>BOB</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='JoSe'>JoSe</div>
#         </td>
#
#         <td>
#             <div title='2'>2</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(df4, None, "with_data_types", "df", **with_data_types)
# Out:
# Creating test_create_df_with_data_types() test function...
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='BOB'>BOB</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='JoSe'>JoSe</div>
#         </td>
#
#         <td>
#             <div title='2'>2</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(df5, None, "nullable", "df", **nullable)
# Out:
# Creating test_create_df_nullable() test function...
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='BOB'>BOB</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='JoSe'>JoSe</div>
#         </td>
#
#         <td>
#             <div title='2'>2</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.run()
# Out:
# Creating file create_df/test_Optimus.py
# Done

# %% [markdown]
# ## Columns Test

# %%
from pyspark.ml.linalg import Vectors

# %%
t = Test(op, source_df, "df_cols", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                        "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F"], path = "df_cols", final_path="..")

# %%
from pyspark.sql import functions as F


def func(col_name, attrs):
    return F.col(col_name) * 2

numeric_col = "height(ft)"
numeric_col_B = "rank"
numeric_col_C = "rank"
string_col = "function"
date_col = "date arrival"
date_col_B = "last date seen"
new_col = "new col"
array_col = "attributes"

# %%
t.create(None, "cols.min", None, "json", numeric_col)
# Out:
# Creating test_cols_min() test function...
# -28

# %%
t.create(None, "cols.min", "all_columns", "json", "*")
# Out:
# Creating test_cols_min_all_columns() test function...
# {'names': {'min': 'Jazz'}, 'height(ft)': {'min': -28}, 'function': {'min': 'Battle Station'}, 'rank': {'min': 7}, 'age': {'min': 5000000}, 'weight(t)': {'min': 1.8}, 'japanese name': {'min': ['Bumble', 'Goldback']}, 'last position seen': {'min': '10.642707,-71.612534'}, 'date arrival': {'min': '1980/04/10'}, 'last date seen': {'min': '2011/04/10'}, 'attributes': {'min': [None, 5700.0]}, 'Date Type': {'min': datetime.date(2011, 4, 10)}, 'Tiemstamp': {'min': datetime.datetime(2014, 6, 24, 0, 0)}, 'Cybertronian': {'min': 1}, 'function(binary)': {'min': bytearray(b'Battle Station')}, 'NullType': {'min': None}}

# %%
t.create(None, "cols.max", None, "json", numeric_col)
# Out:
# Creating test_cols_max() test function...
# 300

# %%
t.create(None, "cols.max", "all_columns", "json", "*")
# Out:
# Creating test_cols_max_all_columns() test function...
# {'names': {'max': 'ironhide&'}, 'height(ft)': {'max': 300}, 'function': {'max': 'Security'}, 'rank': {'max': 10}, 'age': {'max': 5000000}, 'weight(t)': {'max': 5.7}, 'japanese name': {'max': ['Roadbuster']}, 'last position seen': {'max': '37.789563,-122.400356'}, 'date arrival': {'max': '1980/04/10'}, 'last date seen': {'max': '2016/09/10'}, 'attributes': {'max': [91.44000244140625, None]}, 'Date Type': {'max': datetime.date(2016, 9, 10)}, 'Tiemstamp': {'max': datetime.datetime(2014, 6, 24, 0, 0)}, 'Cybertronian': {'max': 1}, 'function(binary)': {'max': bytearray(b'Security')}, 'NullType': {'max': None}}

# %%
t.create(None, "cols.range", None, "json", numeric_col)
# Out:
# Creating test_cols_range() test function...
# {'height(ft)': {'min': -28, 'max': 300}}

# %%
t.create(None, "cols.range", "all_columns", "json", "*")
# Out:
# Creating test_cols_range_all_columns() test function...
# {'names': {'min': 'Jazz', 'max': 'ironhide&'}, 'height(ft)': {'min': -28, 'max': 300}, 'function': {'min': 'Battle Station', 'max': 'Security'}, 'rank': {'min': 7, 'max': 10}, 'age': {'min': 5000000, 'max': 5000000}, 'weight(t)': {'min': 1.8, 'max': 5.7}, 'japanese name': {'min': ['Bumble', 'Goldback'], 'max': ['Roadbuster']}, 'last position seen': {'min': '10.642707,-71.612534', 'max': '37.789563,-122.400356'}, 'date arrival': {'min': '1980/04/10', 'max': '1980/04/10'}, 'last date seen': {'min': '2011/04/10', 'max': '2016/09/10'}, 'attributes': {'min': [None, 5700.0], 'max': [91.44000244140625, None]}, 'Date Type': {'min': datetime.date(2011, 4, 10), 'max': datetime.date(2016, 9, 10)}, 'Tiemstamp': {'min': datetime.datetime(2014, 6, 24, 0, 0), 'max': datetime.datetime(2014, 6, 24, 0, 0)}, 'Cybertronian': {'min': 1, 'max': 1}, 'function(binary)': {'min': bytearray(b'Battle Station'), 'max': bytearray(b'Security')}, 'NullType': {'min': None, 'max': None}}

# %%
t.create(None, "cols.median", None, "json", numeric_col)
# Out:
# Creating test_cols_median() test function...
# -28.0

# %%
t.create(None, "cols.median", "all_columns", "json", "*")
# Out:
# Creating test_cols_median_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': -28.0, 'rank': 7.0, 'age': 5000000.0, 'weight(t)': 1.7999999523162842}

# %%
t.create(None, "cols.percentile", None, "json", numeric_col, [0.05, 0.25], 1)
# Out:
# Creating test_cols_percentile() test function...
# {'0.05': -28.0, '0.25': -28.0}

# %%
t.create(None, "cols.percentile", "all_columns", "json", "*", [0.05, 0.25], 1)
# Out:
# Creating test_cols_percentile_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': {'0.05': -28.0, '0.25': -28.0}, 'rank': {'0.05': 7.0, '0.25': 7.0}, 'age': {'0.05': 5000000.0, '0.25': 5000000.0}, 'weight(t)': {'0.05': 1.7999999523162842, '0.25': 1.7999999523162842}}

# %%
t.create(None, "cols.mad", None, "json", numeric_col)
# Out:
# Creating test_cols_mad() test function...
# 0.0

# %%
t.create(None, "cols.mad", "all_columns", "json", "*")
# Out:
# Creating test_cols_mad_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': 0.0, 'rank': 0.0, 'age': 0.0, 'weight(t)': 0.0}

# %%
t.create(None, "cols.std", None, "json", numeric_col)
# Out:
# Creating test_cols_std() test function...
# 132.66612

# %%
t.create(None, "cols.std", "all_columns", "json", "*")
# Out:
# Creating test_cols_std_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': {'stddev': 132.66612}, 'rank': {'stddev': 1.36626}, 'age': {'stddev': 0.0}, 'weight(t)': {'stddev': 1.64712}}

# %%
t.create(None, "cols.kurt", None, "json", numeric_col)
# Out:
# Creating test_cols_kurt() test function...
# 0.13863

# %%
t.create(None, "cols.kurt", "all_columns", "json", "*")
# Out:
# Creating test_cols_kurt_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': {'kurtosis': 0.13863}, 'rank': {'kurtosis': -1.5}, 'age': {'kurtosis': nan}, 'weight(t)': {'kurtosis': -1.43641}}

# %%
t.create(None, "cols.mean", None, "json", numeric_col)
# Out:
# Creating test_cols_mean() test function...
# 65.6

# %%
t.create(None, "cols.mean", "all_columns", "json", "*")
# Out:
# Creating test_cols_mean_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': {'mean': 65.6}, 'rank': {'mean': 8.33333}, 'age': {'mean': 5000000.0}, 'weight(t)': {'mean': 3.56}}

# %%
t.create(None, "cols.skewness", None, "json", numeric_col)
# Out:
# Creating test_cols_skewness() test function...
# 1.4049

# %%
t.create(None, "cols.skewness", "all_columns", "json", "*")
# Out:
# Creating test_cols_skewness_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': {'skewness': 1.4049}, 'rank': {'skewness': 0.3818}, 'age': {'skewness': nan}, 'weight(t)': {'skewness': 0.06521}}

# %%
t.create(None, "cols.sum", None, "json", numeric_col)
# Out:
# Creating test_cols_sum() test function...
# 328

# %%
t.create(None, "cols.sum", "all_columns", "json", "*")
# Out:
# Creating test_cols_sum_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': {'sum': 328}, 'rank': {'sum': 50}, 'age': {'sum': 30000000}, 'weight(t)': {'sum': 17.8}}

# %%
t.create(None, "cols.variance", None, "json", numeric_col)
# Out:
# Creating test_cols_variance() test function...
# 17600.3

# %%
t.create(None, "cols.variance", "all_columns", "json", "*")
# Out:
# Creating test_cols_variance_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': {'variance': 17600.3}, 'rank': {'variance': 1.86667}, 'age': {'variance': 0.0}, 'weight(t)': {'variance': 2.713}}

# %%
t.create(None, "cols.abs", None, "df", numeric_col)
# Out:
# Creating test_cols_abs() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='28'>28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;R

# %%
t.create(None, "cols.abs", "all_columns", "df", "*")
# Out:
# Creating test_cols_abs_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='28'>28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;R

# %%
t.create(None, "cols.mode", None, "json", numeric_col)
# Out:
# Creating test_cols_mode() test function...
# None

# %%
t.create(None, "cols.mode", "all_columns", "json", "*")
# Out:
# Creating test_cols_mode_all_columns() test function...
# [{'names': None}, {'height(ft)': None}, {'function': None}, {'rank': [8, 7, 10]}, {'age': 5000000}, {'weight(t)': None}, {'japanese name': None}, {'last position seen': None}, {'date arrival': '1980/04/10'}, {'last date seen': None}, {'attributes': None}, {'Date Type': None}, {'Tiemstamp': datetime.datetime(2014, 6, 24, 0, 0)}, {'Cybertronian': True}, {'function(binary)': None}, {'NullType': None}]

# %%
t.create(None, "cols.count", None, "json")
# Out:
# Creating test_cols_count() test function...
# 16

# %%
t.create(None, "cols.count_na", None, "json", numeric_col)
# Out:
# Creating test_cols_count_na() test function...
# 2

# %%
t.create(None, "cols.count_na", "all_columns", "json", "*")
# Out:
# Creating test_cols_count_na_all_columns() test function...
# Including 'nan' as Null in processing 'names'
# Including 'nan' as Null in processing 'function'
# Including 'nan' as Null in processing 'last position seen'
# Including 'nan' as Null in processing 'date arrival'
# Including 'nan' as Null in processing 'last date seen'
# Including 'nan' as Null in processing 'Cybertronian'
# {'names': 1, 'height(ft)': 2, 'function': 1, 'rank': 1, 'age': 1, 'weight(t)': 2, 'japanese name': 1, 'last position seen': 3, 'date arrival': 1, 'last date seen': 1, 'attributes': 1, 'Date Type': 1, 'Tiemstamp': 1, 'Cybertronian': 1, 'function(binary)': 1, 'NullType': 7}

# %%
t.create(None, "cols.count_zeros", None, "json", numeric_col)
# Out:
# Creating test_cols_count_zeros() test function...
# 0

# %%
t.create(None, "cols.count_zeros", "all_columns", "json", "*")
# Out:
# Creating test_cols_count_zeros_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': 0, 'rank': 0, 'age': 0, 'weight(t)': 0}

# %%
t.create(None, "cols.count_uniques", None, "json", numeric_col)
# Out:
# Creating test_cols_count_uniques() test function...
# 5

# %%
t.create(None, "cols.count_uniques", "all_columns", "json", "*")
# Out:
# Creating test_cols_count_uniques_all_columns() test function...
# {'names': 5, 'height(ft)': 5, 'function': 6, 'rank': 3, 'age': 1, 'weight(t)': 5, 'japanese name': 6, 'last position seen': 4, 'date arrival': 1, 'last date seen': 6, 'attributes': 6, 'Date Type': 6, 'Tiemstamp': 1, 'Cybertronian': 1, 'function(binary)': 6, 'NullType': 0}

# %%
t.create(None, "cols.unique", None, "json", numeric_col)
# Out:
# Creating test_cols_unique() test function...
# {'height(ft)': [300, 26, None, 13, 17, -28]}

# %%
t.create(None, "cols.unique", "all_columns", "json", "*")
# Out:
# Creating test_cols_unique_all_columns() test function...
# {'names': ['Jazz', None, 'bumbl#ebéé  ', 'ironhide&', "Optim'us", 'Megatron', 'Metroplex_)^$'], 'height(ft)': [300, 26, None, 13, 17, -28], 'function': ['Leader', 'First Lieutenant', 'None', 'Security', None, 'Espionage', 'Battle Station'], 'rank': [None, 8, 7, 10], 'age': [None, 5000000], 'weight(t)': [5.699999809265137, None, 2.0, 1.7999999523162842, 4.0, 4.300000190734863], 'japanese name': [['Metroflex'], ['Bumble', 'Goldback'], None, ['Inochi', 'Convoy'], ['Megatron'], ['Meister'], ['Roadbuster']], 'last position seen': [None, '37.789563,-122.400356', '19.442735,-99.201111', '33.670666,-117.841553', '10.642707,-71.612534'], 'date arrival': [None, '1980/04/10'], 'last date seen': ['2011/04/10', None, '2012/05/10', '2013/06/10', '2015/08/10', '2014/07/10', '2016/09/10'], 'attributes': [[3.962399959564209, 1800.0], [None, 5700.0], None, [8.53439998626709, 4300.0], [7.924799919128418, 4000.0], [91.44000244140625, None], [5.334000110626221, 2000.0]], 'Date Type': [datetime.date(2012, 5, 10), datetime.date(2015, 8, 10), None, datetime.date(2011, 4, 10), datetime.date(2013, 6, 24), datetime.date(2014, 6, 24), datetime.date(2016, 9, 10)], 'Tiemstamp': [datetime.datetime(2014, 6, 24, 0, 0), None], 'Cybertronian': [None, True], 'function(binary)': [bytearray(b'Leader'), bytearray(b'First Lieutenant'), bytearray(b'None'), bytearray(b'Security'), None, bytearray(b'Espionage'), bytearray(b'Battle Station')], 'NullType': [None]}

# %%
t.create(None, "cols.add", None, "df", [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_add() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">sum</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-18.0'>-18.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='24.0'>24.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>

# %%
t.create(None, "cols.add", "all_columns", "df", "*"),
# Out:
# Creating test_cols_add_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">sum</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='4999986.5'>4999986.5</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='5000026.0'>5000026.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
# (None,)

# %%
t.create(None, "cols.sub", None, "df", [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_sub() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">sub</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-38.0'>-38.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>

# %%
t.create(None, "cols.sub", "all_columns", "df", "*")
# Out:
# Creating test_cols_sub_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">sub</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-5000042.5'>-5000042.5</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-4999992.0'>-4999992.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>

# %%
t.create(None, "cols.mul", None, "df", [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_mul() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">mul</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-280.0'>-280.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='119.0'>119.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <

# %%
t.create(None, "cols.mul", "all_columns", "df", "*")
# Out:
# Creating test_cols_mul_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">mul</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-6020000256.0'>-6020000256.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1190000000.0'>1190000000.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;<

# %%
t.create(None, "cols.div", None, "df", [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_div() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">div</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-2.8'>-2.8</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2.4285714285714284'>2.4285714285714284</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         <

# %%
t.create(None, "cols.div", "all_columns", "df", "*")
# Out:
# Creating test_cols_div_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">div</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-1.302325523628167e-07'>-1.302325523628167e-07</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2.428571428571428e-07'>2.428571428571428e-07</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div

# %%
t.create(None, "cols.z_score", None, "df", numeric_col)
# Out:
# Creating test_cols_z_score() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">z_col_height(ft)</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='0.7055305454022474'>0.7055305454022474</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='0.366333167805013'>0.366333167805013</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>i

# %%
t.create(None, "cols.z_score", "all_columns", "df", "*")
# Out:
# Creating test_cols_z_score_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 20 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">z_col_height(ft)</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">z_col_rank</div>
#             <div class="data_type">18 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">z_col_age</div>
#             <div class="data_type">19 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">z_col_weight(t)</div>
#             <div class="data_type">20 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='0.7055305454022474'>0.7055305454022474</div>
#         </td>
#
#         <td>
#             <div title='1.2198776221217045'>1.2198776221217045</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='0.4492691429494289'>0.4492691429494289</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>

# %%
t.create(None, "cols.iqr", None, "json", numeric_col)
# Out:
# Creating test_cols_iqr() test function...
# 13.0

# %%
t.create(None, "cols.iqr", "all_columns", "json", "*")
# Out:
# Creating test_cols_iqr_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': 13.0, 'rank': 3.0, 'age': 0.0, 'weight(t)': 2.3000001907348633}

# %%
t.create(None, "cols.lower", None, "df", string_col)
# Out:
# Creating test_cols_lower() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='leader'>leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='espionage'>espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='security'>security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.lower", "all_columns", "df", "*")
# Out:
# Creating test_cols_lower_all_columns() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not string
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='optim&#39;us'>optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='leader'>leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='espionage'>espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='security'>security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.upper", None, "df", string_col)
# Out:
# Creating test_cols_upper() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='LEADER'>LEADER</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='ESPIONAGE'>ESPIONAGE</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='SECURITY'>SECURITY</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.upper", "all_columns", "df", "*")
# Out:
# Creating test_cols_upper_all_columns() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not string
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='OPTIM&#39;US'>OPTIM&#39;US</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='LEADER'>LEADER</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='BUMBL#EBÉÉ⸱⸱'>BUMBL#EBÉÉ⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='ESPIONAGE'>ESPIONAGE</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='IRONHIDE&amp;'>IRONHIDE&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='SECURITY'>SECURITY</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.trim", None, "df", numeric_col)
# Out:
# Creating test_cols_trim() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;R

# %%
t.create(None, "cols.trim", "all_columns", "df", "*")
# Out:
# Creating test_cols_trim_all_columns() test function...
# `japanese name`,`attributes`,`Tiemstamp`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float,string,date,bool
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.3'>4.3</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé'>bumbl#ebéé</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadb

# %%
t.create(None, "cols.reverse", None, "df", string_col)
# Out:
# Creating test_cols_reverse() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='redaeL'>redaeL</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='eganoipsE'>eganoipsE</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='ytiruceS'>ytiruceS</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.reverse", "all_columns", "df", "*")
# Out:
# Creating test_cols_reverse_all_columns() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not string
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='su&#39;mitpO'>su&#39;mitpO</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='redaeL'>redaeL</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='111102.99-,537244.91'>111102.99-,537244.91</div>
#         </td>
#
#         <td>
#             <div title='01/40/0891'>01/40/0891</div>
#         </td>
#
#         <td>
#             <div title='01/90/6102'>01/90/6102</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='⸱⸱éébe#lbmub'>⸱⸱éébe#lbmub</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='eganoipsE'>eganoipsE</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='435216.17-,707246.01'>435216.17-,707246.01</div>
#         </td>
#
#         <td>
#             <div title='01/40/0891'>01/40/0891</div>
#         </td>
#
#         <td>
#             <div title='01/80/5102'>01/80/5102</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='&amp;edihnori'>&amp;edihnori</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='ytiruceS'>ytiruceS</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.remove_accents", None, "df", string_col)
# Out:
# Creating test_cols_remove_accents() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.remove_accents", "all_columns", "df", string_col)
# Out:
# Creating test_cols_remove_accents_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
source_df.table()
# Out:
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""

# %%
t.create(None, "cols.remove_special_chars", None, "df", string_col)
# Out:
# Creating test_cols_remove_special_chars() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""

# %%
t.create(None, "cols.remove_special_chars", "all_columns", "df", "*")
# Out:
# Creating test_cols_remove_special_chars_all_columns() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not str
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optimus'>Optimus</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='1944273599201111'>1944273599201111</div>
#         </td>
#
#         <td>
#             <div class="" title='19800410'>19800410</div>
#         </td>
#
#         <td>
#             <div class="" title='20160910'>20160910</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumblebéé⸱⸱'>bumblebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='1064270771612534'>1064270771612534</div>
#         </td>
#
#         <td>
#             <div class="" title='19800410'>19800410</div>
#         </td>
#
#         <td>
#             <div class="" title='20150810'>20150810</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide'>ironhide</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class="" title='Security'>Security</div>
#         </td>

# %%
t.create(None, "cols.remove_white_spaces", None, "df", string_col)
# Out:
# Creating test_cols_remove_white_spaces() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.remove_white_spaces", "all_columns", "df", "*")
# Out:
# Creating test_cols_remove_white_spaces_all_columns() test function...
# `japanese name`,`attributes`,`Tiemstamp`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float,string,date,bool
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.3'>4.3</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé'>bumbl#ebéé</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadb

# %%
t.create(None, "cols.date_transform", None, "df", date_col, "yyyy/MM/dd", "dd-MM-YYYY")
# Out:
# Creating test_cols_date_transform() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival_data_transform</div>
#             <div class="data_type">17 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='10-04-1980'>10-04-1980</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='10-04-1980'>10-04-1980</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>

# %%
t.create(None, "cols.date_transform", "all_columns", "df", [date_col, date_col_B], "yyyy/MM/dd", "dd-MM-YYYY")
# Out:
# Creating test_cols_date_transform_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 18 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival_data_transform</div>
#             <div class="data_type">17 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen_data_transform</div>
#             <div class="data_type">18 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='10-04-1980'>10-04-1980</div>
#         </td>
#
#         <td>
#             <div title='10-09-2016'>10-09-2016</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='

# %%
t.create(None, "cols.years_between", None, "df", date_col, "yyyyMMdd")
# Out:
# Creating test_cols_years_between() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival_years_between</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>

# %%
t.create(None, "cols.years_between", "multiple_columns", "df", [date_col, date_col_B], "yyyyMMdd")
# Out:
# Creating test_cols_years_between_multiple_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 18 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival_years_between</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen_years_between</div>
#             <div class="data_type">18 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#3

# %%
t.create(None, "cols.impute", None, "df", numeric_col_B)
# Out:
# Creating test_cols_impute() test function...
# 1 values imputed for column(s) 'rank'
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank_imputed</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>

# %%
t.create(None, "cols.impute", "all_columns", "df", "names","categorical")
# Out:
# Creating test_cols_impute_all_columns() test function...
# Including 'nan' as Null in processing 'names'
# 1 values imputed for column(s) 'names' with 'None'
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.hist", None, "json", numeric_col_B, 4)
# Out:
# Creating test_cols_hist() test function...
# [{'count': 2, 'lower': 7.0, 'upper': 7.75}, {'count': 2, 'lower': 7.75, 'upper': 8.5}, {'count': 0, 'lower': 8.5, 'upper': 9.25}, {'count': 2, 'lower': 9.25, 'upper': 10.0}]

# %%
# t.create(None,"cols.hist","all_columns","df","*",4)

# %%
t.create(None, "cols.frequency", None, "json", numeric_col_B, 4)
# Out:
# Creating test_cols_frequency() test function...
# {'rank': [{'value': 10, 'count': 2}, {'value': 8, 'count': 2}, {'value': 7, 'count': 2}, {'value': None, 'count': 1}]}

# %%
t.create(None, "cols.frequency", "all_columns", "json", "*", 4)
# Out:
# Creating test_cols_frequency_all_columns() test function...
# {'names': [{'value': 'ironhide&', 'count': 1}, {'value': 'bumbl#ebéé  ', 'count': 1}, {'value': "Optim'us", 'count': 1}, {'value': 'Metroplex_)^$', 'count': 1}], 'height(ft)': [{'value': None, 'count': 2}, {'value': 300, 'count': 1}, {'value': 26, 'count': 1}, {'value': 17, 'count': 1}], 'function': [{'value': 'Security', 'count': 1}, {'value': 'None', 'count': 1}, {'value': 'Leader', 'count': 1}, {'value': 'First Lieutenant', 'count': 1}], 'rank': [{'value': 10, 'count': 2}, {'value': 8, 'count': 2}, {'value': 7, 'count': 2}, {'value': None, 'count': 1}], 'age': [{'value': 5000000, 'count': 6}, {'value': None, 'count': 1}], 'weight(t)': [{'value': None, 'count': 2}, {'value': 5.699999809265137, 'count': 1}, {'value': 4.300000190734863, 'count': 1}, {'value': 4.0, 'count': 1}], 'japanese name': [{'value': ['Roadbuster'], 'count': 1}, {'value': ['Metroflex'], 'count': 1}, {'value': ['Meister'], 'count': 1}, {'value': ['Megatron'], 'count': 1}], 'last position seen': [{'value': None, 'count': 3}, {'value': '37.789563,-122.400356', 'count': 1}, {'value': '33.670666,-117.841553', 'count': 1}, {'value': '19.442735,-99.201111', 'count': 1}], 'date arrival': [{'value': '1980/04/10', 'count': 6}, {'value': None, 'count': 1}], 'last date seen': [{'value': '2016/09/10', 'count': 1}, {'value': '2015/08/10', 'count': 1}, {'value': '2014/07/10', 'count': 1}, {'value': '2013/06/10', 'count': 1}], 'attributes': [{'value': [91.44000244140625, None], 'count': 1}, {'value': [8.53439998626709, 4300.0], 'count': 1}, {'value': [7.924799919128418, 4000.0], 'count': 1}, {'value': [5.334000110626221, 2000.0], 'count': 1}], 'Date Type': [{'value': datetime.date(2016, 9, 10), 'count': 1}, {'value': datetime.date(2015, 8, 10), 'count': 1}, {'value': datetime.date(2014, 6, 24), 'count': 1}, {'value': datetime.date(2013, 6, 24), 'count': 1}], 'Tiemstamp': [{'value': datetime.datetime(2014, 6, 24, 0, 0), 'count': 6}, {'value': None, 'count': 1}], 'Cybertronian': [{'value': True, 'count': 6}, {'value': None, 'count': 1}], 'function(binary)': [{'value': bytearray(b'Security'), 'count': 1}, {'value': bytearray(b'None'), 'count': 1}, {'value': bytearray(b'Leader'), 'count': 1}, {'value': bytearray(b'First Lieutenant'), 'count': 1}], 'NullType': [{'value': None, 'count': 7}]}

# %%
t.create(None, "cols.schema_dtype", None, "json", numeric_col_B)
# Out:
# Creating test_cols_schema_dtype() test function...
# ByteType

# %%
t.create(None, "cols.schema_dtype", "all_columns", "json", "*")
# Out:
# Creating test_cols_schema_dtype_all_columns() test function...
# [StringType, ShortType, StringType, ByteType, IntegerType, FloatType, ArrayType(StringType,true), StringType, StringType, StringType, ArrayType(FloatType,true), DateType, TimestampType, BooleanType, BinaryType, NullType]

# %%
t.create(None, "cols.dtypes", None, "json", numeric_col_B)
# Out:
# Creating test_cols_dtypes() test function...
# tinyint

# %%
t.create(None, "cols.dtypes", "all_columns", "json", "*")
# Out:
# Creating test_cols_dtypes_all_columns() test function...
# {'names': 'string', 'height(ft)': 'smallint', 'function': 'string', 'rank': 'tinyint', 'age': 'int', 'weight(t)': 'float', 'japanese name': 'array<string>', 'last position seen': 'string', 'date arrival': 'string', 'last date seen': 'string', 'attributes': 'array<float>', 'Date Type': 'date', 'Tiemstamp': 'timestamp', 'Cybertronian': 'boolean', 'function(binary)': 'binary', 'NullType': 'null'}

# %%
t.create(None, "cols.select_by_dtypes", "str", "df", "str")
# Out:
# Creating test_cols_select_by_dtypes_str() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not str
# <div class="info_items">Viewing 7 of 7 rows / 5 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='37.789563,-122.400356'>37.789563,-122.400356</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2014/07/10'>2014/07/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Jazz'>Jazz</div>
#         </td>
#
#         <td>
#             <div title='First⸱Lieutenant'>First⸱Lieutenant</div>
#         </td>
#
#         <td>
#             <div title='33.670666,-117.841553'>33.670666,-117.841553</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2013/06/10'>2013/06/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Megatron'>Megatron</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2012/05/10'>2012/05/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Metroplex_)^$'>Metroplex_)^$</div>
#         </td>
#
#         <td>
#             <div title='Battle⸱Station'>Battle⸱Station</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2011/04/10'>2011/04/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 5 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.select_by_dtypes", "int", "df", "int")
# Out:
# Creating test_cols_select_by_dtypes_int() test function...
# `names`,`height(ft)`,`function`,`rank`,`weight(t)`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not int
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">1 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.select_by_dtypes", "float", "df", "float")
# Out:
# Creating test_cols_select_by_dtypes_float() test function...
# `names`,`height(ft)`,`function`,`rank`,`age`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not float
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">1 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='1.7999999523162842'>1.7999999523162842</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5.699999809265137'>5.699999809265137</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.select_by_dtypes", "array", "df", "array")
# Out:
# Creating test_cols_select_by_dtypes_array() test function...
# `names`,`height(ft)`,`function`,`rank`,`age`,`weight(t)`,`last position seen`,`date arrival`,`last date seen`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not array
# <div class="info_items">Viewing 7 of 7 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">1 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">2 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[7.924799919128418,⸱4000.0]'>[7.924799919128418,⸱4000.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Meister&#39;]'>[&#39;Meister&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[3.962399959564209,⸱1800.0]'>[3.962399959564209,⸱1800.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Megatron&#39;]'>[&#39;Megatron&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[None,⸱5700.0]'>[None,⸱5700.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Metroflex&#39;]'>[&#39;Metroflex&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[91.44000244140625,⸱None]'>[91.44000244140625,⸱None]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.names", None, "json")
# Out:
# Creating test_cols_names() test function...
# ['names', 'height(ft)', 'function', 'rank', 'age', 'weight(t)', 'japanese name', 'last position seen', 'date arrival', 'last date seen', 'attributes', 'Date Type', 'Tiemstamp', 'Cybertronian', 'function(binary)', 'NullType']

# %%
t.create(None, "cols.qcut", None, "df", numeric_col_B, 4)
# Out:
# Creating test_cols_qcut() test function...
# <div class="info_items">Viewing 6 of 6 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank_qcut</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='3.0'>3.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1.0'>1.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>

# %%
t.create(None, "cols.qcut", "all_columns", "df", "*", 4)
# Out:
# Creating test_cols_qcut_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 4 of 4 rows / 20 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)_qcut</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank_qcut</div>
#             <div class="data_type">18 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age_qcut</div>
#             <div class="data_type">19 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)_qcut</div>
#             <div class="data_type">20 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='0.0'>0.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='1.0'>1.0</div>
#         </td>
#
#         <td>
#             <div title='3.0'>3.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>

# %%
t.create(None, "cols.clip", None, "df", numeric_col_B, 3, 5)
# Out:
# Creating test_cols_clip() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadb

# %%
t.create(None, "cols.clip", "all_columns", "df", "*", 3, 5)
# Out:
# Creating test_cols_clip_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='3'>3</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='3.0'>3.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>

# %%
t.create(None, "cols.replace", None, "df", string_col, ["Security", "Leader"], "Match")
# Out:
# Creating test_cols_replace() test function...
# function
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Match'>Match</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Match'>Match</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbus

# %%
import re
_value = None
attr ={'Jazz': 'Match', 'Leader': 'Match'}
_regex = re.compile("|".join(map(re.escape, attr.keys())))
result = _regex.sub(lambda match: attr[match.group(0)], str(_value))
print(result)
# Out:
# None

# %%
t.create(None, "cols.replace", "all_columns", "df", "*", ["Jazz", "Leader"], "Match")
source_df.table()
# Out:
# Creating test_cols_replace_all_columns() test function...
# `japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not str,byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Match'>Match</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
# Its necesary to save the function 
t.delete(None, "cols.apply_expr", None, "df", numeric_col_B, func)
# Out:
# Deleting file df_cols//cols_apply_expr.test...
# File NOT found

# %%
# Its necesary to save the function 
t.delete(None, "cols.apply_expr", "all_columns", "df", [numeric_col_B,numeric_col_C], func)
# Out:
# Deleting file df_cols//cols_apply_expr_all_columns.test...
# File NOT found

# %%
t.create(None, "cols.append", "number", "df", new_col, 1)
# Out:
# Creating test_cols_append_number() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">new col</div>
#             <div class="data_type">17 (int)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>

# %%
#t.create(None, "cols.append", "advance", "df", [("new_col_4", "test"),
    #                                                ("new_col_5", df[numeric_col_B] * 2),
    #                                                ("new_col_6", [1, 2, 3])
    #                                                ]),

# %%
t.create(None, "cols.rename", None, "df", numeric_col_B, numeric_col_B + "(old)")
# Out:
# Creating test_cols_rename() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank(old)</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='

# %%
t.create(None, "cols.rename", "list", "df", [numeric_col, numeric_col + "(tons)", numeric_col_B, numeric_col_B + "(old)"])
# Out:
# Creating test_cols_rename_list() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.rename", "function", "df", str.upper)
# Out:
# Creating test_cols_rename_function() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">NAMES</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">HEIGHT(FT)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">FUNCTION</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">RANK</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">AGE</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">WEIGHT(T)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">JAPANESE NAME</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">LAST POSITION SEEN</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">DATE ARRIVAL</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">LAST DATE SEEN</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ATTRIBUTES</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">DATE TYPE</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">TIEMSTAMP</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">CYBERTRONIAN</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">FUNCTION(BINARY)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NULLTYPE</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.drop", None, "df", numeric_col_B)
# Out:
# Creating test_cols_drop() test function...
# <div class="info_items">Viewing 7 of 7 rows / 15 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">10 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">11 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">12 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">13 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">14 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">15 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>
#
#         <td>
#             <div title='37.789563,-122.400356'>37.789563,-122.400356</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2014/07/10'>2014/07/10</div>
#         </td>
#
#         <td>
#             <div title='[7.924799919128418,⸱4000.0]'>[7.924799919128418,⸱4000.0]</div>

# %%
t.create(None, "cols.cast", None, "df", string_col, "string")
# Out:
# Creating test_cols_cast() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.cast", "all_columns", "df", "*", "string")
# Out:
# Creating test_cols_cast_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.3'>4.3</div>
#         </td>
#
#         <td>
#             <div title='[Inochi,⸱Convoy]'>[Inochi,⸱Convoy]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.5344,⸱4300.0]'>[8.5344,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[Bumble,⸱Goldback]'>[Bumble,⸱Goldback]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334,⸱2000.0]'>[5.334,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[Roadbuster]'>[Roadbuster]</div>
#         </td>
#
#         <td>
#             <div title='37.789563,-122.400356'>37.789563,-122.400356</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>

# %%
# Problems with precision
t.delete(None, "cols.cast", "vector", "df", array_col, Vectors)
# Out:
# Deleting file df_cols//cols_cast_vector.test...

# %%
t.create(None, "cols.keep", None, "df", numeric_col_B)
# Out:
# Creating test_cols_keep() test function...
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">1 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='8'>8</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='8'>8</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.move", "after", "df", numeric_col_B, "after", array_col)
# Out:
# Creating test_cols_move_after() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">10 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">11 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>

# %%
t.create(None, "cols.move", "before", "df", numeric_col_B, "before", array_col)
# Out:
# Creating test_cols_move_before() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">10 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>

# %%
t.create(None, "cols.move", "beginning", "df", numeric_col_B, "beginning")
# Out:
# Creating test_cols_move_beginning() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">1 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">3 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.move", "end", "df", numeric_col_B, "end")
# Out:
# Creating test_cols_move_end() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">10 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">11 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">12 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">13 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">14 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">15 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">16 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>

# %%
t.create(None, "cols.select", None, "df", 0, numeric_col)
# Out:
# Creating test_cols_select() test function...
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Jazz'>Jazz</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Megatron'>Megatron</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Metroplex_)^$'>Metroplex_)^$</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.select", "regex", "df", "n.*", regex=True),
# Out:
# Creating test_cols_select_regex() test function...
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Jazz'>Jazz</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Megatron'>Megatron</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Metroplex_)^$'>Metroplex_)^$</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
# (None,)

# %%
t.create(None, "cols.sort", None, "df")
# Out:
# Creating test_cols_sort() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">1 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">2 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">3 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">4 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">6 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">9 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">10 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">11 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">15 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">16 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24'>2014-06-24</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='[7.924799919128418,⸱4000.0]'>[7.924799919128418,⸱4000.

# %%
t.create(None, "cols.sort", "desc", "df", "desc")
# Out:
# Creating test_cols_sort_desc() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">1 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">2 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">7 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">8 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">12 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">14 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">15 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">16 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='37.789563,-122.400356'>37.789563,-122.400356</div>
#         </td>
#
#         <td>
#             <div title='2014/07/10'>2014/07/10</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]

# %%
t.create(None, "cols.sort", "asc", "df", "asc")
# Out:
# Creating test_cols_sort_asc() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">1 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">2 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">3 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">4 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">6 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">9 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">10 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">11 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">15 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">16 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24'>2014-06-24</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='[7.924799919128418,⸱4000.0]'>[7.924799919128418,⸱4000.

# %%
t.create(None, "cols.fill_na", None, "df", numeric_col, "1")
# Out:
# Creating test_cols_fill_na() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26.0'>26.0</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div ti

# %%
t.create(None, "cols.fill_na", "array", "df", "japanese name", ["1","2"])
# Out:
# Creating test_cols_fill_na_array() test function...
# japanese name
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.fill_na", "bool", "df", "Cybertronian", False)
# Out:
# Creating test_cols_fill_na_bool() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.fill_na", "all_columns", "df", ["names","height(ft)", "function", "rank", "age"], "2")
# Out:
# Creating test_cols_fill_na_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26.0'>26.0</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>

# %%
t.create(None, "cols.nest", None, "df", [numeric_col, numeric_col_B], new_col, separator=" ")
# Out:
# Creating test_cols_nest() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">new col</div>
#             <div class="data_type">17 (string)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-28⸱10'>-28⸱10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='17⸱7'>17⸱7</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         <

# %%
# t.create(None, "cols.nest", "mix", "df", [F.col(numeric_col_C), F.col(numeric_col_B)], "E", separator="--")

# %%
df_na = source_df.cols.drop("NullType").rows.drop_na("*")

t.create(df_na, "cols.nest", "vector_all_columns", "df", [numeric_col_C, numeric_col_B], new_col, shape="vector")
# Out:
# Creating test_cols_nest_vector_all_columns() test function...
# <div class="info_items">Viewing 4 of 4 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">new col</div>
#             <div class="data_type">16 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='[10.0]'>[10.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='[7.0]'>[7.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title

# %%
t.create(df_na, "cols.nest", "vector", "df", [numeric_col_C, numeric_col_B], new_col, shape="vector")
# Out:
# Creating test_cols_nest_vector() test function...
# <div class="info_items">Viewing 4 of 4 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">new col</div>
#             <div class="data_type">16 (vector)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='[10.0]'>[10.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='[7.0]'>[7.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title

# %%
t.create(None, "cols.nest", "array_all_columns", "df", "*", new_col, shape="array")
# Out:
# Creating test_cols_nest_array_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">new col</div>
#             <div class="data_type">17 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.3'>4.3</div>
#         </td>
#
#         <td>
#             <div title='[Inochi,⸱Convoy]'>[Inochi,⸱Convoy]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.5344,⸱4300.0]'>[8.5344,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='[&#34;Optim&#39;us&#34;,⸱&#39;-28&#39;,⸱&#39;Leader&#39;,⸱&#39;10&#39;,⸱&#39;5000000&#39;,⸱&#39;4.3&#39;,⸱&#39;[Inochi,⸱Convoy]&#39;,⸱&#39;19.442735,-99.201111&#39;,⸱&#39;1980/04/10&#39;,⸱&#39;2016/09/10&#39;,⸱&#39;[8.5344,⸱4300.0]&#39;,⸱&#39;2016-09-10&#39;,⸱&#39;2014-06-24⸱00:00:00&#39;,⸱&#39;true&#39;,⸱&#39;Leader&#39;,⸱None]'>[&#34;Optim&#39;us&#34;,⸱&#39;-28&#39;,⸱&#39;Leader&#39;,⸱&#39;10&#39;,⸱&#39;5000000&#39;,⸱&#39;4.3&#39;,⸱&#39;[Inochi,⸱Convoy]&#39;,⸱&#39;19.442735,-99.201111&#39;,⸱&#39;1980/04/10&#39;,⸱&#39;2016/09/10&#39;,...</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[Bumble,⸱Goldback]'>[Bumble,⸱Goldback]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334,⸱2000.0]'>[5.334,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>

# %%
t.create(None, "cols.nest", "array", "df", [numeric_col, numeric_col_B,numeric_col_C], new_col, shape="array")
# Out:
# Creating test_cols_nest_array() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">new col</div>
#             <div class="data_type">17 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.3'>4.3</div>
#         </td>
#
#         <td>
#             <div title='[Inochi,⸱Convoy]'>[Inochi,⸱Convoy]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.5344,⸱4300.0]'>[8.5344,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='[&#39;-28&#39;,⸱&#39;10&#39;,⸱&#39;10&#39;]'>[&#39;-28&#39;,⸱&#39;10&#39;,⸱&#39;10&#39;]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[Bumble,⸱Goldback]'>[Bumble,⸱Goldback]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334,⸱2000.0]'>[5.334,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='[&#39;17&#39;,⸱&#39;7&#39;,⸱&#39;7&#39;]'>[&#39;17&#39;,⸱&#39;7&#39;,⸱&#39;7&#39;]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>

# %%
t.create(None, "cols.unnest", "array_all_columns", "df", array_col, "-", index=1)
# Out:
# Creating test_cols_unnest_array_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 18 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_0</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_1</div>
#             <div class="data_type">18 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='8.53439998626709'>8.53439998626709</div>
#         </td>
#
#         <td>
#             <div title='4300.0'>4300.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;

# %%
t.create(None, "cols.unnest", "array", "df", array_col)
# Out:
# Creating test_cols_unnest_array() test function...
# <div class="info_items">Viewing 7 of 7 rows / 18 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_0</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_1</div>
#             <div class="data_type">18 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='8.53439998626709'>8.53439998626709</div>
#         </td>
#
#         <td>
#             <div title='4300.0'>4300.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;

# %%
t.create(None, "cols.unnest", "array_all_columns", "df", array_col)
# Out:
# Creating test_cols_unnest_array_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 18 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_0</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_1</div>
#             <div class="data_type">18 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='8.53439998626709'>8.53439998626709</div>
#         </td>
#
#         <td>
#             <div title='4300.0'>4300.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;

# %%
t.create(None, "cols.is_na", "all_columns", "df", "*")
# Out:
# Creating test_cols_is_na_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='Fal

# %%
t.create(None, "cols.is_na", None, "df", numeric_col)
# Out:
# Creating test_cols_is_na() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Ro

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
from pyspark.sql.types import *
from optimus import Optimus
from optimus.helpers.functions import json_enconding 
from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector
import numpy as np
nan = np.nan
import datetime

# %%
actual_df =source_df.cols.remove_special_chars('function')
expected_df = op.create.df([('names', StringType(), True),('height(ft)', ShortType(), True),('function', StringType(), True),('rank', ByteType(), True),('age', IntegerType(), True),('weight(t)', FloatType(), True),('japanese name', ArrayType(StringType(),True), True),('last position seen', StringType(), True),('date arrival', StringType(), True),('last date seen', StringType(), True),('attributes', ArrayType(FloatType(),True), True),('Date Type', DateType(), True),('Tiemstamp', TimestampType(), True),('Cybertronian', BooleanType(), True),('function(binary)', BinaryType(), True),('NullType', NullType(), True)], [("Optim'us", -28, 'Leader', 10, 5000000, 4.300000190734863, ['Inochi', 'Convoy'], '19.442735,-99.201111', '1980/04/10', '2016/09/10', [8.53439998626709, 4300.0], datetime.date(2016, 9, 10), datetime.datetime(2014, 6, 24, 0, 0), True, bytearray(b'Leader'), None), ('bumbl#ebéé  ', 17, 'Espionage', 7, 5000000, 2.0, ['Bumble', 'Goldback'], '10.642707,-71.612534', '1980/04/10', '2015/08/10', [5.334000110626221, 2000.0], datetime.date(2015, 8, 10), datetime.datetime(2014, 6, 24, 0, 0), True, bytearray(b'Espionage'), None), ('ironhide&', 26, 'Security', 7, 5000000, 4.0, ['Roadbuster'], '37.789563,-122.400356', '1980/04/10', '2014/07/10', [7.924799919128418, 4000.0], datetime.date(2014, 6, 24), datetime.datetime(2014, 6, 24, 0, 0), True, bytearray(b'Security'), None), ('Jazz', 13, 'First Lieutenant', 8, 5000000, 1.7999999523162842, ['Meister'], '33.670666,-117.841553', '1980/04/10', '2013/06/10', [3.962399959564209, 1800.0], datetime.date(2013, 6, 24), datetime.datetime(2014, 6, 24, 0, 0), True, bytearray(b'First Lieutenant'), None), ('Megatron', None, 'None', 10, 5000000, 5.699999809265137, ['Megatron'], None, '1980/04/10', '2012/05/10', [None, 5700.0], datetime.date(2012, 5, 10), datetime.datetime(2014, 6, 24, 0, 0), True, bytearray(b'None'), None), ('Metroplex_)^$', 300, 'Battle Station', 8, 5000000, None, ['Metroflex'], None, '1980/04/10', '2011/04/10', [91.44000244140625, None], datetime.date(2011, 4, 10), datetime.datetime(2014, 6, 24, 0, 0), True, bytearray(b'Battle Station'), None), (None, None, 'None', None, None, None, None, None, None, None, None, None, None, None, None, None)])

# assert (expected_df.collect() == actual_df.collect())

from deepdiff import DeepDiff  # For Deep Difference of 2 objects

# source_df.table()
# print(actual_df.to_json())
# print(expected_df.to_json())
a1 = actual_df.to_json()
e1 = expected_df.to_json()

# %%
actual_df.table()
expected_df.table()
# Out:
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""

# %%
ddiff = DeepDiff(a1, e1, ignore_order=False)
print(ddiff)
# Out:
# {}

# %% [markdown]
# # Rows Test

# %%
t = Test(op,df, "df_rows", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                         "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F",
                                        "from optimus.functions import abstract_udf as audf"])

# %%
rows = [
        ("Optim'us", 28, "Leader", 10, 5000000, 4.30, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
         "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True, bytearray("Leader", "utf-8"),
         None)
]

# %%
df = op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.csv")

# %%
t = Test(op, df, "op_io", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                        "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F"])

# %%
t.run(
    
    t.create(op, "load.csv", None, "df", "../examples/data/foo.csv"),
    t.create(op, "load.json", None, "df", "../examples/data/foo.json"),
    t.create(op, "load.parquet", None, "df", "../examples/data/foo.parquet"),

    t.create(op, "load.url", "csv", "df", "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.csv"),
    t.create(op, "load.url", "json", "df", "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.json","json"),
    t.create(op, "load.url", "parquet", "df", "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.parquet","parquet"),
    
     t.create(None, "save.csv", None, None, "test.csv"),
     t.create(None, "save.json", None, None, "test.json"),
     t.create(None, "save.parquet", None, None, "test.parquet"),
    
     
    
)
# Out:
# Creating test_load_csv() test function...
# Creating test_load_json() test function...
# Creating test_load_parquet() test function...
# Creating test_load_url_csv() test function...
# Creating test_load_url_json() test function...
# Creating test_load_url_parquet() test function...
# Creating test_save_csv() test function...
# Creating test_save_json() test function...
# Creating test_save_parquet() test function...
# Creating file test_op_io.py
# Done
