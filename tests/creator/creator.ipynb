# %% [markdown]
# # This notebook create the tests in python code. All this cells must be run to executed the tests

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../..")

# %%
from optimus import Optimus
from optimus.helpers.test import Test
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\socks.py:58: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Callable
#
#     You are using PySparkling of version 2.4.10, but your PySpark is of
#     version 2.3.1. Please make sure Spark and PySparkling versions are compatible.
# `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly

# %%
op = Optimus(master='local', verbose=True)
# Out:
# INFO:optimus:Operative System:Windows
# INFO:optimus:Just check that Spark and all necessary environments vars are present...
# INFO:optimus:-----
# INFO:optimus:SPARK_HOME=C:\opt\spark\spark-2.3.1-bin-hadoop2.7
# INFO:optimus:HADOOP_HOME=C:\opt\hadoop-2.7.7
# INFO:optimus:PYSPARK_PYTHON=C:\Users\argenisleon\Anaconda3\python.exe
# INFO:optimus:PYSPARK_DRIVER_PYTHON=jupyter
# INFO:optimus:PYSPARK_SUBMIT_ARGS=--jars "file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/RedshiftJDBC42-1.2.16.1027.jar,file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/mysql-connector-java-8.0.16.jar,file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/ojdbc8.jar,file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/postgresql-42.2.5.jar,file:///C:/Users/argenisleon/Documents/Optimus/optimus/jars/presto-jdbc-0.224.jar" --driver-class-path "C:/Users/argenisleon/Documents/Optimus/optimus/jars/RedshiftJDBC42-1.2.16.1027.jar;C:/Users/argenisleon/Documents/Optimus/optimus/jars/mysql-connector-java-8.0.16.jar;C:/Users/argenisleon/Documents/Optimus/optimus/jars/ojdbc8.jar;C:/Users/argenisleon/Documents/Optimus/optimus/jars/postgresql-42.2.5.jar;C:/Users/argenisleon/Documents/Optimus/optimus/jars/presto-jdbc-0.224.jar" --conf "spark.sql.catalogImplementation=hive" pyspark-shell
# INFO:optimus:JAVA_HOME=C:\java
# INFO:optimus:Pyarrow Installed
# INFO:optimus:-----
# INFO:optimus:Starting or getting SparkSession and SparkContext...
# INFO:optimus:Spark Version:2.3.1
# INFO:optimus:
#                              ____        __  _
#                             / __ \____  / /_(_)___ ___  __  _______
#                            / / / / __ \/ __/ / __ `__ \/ / / / ___/
#                           / /_/ / /_/ / /_/ / / / / / / /_/ (__  )
#                           \____/ .___/\__/_/_/ /_/ /_/\__,_/____/
#                               /_/
#
# INFO:optimus:Transform and Roll out...
# INFO:optimus:Optimus successfully imported. Have fun :).
# INFO:optimus:Config.ini not found

# %%
import pandas as pd
from pyspark.sql.types import *
from datetime import date, datetime


cols = [
        ("names", "str"),
        ("height(ft)", ShortType()),
        ("function", "str"),
        ("rank", ByteType()),
        ("age", "int"),
        ("weight(t)", "float"),
        "japanese name",
        "last position seen",
        "date arrival",
        "last date seen",
        ("attributes", ArrayType(FloatType())),
        ("Date Type", DateType()),
        ("timestamp", TimestampType()),
        ("Cybertronian", BooleanType()),
        ("function(binary)", BinaryType()),
        ("NullType", NullType())

    ]

rows = [
        ("Optim'us", -28, "Leader", 10, 5000000, 4.30, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
         "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True, bytearray("Leader", "utf-8"),
         None),
        ("bumbl#ebéé  ", 17, "Espionage", 7, 5000000, 2.0, ["Bumble", "Goldback"], "10.642707,-71.612534", "1980/04/10",
         "2015/08/10", [5.334, 2000.0], date(2015, 8, 10), datetime(2014, 6, 24), True, bytearray("Espionage", "utf-8"),
         None),
        ("ironhide&", 26, "Security", 7, 5000000, 4.0, ["Roadbuster"], "37.789563,-122.400356", "1980/04/10",
         "2014/07/10", [7.9248, 4000.0], date(2014, 6, 24), datetime(2014, 6, 24), True, bytearray("Security", "utf-8"),
         None),
        ("Jazz", 13, "First Lieutenant", 8, 5000000, 1.80, ["Meister"], "33.670666,-117.841553", "1980/04/10",
         "2013/06/10", [3.9624, 1800.0], date(2013, 6, 24), datetime(2014, 6, 24), True,
         bytearray("First Lieutenant", "utf-8"), None),
        ("Megatron", None, "None", 10, 5000000, 5.70, ["Megatron"], None, "1980/04/10", "2012/05/10", [None, 5700.0],
         date(2012, 5, 10), datetime(2014, 6, 24), True, bytearray("None", "utf-8"), None),
        ("Metroplex_)^$", 300, "Battle Station", 8, 5000000, None, ["Metroflex"], None, "1980/04/10", "2011/04/10",
         [91.44, None], date(2011, 4, 10), datetime(2014, 6, 24), True, bytearray("Battle Station", "utf-8"), None),
        (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),

    ]
source_df = op.create.df(cols ,rows)
source_df.table()
# Out:
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28">
#
#                 -28
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10">
#
#                 10
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000">
#
#                 5000000
#
#             </

# %% [markdown]
# ### End Init Section

# %% [markdown]
# # Test

# %% [markdown]
# ## Optimus Test

# %%
from pyspark.ml.linalg import Vectors

# %%
t = Test(op, None, "create_df", imports=["import datetime",
                                "from pyspark.sql import functions as F"], path = "..", final_path="..")

# %%
one_column = {"rows":["Argenis", "Favio", "Matthew"], "cols":["name"]}
plain = {"rows":[("BOB", 1),("JoSe", 2)],"cols":["name","age"]}
plain_infer_false = {"rows":[("BOB", 1),("JoSe", 2)],"cols":["name","age"],"infer_schema":False}
with_data_types = {"rows":[("BOB", 1),("JoSe", 2)],"cols":[("name", StringType(), True),("age", IntegerType(), False)]}
nullable = {"rows":[("BOB", 1),("JoSe", 2)],"cols":[("name", StringType()),("age", IntegerType())]}

df1 = op.create.df(**one_column)
df2 = op.create.df(**plain)
df3 = op.create.df(**plain_infer_false)
df4 = op.create.df(**with_data_types)
df5 = op.create.df(**nullable)

# %%
t.create(df1, None, "one_column", "df", **one_column)

# %%
t.create(df2, None, "plain", "df", **plain)
# Out:
# Creating test_create_df_plain() test function...
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='BOB'>BOB</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='JoSe'>JoSe</div>
#         </td>
#
#         <td>
#             <div title='2'>2</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(df3, None, "plain_infer_false", "df", **plain_infer_false)
# Out:
# Creating test_create_df_plain_infer_false() test function...
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='BOB'>BOB</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='JoSe'>JoSe</div>
#         </td>
#
#         <td>
#             <div title='2'>2</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(df4, None, "with_data_types", "df", **with_data_types)
# Out:
# Creating test_create_df_with_data_types() test function...
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='BOB'>BOB</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='JoSe'>JoSe</div>
#         </td>
#
#         <td>
#             <div title='2'>2</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(df5, None, "nullable", "df", **nullable)
# Out:
# Creating test_create_df_nullable() test function...
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='BOB'>BOB</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='JoSe'>JoSe</div>
#         </td>
#
#         <td>
#             <div title='2'>2</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.run()
# Out:
# Creating file create_df/test_Optimus.py
# Done

# %% [markdown]
# ## Columns Test

# %%
from pyspark.ml.linalg import Vectors

# %%
t = Test(op, source_df, "df_cols", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                        "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F"], path = "df_cols", final_path="..")

# %%
from pyspark.sql import functions as F


def func(col_name, attrs):
    return F.col(col_name) * 2

numeric_col = "height(ft)"
numeric_col_B = "rank"
numeric_col_C = "rank"
string_col = "function"
date_col = "date arrival"
date_col_B = "last date seen"
new_col = "new col"
array_col = "attributes"

# %%
t.create(None, "cols.remove", None, "df", None, string_col, "i")
# Out:
# Creating test_cols_remove() test function...
# INFO:optimus:test_cols_remove()
# INFO:optimus:Using 'pandas_udf' to process column 'function' with function multiple_replace
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28">
#
#                 -28
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10">
#
#                 10
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000">
#
#                 5000000
#
#             </
# export.......................

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# export.......................
# Done

# %%
t.create(None, "cols.remove", "list", "df", string_col, ["a","i","Es"])
# Out:
# Creating test_cols_remove_list() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim'us'>Optim'us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-28'>-28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leder'>Leder
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Inochi',&#8901;'Convoy']'>['Inochi',&#8901;'Convoy']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,&#8901;4300.0]'>[8.53439998626709,&#8901;4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b'Leader')'>bytearray(b'Leader')
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé&#8901;&#8901;'>bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='ponge'>ponge
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Bumble',&#8901;'Goldback']'>['Bumble',&#8901;'Goldback']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334000110626221,&#8901;2000.0]'>[5.334000110626221,&#8901;2000.0]

# %%
t.create(None, "cols.remove", "list_output", "df", string_col, ["a","i","Es"], output_cols=string_col+"_new")
# Out:
# Creating test_cols_remove_list_output() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function_new</div>
#             <div class="data_type">17 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim'us'>Optim'us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-28'>-28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Inochi',&#8901;'Convoy']'>['Inochi',&#8901;'Convoy']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,&#8901;4300.0]'>[8.53439998626709,&#8901;4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b'Leader')'>bytearray(b'Leader')
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leder'>Leder
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé&#8901;&#8901;'>bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Bumble',&#8901;'Goldback']'>['Bumble',&#8901;'Goldback']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.min", None, "json", numeric_col)
# Out:
# Creating test_cols_min() test function...
# -28

# %%
t.create(None, "cols.min", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_min_all_columns() test function...
# INFO:optimus:test_cols_min_all_columns()
# names <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# function <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# rank <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# age <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# weight(t) <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# japanese name <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# last position seen <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# date arrival <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# last date seen <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# attributes <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# Date Type <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# Tiemstamp <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# Cybertronian <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# function(binary) <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# NullType <function _create_function.<locals>._ at 0x000001E3FF7F49D8>
# <function _create_function.<locals>._ at 0x000001E3FF7F49D8>->../..\optimus\dataframe\columns.py:512
# Column<b'min(names) AS `min_names`'> Column<b'min(height(ft)) AS `min_height(ft)`'> Column<b'min(function) AS `min_function`'> Column<b'min(rank) AS `min_rank`'> Column<b'min(age) AS `min_age`'> Column<b'min(weight(t)) AS `min_weight(t)`'> Column<b'min(japanese name) AS `min_japanese name`'> Column<b'min(last position seen) AS `min_last position seen`'> Column<b'min(date arrival) AS `min_date arrival`'> Column<b'min(last date seen) AS `min_last date seen`'> Column<b'min(attributes) AS `min_attributes`'> Column<b'min(Date Type) AS `min_Date Type`'> Column<b'min(Tiemstamp) AS `min_Tiemstamp`'> Column<b'min(Cybertronian) AS `min_Cybertronian`'> Column<b'min(function(binary)) AS `min_function(binary)`'> Column<b'min(NullType) AS `min_NullType`'>
# {'names': 'Jazz', 'height(ft)': -28, 'function': 'Battle Station', 'rank': 7, 'age': 5000000, 'weight(t)': 1.8, 'japanese name': ['Bumble', 'Goldback'], 'last position seen': '10.642707,-71.612534', 'date arrival': '1980/04/10', 'last date seen': '2011/04/10', 'attributes': [None, 5700.0], 'Date Type': '2011-04-10', 'Tiemstamp': '2014-06-24 00:00:00', 'Cybertronian': 1, 'function(binary)': None, 'NullType': None}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.max", None, "json", numeric_col)
# Out:
# Creating test_cols_max() test function...
# 300

# %%
t.create(None, "cols.max", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_max_all_columns() test function...
# INFO:optimus:test_cols_max_all_columns()
# names <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# function <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# rank <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# age <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# weight(t) <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# japanese name <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# last position seen <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# date arrival <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# last date seen <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# attributes <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# Date Type <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# Tiemstamp <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# Cybertronian <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# function(binary) <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# NullType <function _create_function.<locals>._ at 0x000001E3FF7F4950>
# <function _create_function.<locals>._ at 0x000001E3FF7F4950>->../..\optimus\dataframe\columns.py:512
# Column<b'max(names) AS `max_names`'> Column<b'max(height(ft)) AS `max_height(ft)`'> Column<b'max(function) AS `max_function`'> Column<b'max(rank) AS `max_rank`'> Column<b'max(age) AS `max_age`'> Column<b'max(weight(t)) AS `max_weight(t)`'> Column<b'max(japanese name) AS `max_japanese name`'> Column<b'max(last position seen) AS `max_last position seen`'> Column<b'max(date arrival) AS `max_date arrival`'> Column<b'max(last date seen) AS `max_last date seen`'> Column<b'max(attributes) AS `max_attributes`'> Column<b'max(Date Type) AS `max_Date Type`'> Column<b'max(Tiemstamp) AS `max_Tiemstamp`'> Column<b'max(Cybertronian) AS `max_Cybertronian`'> Column<b'max(function(binary)) AS `max_function(binary)`'> Column<b'max(NullType) AS `max_NullType`'>
# {'names': 'ironhide&', 'height(ft)': 300, 'function': 'Security', 'rank': 10, 'age': 5000000, 'weight(t)': 5.7, 'japanese name': ['Roadbuster'], 'last position seen': '37.789563,-122.400356', 'date arrival': '1980/04/10', 'last date seen': '2016/09/10', 'attributes': [91.44000244140625, None], 'Date Type': '2016-09-10', 'Tiemstamp': '2014-06-24 00:00:00', 'Cybertronian': 1, 'function(binary)': None, 'NullType': None}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.range", None, "json",None, numeric_col)
# Out:
# Creating test_cols_range() test function...
# INFO:optimus:test_cols_range()
# {'height(ft)': {'range': {'max': 300, 'min': -28}}}

# %%
t.create(None, "cols.range", "all_columns", "json",None, "*")
# Out:
# Creating test_cols_range_all_columns() test function...
# INFO:optimus:test_cols_range_all_columns()
# {'names': {'range': {'max': 'ironhide&', 'min': 'Jazz'}}, 'height(ft)': {'range': {'max': 300, 'min': -28}}, 'function': {'range': {'max': 'Security', 'min': 'Battle Station'}}, 'rank': {'range': {'max': 10, 'min': 7}}, 'age': {'range': {'max': 5000000, 'min': 5000000}}, 'weight(t)': {'range': {'max': 5.699999809265137, 'min': 1.7999999523162842}}, 'japanese name': {'range': {'max': ['Roadbuster'], 'min': ['Bumble', 'Goldback']}}, 'last position seen': {'range': {'max': '37.789563,-122.400356', 'min': '10.642707,-71.612534'}}, 'date arrival': {'range': {'max': '1980/04/10', 'min': '1980/04/10'}}, 'last date seen': {'range': {'max': '2016/09/10', 'min': '2011/04/10'}}, 'attributes': {'range': {'max': [91.44000244140625, None], 'min': [None, 5700.0]}}, 'Date Type': {'range': {'max': '2016-09-10', 'min': '2011-04-10'}}, 'timestamp': {'range': {'max': '2014-06-24 00:00:00', 'min': '2014-06-24 00:00:00'}}, 'Cybertronian': {'range': {'max': True, 'min': True}}, 'function(binary)': {'range': {'max': None, 'min': None}}, 'NullType': {'range': {'max': None, 'min': None}}}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
source_df.table()
# Out:
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
t.create(None, "cols.median", None, "json", None,numeric_col)
# Out:
# Creating test_cols_median() test function...
# INFO:optimus:test_cols_median()
# 17

# %%
t.create(None, "cols.median", "all_columns", "json", None, "*")
# Out:
# Creating test_cols_median_all_columns() test function...
# INFO:optimus:test_cols_median_all_columns()
# {'height(ft)': 17, 'rank': 8, 'age': 5000000, 'weight(t)': 4.0}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.percentile", None, "json", None, numeric_col, [0.05, 0.25], 1)
# Out:
# Creating test_cols_percentile() test function...
# INFO:optimus:test_cols_percentile()
# INFO:optimus:percentile() executed in 1.6 sec
# {'height(ft)': {'percentile': {'0.05': -28, '0.25': -28}}}

# %%
t.create(None, "cols.percentile", "all_columns", "json", None, "*", [0.05, 0.25], 1)
# Out:
# Creating test_cols_percentile_all_columns() test function...
# INFO:optimus:test_cols_percentile_all_columns()
# INFO:optimus:percentile() executed in 1.72 sec
# {'height(ft)': {'percentile': {'0.05': -28, '0.25': -28}}, 'rank': {'percentile': {'0.05': 7, '0.25': 7}}, 'age': {'percentile': {'0.05': 5000000, '0.25': 5000000}}, 'weight(t)': {'percentile': {'0.05': 1.7999999523162842, '0.25': 1.7999999523162842}}}

# %% [markdown]
# ## MAD

# %%
t.create(None, "cols.mad", None, "json", None, numeric_col)
# Out:
# Creating test_cols_mad() test function...
# INFO:optimus:test_cols_mad()
# 9

# %%
t.create(None, "cols.mad", "all_columns", "json", None, "*")
# Out:
# Creating test_cols_mad_all_columns() test function...
# INFO:optimus:test_cols_mad_all_columns()
# INFO:optimus:`names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`timestamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# {'height(ft)': 9, 'rank': 1, 'age': 0, 'weight(t)': 1.6999998092651367}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.std", None, "json", numeric_col)
# Out:
# Creating test_cols_std() test function...
# 132.66612

# %%
t.create(None, "cols.std", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_std_all_columns() test function...
# INFO:optimus:test_cols_std_all_columns()
# INFO:optimus:`names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF80E048>
# <function _create_function.<locals>._ at 0x000001E3FF80E048>->../..\optimus\dataframe\columns.py:512
# rank <function _create_function.<locals>._ at 0x000001E3FF80E048>
# <function _create_function.<locals>._ at 0x000001E3FF80E048>->../..\optimus\dataframe\columns.py:512
# age <function _create_function.<locals>._ at 0x000001E3FF80E048>
# <function _create_function.<locals>._ at 0x000001E3FF80E048>->../..\optimus\dataframe\columns.py:512
# weight(t) <function _create_function.<locals>._ at 0x000001E3FF80E048>
# <function _create_function.<locals>._ at 0x000001E3FF80E048>->../..\optimus\dataframe\columns.py:512
# Column<b'stddev_samp(height(ft)) AS `stddev_height(ft)`'> Column<b'stddev_samp(rank) AS `stddev_rank`'> Column<b'stddev_samp(age) AS `stddev_age`'> Column<b'stddev_samp(weight(t)) AS `stddev_weight(t)`'>
# {'height(ft)': 132.66612, 'rank': 1.36626, 'age': 0.0, 'weight(t)': 1.64712}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.kurt", None, "json", None, numeric_col)
t.run()
# Out:
# Creating test_cols_kurt() test function...
# INFO:optimus:test_cols_kurt()
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF80E400>
# <function _create_function.<locals>._ at 0x000001E3FF80E400>->../..\optimus\dataframe\columns.py:512
# Column<b'kurtosis(height(ft)) AS `kurtosis_height(ft)`'>
# 0.13863
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.kurt", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_kurt_all_columns() test function...
# INFO:optimus:test_cols_kurt_all_columns()
# INFO:optimus:`names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF80E400>
# <function _create_function.<locals>._ at 0x000001E3FF80E400>->../..\optimus\dataframe\columns.py:512
# rank <function _create_function.<locals>._ at 0x000001E3FF80E400>
# <function _create_function.<locals>._ at 0x000001E3FF80E400>->../..\optimus\dataframe\columns.py:512
# age <function _create_function.<locals>._ at 0x000001E3FF80E400>
# <function _create_function.<locals>._ at 0x000001E3FF80E400>->../..\optimus\dataframe\columns.py:512
# weight(t) <function _create_function.<locals>._ at 0x000001E3FF80E400>
# <function _create_function.<locals>._ at 0x000001E3FF80E400>->../..\optimus\dataframe\columns.py:512
# Column<b'kurtosis(height(ft)) AS `kurtosis_height(ft)`'> Column<b'kurtosis(rank) AS `kurtosis_rank`'> Column<b'kurtosis(age) AS `kurtosis_age`'> Column<b'kurtosis(weight(t)) AS `kurtosis_weight(t)`'>
# 'kurtosis' function in 'age' column is returning 'nan'. Is that what you expected?. Seems that 'age' has 'nan' values
# {'height(ft)': 0.13863, 'rank': -1.5, 'age': nan, 'weight(t)': -1.43641}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.mean", None, "json", numeric_col)
# Out:
# Creating test_cols_mean() test function...
# 65.6

# %%
t.create(None, "cols.mean", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_mean_all_columns() test function...
# INFO:optimus:test_cols_mean_all_columns()
# INFO:optimus:`names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF7F4C80>
# <function _create_function.<locals>._ at 0x000001E3FF7F4C80>->../..\optimus\dataframe\columns.py:512
# rank <function _create_function.<locals>._ at 0x000001E3FF7F4C80>
# <function _create_function.<locals>._ at 0x000001E3FF7F4C80>->../..\optimus\dataframe\columns.py:512
# age <function _create_function.<locals>._ at 0x000001E3FF7F4C80>
# <function _create_function.<locals>._ at 0x000001E3FF7F4C80>->../..\optimus\dataframe\columns.py:512
# weight(t) <function _create_function.<locals>._ at 0x000001E3FF7F4C80>
# <function _create_function.<locals>._ at 0x000001E3FF7F4C80>->../..\optimus\dataframe\columns.py:512
# Column<b'avg(height(ft)) AS `mean_height(ft)`'> Column<b'avg(rank) AS `mean_rank`'> Column<b'avg(age) AS `mean_age`'> Column<b'avg(weight(t)) AS `mean_weight(t)`'>
# {'height(ft)': 65.6, 'rank': 8.33333, 'age': 5000000.0, 'weight(t)': 3.56}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.skewness", None, "json", numeric_col)
# Out:
# Creating test_cols_skewness() test function...
# 1.4049

# %%
t.create(None, "cols.skewness", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_skewness_all_columns() test function...
# INFO:optimus:test_cols_skewness_all_columns()
# INFO:optimus:`names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF80E378>
# <function _create_function.<locals>._ at 0x000001E3FF80E378>->../..\optimus\dataframe\columns.py:512
# rank <function _create_function.<locals>._ at 0x000001E3FF80E378>
# <function _create_function.<locals>._ at 0x000001E3FF80E378>->../..\optimus\dataframe\columns.py:512
# age <function _create_function.<locals>._ at 0x000001E3FF80E378>
# <function _create_function.<locals>._ at 0x000001E3FF80E378>->../..\optimus\dataframe\columns.py:512
# weight(t) <function _create_function.<locals>._ at 0x000001E3FF80E378>
# <function _create_function.<locals>._ at 0x000001E3FF80E378>->../..\optimus\dataframe\columns.py:512
# Column<b'skewness(height(ft)) AS `skewness_height(ft)`'> Column<b'skewness(rank) AS `skewness_rank`'> Column<b'skewness(age) AS `skewness_age`'> Column<b'skewness(weight(t)) AS `skewness_weight(t)`'>
# 'skewness' function in 'age' column is returning 'nan'. Is that what you expected?. Seems that 'age' has 'nan' values
# {'height(ft)': 1.4049, 'rank': 0.3818, 'age': nan, 'weight(t)': 0.06521}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.sum", None, "json", numeric_col)
# Out:
# Creating test_cols_sum() test function...
# 328

# %%
t.create(None, "cols.sum", "all_columns", "json", None,"*")
t.run()
# Out:
# Creating test_cols_sum_all_columns() test function...
# INFO:optimus:test_cols_sum_all_columns()
# INFO:optimus:`names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF7F4B70>
# <function _create_function.<locals>._ at 0x000001E3FF7F4B70>->../..\optimus\dataframe\columns.py:512
# rank <function _create_function.<locals>._ at 0x000001E3FF7F4B70>
# <function _create_function.<locals>._ at 0x000001E3FF7F4B70>->../..\optimus\dataframe\columns.py:512
# age <function _create_function.<locals>._ at 0x000001E3FF7F4B70>
# <function _create_function.<locals>._ at 0x000001E3FF7F4B70>->../..\optimus\dataframe\columns.py:512
# weight(t) <function _create_function.<locals>._ at 0x000001E3FF7F4B70>
# <function _create_function.<locals>._ at 0x000001E3FF7F4B70>->../..\optimus\dataframe\columns.py:512
# Column<b'sum(height(ft)) AS `sum_height(ft)`'> Column<b'sum(rank) AS `sum_rank`'> Column<b'sum(age) AS `sum_age`'> Column<b'sum(weight(t)) AS `sum_weight(t)`'>
# {'height(ft)': 328, 'rank': 50, 'age': 30000000, 'weight(t)': 17.8}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.variance", None, "json", numeric_col)
# Out:
# Creating test_cols_variance() test function...
# 17600.3

# %%
t.create(None, "cols.variance", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_variance_all_columns() test function...
# INFO:optimus:test_cols_variance_all_columns()
# INFO:optimus:`names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# height(ft) <function _create_function.<locals>._ at 0x000001E3FF80E1E0>
# <function _create_function.<locals>._ at 0x000001E3FF80E1E0>->../..\optimus\dataframe\columns.py:512
# rank <function _create_function.<locals>._ at 0x000001E3FF80E1E0>
# <function _create_function.<locals>._ at 0x000001E3FF80E1E0>->../..\optimus\dataframe\columns.py:512
# age <function _create_function.<locals>._ at 0x000001E3FF80E1E0>
# <function _create_function.<locals>._ at 0x000001E3FF80E1E0>->../..\optimus\dataframe\columns.py:512
# weight(t) <function _create_function.<locals>._ at 0x000001E3FF80E1E0>
# <function _create_function.<locals>._ at 0x000001E3FF80E1E0>->../..\optimus\dataframe\columns.py:512
# Column<b'var_samp(height(ft)) AS `variance_height(ft)`'> Column<b'var_samp(rank) AS `variance_rank`'> Column<b'var_samp(age) AS `variance_age`'> Column<b'var_samp(weight(t)) AS `variance_weight(t)`'>
# {'height(ft)': 17600.3, 'rank': 1.86667, 'age': 0.0, 'weight(t)': 2.713}
# Creating file ../test_df_cols.py
# Done

# %%
source_df.table()
# Out:
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
from pyspark.sql import functions as F
source_df.select(F.abs(F.col("age")))
# Out:
# DataFrame[abs(age): int]

# %%
t.create(None, "cols.abs", None, "df", None,"weight(t)")

# %%
t.create(None, "cols.abs", "all_columns", "json", None, "*")

# %%
source_df.table()
# Out:
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
from pyspark.sql import functions as F

source_df.select(F.abs("weight(t)"))
# Out:
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# <ipython-input-122-b265435ce4f1> in <module>
#       1 from pyspark.sql import functions as F
#       2
# ----> 3 source_df.select(F.abs("weight(t)"))
#
# ~\Anaconda3\lib\site-packages\pyspark\sql\functions.py in _(col)
#      40     def _(col):
#      41         sc = SparkContext._active_spark_context
# ---> 42         jc = getattr(sc._jvm.functions, name)(col._jc if isinstance(col, Column) else col)
#      43         return Column(jc)
#      44     _.__name__ = name
#
# ~\Anaconda3\lib\site-packages\py4j\java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# ~\Anaconda3\lib\site-packages\pyspark\sql\utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# ~\Anaconda3\lib\site-packages\py4j\protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     330                 raise Py4JError(
#     331                     "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
# --> 332                     format(target_id, ".", name, value))
#     333         else:
#     334             raise Py4JError(
#
# Py4JError: An error occurred while calling z:org.apache.spark.sql.functions.abs. Trace:
# py4j.Py4JException: Method abs([class java.lang.String]) does not exist
# 	at py4j.reflection.ReflectionEngine.getMethod(ReflectionEngine.java:318)
# 	at py4j.reflection.ReflectionEngine.getMethod(ReflectionEngine.java:339)
# 	at py4j.Gateway.invoke(Gateway.java:276)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
t.create(None, "cols.mode", None, "json", numeric_col)
# Out:
# Creating test_cols_mode() test function...
# None

# %%
t.create(None, "cols.mode", "all_columns", "json", "*")
# Out:
# Creating test_cols_mode_all_columns() test function...
# [{'names': None}, {'height(ft)': None}, {'function': None}, {'rank': [8, 7, 10]}, {'age': 5000000}, {'weight(t)': None}, {'japanese name': None}, {'last position seen': None}, {'date arrival': '1980/04/10'}, {'last date seen': None}, {'attributes': None}, {'Date Type': None}, {'Tiemstamp': datetime.datetime(2014, 6, 24, 0, 0)}, {'Cybertronian': True}, {'function(binary)': None}, {'NullType': None}]

# %%
t.create(None, "cols.count", None, "json")
# Out:
# Creating test_cols_count() test function...
# 16

# %% [markdown]
# ## Count na

# %%
t.create(None, "cols.count_na", None, "json", None, numeric_col)
# Out:
# Creating test_cols_count_na() test function...
# INFO:optimus:test_cols_count_na()
# 2

# %%
t.create(None, "cols.count_na", "all_columns", "json",None, "*")
# Out:
# Creating test_cols_count_na_all_columns() test function...
# INFO:optimus:test_cols_count_na_all_columns()
# {'names': 1, 'height(ft)': 2, 'function': 1, 'rank': 1, 'age': 1, 'weight(t)': 2, 'japanese name': 1, 'last position seen': 3, 'date arrival': 1, 'last date seen': 1, 'attributes': 1, 'Date Type': 1, 'timestamp': 1, 'Cybertronian': 1, 'function(binary)': 1, 'NullType': 7}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
source_df.cols.names("rank",["str","int","float"],True)
# Out:
# INFO:optimus:`rank` column(s) was not processed because is/are not str,int,float
# ['rank']

# %%
t.create(None, "cols.count_zeros", None, "json", numeric_col)
# Out:
# Creating test_cols_count_zeros() test function...
# 0

# %%
t.create(None, "cols.count_zeros", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_count_zeros_all_columns() test function...
# INFO:optimus:test_cols_count_zeros_all_columns()
# {'names': 0, 'height(ft)': 0, 'function': 0, 'rank': 0, 'age': 0, 'weight(t)': 0, 'last position seen': 0, 'date arrival': 0, 'last date seen': 0}
# Creating file ../test_df_cols.py
# Done

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
source_df.cols.names()
# Out:
# ['names',
#  'height(ft)',
#  'function',
#  'rank',
#  'age',
#  'weight(t)',
#  'japanese name',
#  'last position seen',
#  'date arrival',
#  'last date seen',
#  'attributes',
#  'Date Type',
#  'timestamp',
#  'Cybertronian',
#  'function(binary)',
#  'NullType']

# %% [markdown]
# ## Value counts

# %%
t.create(None, "cols.value_counts", None, "json", None, numeric_col)
t.run()
# Out:
# Creating test_cols_value_counts() test function...
# INFO:optimus:test_cols_value_counts()
# {'height(ft)': [{'value': 300, 'count': 1}, {'value': 26, 'count': 1}, {'value': 13, 'count': 1}, {'value': 17, 'count': 1}, {'value': -28, 'count': 1}, {'value': None, 'count': 2}]}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.value_counts", "all_columns", "json", None,  "*")
t.run()

# %%
t.create(None, "cols.count_uniques", None, "json", None, numeric_col)
t.run()
# Out:
# Creating test_cols_count_uniques() test function...
# INFO:optimus:test_cols_count_uniques()
# 5
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.count_uniques", "all_columns", "json",None, "*")
t.run()
# Out:
# Creating test_cols_count_uniques_all_columns() test function...
# INFO:optimus:test_cols_count_uniques_all_columns()
# {'names': 5, 'height(ft)': 5, 'function': 6, 'rank': 3, 'age': 1, 'weight(t)': 5, 'japanese name': 6, 'last position seen': 4, 'date arrival': 1, 'last date seen': 6, 'attributes': 6, 'Date Type': 6, 'timestamp': 1, 'Cybertronian': 1, 'function(binary)': 6, 'NullType': 0}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.unique", None, "json", None,numeric_col)
t.run()
# Out:
# Creating test_cols_unique() test function...
# INFO:optimus:test_cols_unique()
# {'height(ft)': [300, 26, None, 13, 17, -28]}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.unique", "all_columns", "json", None,"*")
t.run()
# Out:
# Creating test_cols_unique_all_columns() test function...
# INFO:optimus:test_cols_unique_all_columns()
# {'names': ['Jazz', None, 'bumbl#ebéé  ', 'ironhide&', "Optim'us", 'Megatron', 'Metroplex_)^$'], 'height(ft)': [300, 26, None, 13, 17, -28], 'function': ['Leader', 'First Lieutenant', 'None', 'Security', None, 'Espionage', 'Battle Station'], 'rank': [None, 8, 7, 10], 'age': [None, 5000000], 'weight(t)': [5.699999809265137, None, 2.0, 1.7999999523162842, 4.0, 4.300000190734863], 'japanese name': [['Metroflex'], ['Bumble', 'Goldback'], None, ['Inochi', 'Convoy'], ['Megatron'], ['Meister'], ['Roadbuster']], 'last position seen': [None, '37.789563,-122.400356', '19.442735,-99.201111', '33.670666,-117.841553', '10.642707,-71.612534'], 'date arrival': [None, '1980/04/10'], 'last date seen': ['2011/04/10', None, '2012/05/10', '2013/06/10', '2015/08/10', '2014/07/10', '2016/09/10'], 'attributes': [[3.962399959564209, 1800.0], [None, 5700.0], None, [8.53439998626709, 4300.0], [7.924799919128418, 4000.0], [91.44000244140625, None], [5.334000110626221, 2000.0]], 'Date Type': ['2012-05-10', '2015-08-10', None, '2011-04-10', '2013-06-24', '2014-06-24', '2016-09-10'], 'timestamp': ['2014-06-24 00:00:00', None], 'Cybertronian': [None, True], 'function(binary)': [None, None, None, None, None, None, None], 'NullType': [None]}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.add", None, "df", [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_add() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">sum</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-18.0'>-18.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='24.0'>24.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>

# %%
t.create(None, "cols.add", "all_columns", "df", "*"),
# Out:
# Creating test_cols_add_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">sum</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='4999986.5'>4999986.5</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='5000026.0'>5000026.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
# (None,)

# %%
t.create(None, "cols.sub", None, "df", [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_sub() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">sub</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-38.0'>-38.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>

# %%
t.create(None, "cols.sub", "all_columns", "df", "*")
# Out:
# Creating test_cols_sub_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">sub</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-5000042.5'>-5000042.5</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-4999992.0'>-4999992.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>

# %%
t.create(None, "cols.mul", None, "df", [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_mul() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">mul</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-280.0'>-280.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='119.0'>119.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <

# %%
t.create(None, "cols.mul", "all_columns", "df", "*")
# Out:
# Creating test_cols_mul_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">mul</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-6020000256.0'>-6020000256.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1190000000.0'>1190000000.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;<

# %%
t.create(None, "cols.div", None, "df", [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_div() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">div</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-2.8'>-2.8</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2.4285714285714284'>2.4285714285714284</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         <

# %%
t.create(None, "cols.div", "all_columns", "df", "*")
# Out:
# Creating test_cols_div_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">div</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='-1.302325523628167e-07'>-1.302325523628167e-07</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='2.428571428571428e-07'>2.428571428571428e-07</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div

# %%
t.create(None, "cols.z_score", None, "df", numeric_col)
# Out:
# Creating test_cols_z_score() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim&#39;us'>Optim&#39;us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0.7055305454022474'>0.7055305454022474
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0.366333167805013'>0.366333167805013
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "

# %%
t.create(None, "cols.z_score", "all_columns", "df", "*")
# Out:
# Creating test_cols_z_score_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim&#39;us'>Optim&#39;us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0.7055305454022474'>0.7055305454022474
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1.2198776221217045'>1.2198776221217045
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0.4492691429494289'>0.4492691429494289
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0.366333167805013'>0.366333167805013
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0.9758977061467071'>0.9758977061467071
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0.9471076788576425'>0.9471076788576425
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10

# %%
t.create(None, "cols.iqr", None, "json", None, numeric_col)
# Out:
# Creating test_cols_iqr() test function...
# INFO:optimus:test_cols_iqr()
# DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null] ['0.25', '0.5', '0.75'] 10000
# (DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null], ['0.25', '0.5', '0.75'], 10000)
# INFO:optimus:percentile() executed in 1.61 sec
# 13

# %%
t.create(None, "cols.iqr", "all_columns", "json",None, "*")
# Out:
# Creating test_cols_iqr_all_columns() test function...
# INFO:optimus:test_cols_iqr_all_columns()
# INFO:optimus:`names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`timestamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null] ['0.25', '0.5', '0.75'] 10000
# (DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null], ['0.25', '0.5', '0.75'], 10000)
# DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null] ['0.25', '0.5', '0.75'] 10000
# (DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null], ['0.25', '0.5', '0.75'], 10000)
# DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null] ['0.25', '0.5', '0.75'] 10000
# (DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null], ['0.25', '0.5', '0.75'], 10000)
# DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null] ['0.25', '0.5', '0.75'] 10000
# (DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null], ['0.25', '0.5', '0.75'], 10000)
# INFO:optimus:percentile() executed in 1.75 sec
# {'height(ft)': 13, 'rank': 3, 'age': 0, 'weight(t)': 2.3000001907348633}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.lower", None, "df", string_col)
# Out:
# Creating test_cols_lower() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='leader'>leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='espionage'>espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='security'>security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.lower", "all_columns", "df", "*")
# Out:
# Creating test_cols_lower_all_columns() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not string
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='optim&#39;us'>optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='leader'>leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='espionage'>espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='security'>security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.upper", None, "df", string_col)
# Out:
# Creating test_cols_upper() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='LEADER'>LEADER</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='ESPIONAGE'>ESPIONAGE</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='SECURITY'>SECURITY</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.upper", "all_columns", "df", "*")
# Out:
# Creating test_cols_upper_all_columns() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not string
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='OPTIM&#39;US'>OPTIM&#39;US
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-28'>-28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='LEADER'>LEADER
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='BUMBL#EBÉÉ⸱⸱'>BUMBL#EBÉÉ⸱⸱
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='ESPIONAGE'>ESPIONAGE
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.trim", None, "df", numeric_col)
# Out:
# Creating test_cols_trim() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;R

# %%
t.create(None, "cols.trim", "all_columns", "df", "*")
# Out:
# Creating test_cols_trim_all_columns() test function...
# `japanese name`,`attributes`,`Tiemstamp`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float,string,date,bool
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.3'>4.3</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé'>bumbl#ebéé</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadb

# %%
t.create(None, "cols.reverse", None, "df", string_col)
# Out:
# Creating test_cols_reverse() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='redaeL'>redaeL</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='eganoipsE'>eganoipsE</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='ytiruceS'>ytiruceS</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.reverse", "all_columns", "df", "*")
# Out:
# Creating test_cols_reverse_all_columns() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not string
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='su&#39;mitpO'>su&#39;mitpO</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='redaeL'>redaeL</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='111102.99-,537244.91'>111102.99-,537244.91</div>
#         </td>
#
#         <td>
#             <div title='01/40/0891'>01/40/0891</div>
#         </td>
#
#         <td>
#             <div title='01/90/6102'>01/90/6102</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='⸱⸱éébe#lbmub'>⸱⸱éébe#lbmub</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='eganoipsE'>eganoipsE</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='435216.17-,707246.01'>435216.17-,707246.01</div>
#         </td>
#
#         <td>
#             <div title='01/40/0891'>01/40/0891</div>
#         </td>
#
#         <td>
#             <div title='01/80/5102'>01/80/5102</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='&amp;edihnori'>&amp;edihnori</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='ytiruceS'>ytiruceS</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.remove_accents", None, "df", string_col)
# Out:
# Creating test_cols_remove_accents() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.remove_accents", "all_columns", "df", string_col)
# Out:
# Creating test_cols_remove_accents_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
source_df.table()
# Out:
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""

# %%
t.create(None, "cols.remove_special_chars", None, "df", string_col)
# Out:
# Creating test_cols_remove_special_chars() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.remove_special_chars", "all_columns", "df", "*")
# Out:
# Creating test_cols_remove_special_chars_all_columns() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not str
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optimus'>Optimus</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='1944273599201111'>1944273599201111</div>
#         </td>
#
#         <td>
#             <div class="" title='19800410'>19800410</div>
#         </td>
#
#         <td>
#             <div class="" title='20160910'>20160910</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumblebéé⸱⸱'>bumblebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='1064270771612534'>1064270771612534</div>
#         </td>
#
#         <td>
#             <div class="" title='19800410'>19800410</div>
#         </td>
#
#         <td>
#             <div class="" title='20150810'>20150810</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide'>ironhide</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class="" title='Security'>Security</div>
#         </td>
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.remove_white_spaces", None, "df", string_col)
# Out:
# Creating test_cols_remove_white_spaces() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.remove_white_spaces", "all_columns", "df", "*")
# Out:
# Creating test_cols_remove_white_spaces_all_columns() test function...
# `japanese name`,`attributes`,`Tiemstamp`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float,string,date,bool
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.3'>4.3</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé'>bumbl#ebéé</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='true'>true</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadb

# %%
t.create(None, "cols.date_transform", None, "df", date_col, "yyyy/MM/dd", "dd-MM-YYYY")
# Out:
# Creating test_cols_date_transform() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim&#39;us'>Optim&#39;us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-28'>-28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10-04-1980'>10-04-1980
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10-04-1980'>10-04-1980
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.date_transform", "all_columns", "df", [date_col, date_col_B], "yyyy/MM/dd", "dd-MM-YYYY")
# Out:
# Creating test_cols_date_transform_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim&#39;us'>Optim&#39;us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-28'>-28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10-04-1980'>10-04-1980
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10-09-2016'>10-09-2016
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10-04-1980'>10-04-1980
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10-08-2015'>10-08-2015
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱

# %%
# t.create(None, "cols.years_between", None, "df", date_col, "yyyy/MM/dd")
t.delete(None, "cols.years_between", None, "df", date_col, "yyyy/MM/dd")
# Out:
# Deleting file df_cols//cols_years_between.test...

# %%
# t.create(None, "cols.years_between", "multiple_columns", "df", [date_col, date_col_B], "yyyy/MM/dd")
t.delete(None, "cols.years_between", "multiple_columns", "df", [date_col, date_col_B], "yyyy/MM/dd")
# Out:
# Deleting file df_cols//cols_years_between_multiple_columns.test...

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.impute", None, "df", numeric_col_B)
# Out:
# Creating test_cols_impute() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim&#39;us'>Optim&#39;us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-28'>-28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.0'>10.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7.0'>7.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334000110626221,⸱2000.0]'>[5.33400011062

# %%
t.create(None, "cols.impute", "all_columns", "df", "names","categorical")
# Out:
# Creating test_cols_impute_all_columns() test function...
# Including 'nan' as Null in processing 'names'
# 1 values imputed for column(s) 'names' with 'None'
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %% [markdown]
# ## Hist

# %%
t.create(None, "cols.hist", None, "json", None, ["height(ft)",numeric_col_B], 4)
t.run()
# Out:
# Creating test_cols_hist() test function...
# INFO:optimus:test_cols_hist()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-8a43a556a9a3> in <module>
# ----> 1 t.create(None, "cols.hist", None, "json", None, ["height(ft)",numeric_col_B], 4)
#       2 t.run()
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     205                 df_func = getattr(df_func, f)
#     206
# --> 207             df_result = df_func(*args, **kwargs)
#     208
#     209         # Additional Methods
#
# ~\Documents\Optimus\optimus\helpers\decorators.py in wrapper(*args, **kwargs)
#      47         def wrapper(*args, **kwargs):
#      48             start_time = timeit.default_timer()
# ---> 49             f = func(*args, **kwargs)
#      50             _time = round(timeit.default_timer() - start_time, 2)
#      51             if log_time:
#
# ~\Documents\Optimus\optimus\dataframe\columns.py in hist(columns, buckets)
#    1525     def hist(columns, buckets=20):
#    1526
# -> 1527         result = agg_exprs(columns, hist_agg, self, buckets)
#    1528         # TODO: for some reason casting to int in the exprss do not work. Casting Here. A Spark bug?
#    1529         # Example
#
# ~\Documents\Optimus\optimus\dataframe\columns.py in agg_exprs(columns, funcs, *args)
#     555         :return:
#     556         """
# --> 557         return exec_agg(create_exprs(columns, funcs, *args))
#     558
#     559     @add_attr(cols)
#
# ~\Documents\Optimus\optimus\dataframe\columns.py in create_exprs(columns, funcs, *args)
#     544             return _exprs
#     545
# --> 546         return _agg_exprs(exprs)
#     547
#     548     @add_attr(cols)
#
# ~\Documents\Optimus\optimus\dataframe\columns.py in _agg_exprs(_funcs)
#     534
#     535                 if not _filter(_col_name, _func):
# --> 536                     agg = _func(*_args)
#     537                     if agg is not None:
#     538                         func_name = _beautify_col_names(_func)
#
# ~\Documents\Optimus\optimus\helpers\columns_expression.py in hist_agg(col_name, df, buckets)
#      93     if is_column_a(df, col_name, PYSPARK_NUMERIC_TYPES):
#      94         min_max = df.agg(F.min(col_name).alias("min"), F.max(col_name).alias("max")).to_json()[0]
# ---> 95         buckets = create_buckets(min_max["min"], min_max["max"], buckets)
#      96         func = F.col
#      97         exprs = create_exprs(col_name, buckets, func)
#
# TypeError: string indices must be integers

# %%
t.create(None,"cols.hist","all_columns","json",None, "Date Type",4)
# Out:
# Creating test_cols_hist_all_columns() test function...
# INFO:optimus:test_cols_hist_all_columns()
# DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null] 4
# (DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null], 4)
# INFO:optimus:hist() executed in 10.25 sec
# {'Date Type': {'hist': {'hours': [{'count': 6.0, 'lower': 0.0, 'upper': 1.0}, {'count': 0.0, 'lower': 1.0, 'upper': 2.0}, {'count': 0.0, 'lower': 2.0, 'upper': 3.0}, {'count': 0.0, 'lower': 3.0, 'upper': 4.0}, {'count': 0.0, 'lower': 4.0, 'upper': 5.0}, {'count': 0.0, 'lower': 5.0, 'upper': 6.0}, {'count': 0.0, 'lower': 6.0, 'upper': 7.0}, {'count': 0.0, 'lower': 7.0, 'upper': 8.0}, {'count': 0.0, 'lower': 8.0, 'upper': 9.0}, {'count': 0.0, 'lower': 9.0, 'upper': 10.0}, {'count': 0.0, 'lower': 10.0, 'upper': 11.0}, {'count': 0.0, 'lower': 11.0, 'upper': 12.0}, {'count': 0.0, 'lower': 12.0, 'upper': 13.0}, {'count': 0.0, 'lower': 13.0, 'upper': 14.0}, {'count': 0.0, 'lower': 14.0, 'upper': 15.0}, {'count': 0.0, 'lower': 15.0, 'upper': 16.0}, {'count': 0.0, 'lower': 16.0, 'upper': 17.0}, {'count': 0.0, 'lower': 17.0, 'upper': 18.0}, {'count': 0.0, 'lower': 18.0, 'upper': 19.0}, {'count': 0.0, 'lower': 19.0, 'upper': 20.0}, {'count': 0.0, 'lower': 20.0, 'upper': 21.0}, {'count': 0.0, 'lower': 21.0, 'upper': 22.0}, {'count': 0.0, 'lower': 22.0, 'upper': 23.0}], 'seconds': [{'count': 6.0, 'lower': 0.0, 'upper': 1.0}, {'count': 0.0, 'lower': 1.0, 'upper': 2.0}, {'count': 0.0, 'lower': 2.0, 'upper': 3.0}, {'count': 0.0, 'lower': 3.0, 'upper': 4.0}, {'count': 0.0, 'lower': 4.0, 'upper': 5.0}, {'count': 0.0, 'lower': 5.0, 'upper': 6.0}, {'count': 0.0, 'lower': 6.0, 'upper': 7.0}, {'count': 0.0, 'lower': 7.0, 'upper': 8.0}, {'count': 0.0, 'lower': 8.0, 'upper': 9.0}, {'count': 0.0, 'lower': 9.0, 'upper': 10.0}, {'count': 0.0, 'lower': 10.0, 'upper': 11.0}, {'count': 0.0, 'lower': 11.0, 'upper': 12.0}, {'count': 0.0, 'lower': 12.0, 'upper': 13.0}, {'count': 0.0, 'lower': 13.0, 'upper': 14.0}, {'count': 0.0, 'lower': 14.0, 'upper': 15.0}, {'count': 0.0, 'lower': 15.0, 'upper': 16.0}, {'count': 0.0, 'lower': 16.0, 'upper': 17.0}, {'count': 0.0, 'lower': 17.0, 'upper': 18.0}, {'count': 0.0, 'lower': 18.0, 'upper': 19.0}, {'count': 0.0, 'lower': 19.0, 'upper': 20.0}, {'count': 0.0, 'lower': 20.0, 'upper': 21.0}, {'count': 0.0, 'lower': 21.0, 'upper': 22.0}, {'count': 0.0, 'lower': 22.0, 'upper': 23.0}, {'count': 0.0, 'lower': 23.0, 'upper': 24.0}, {'count': 0.0, 'lower': 24.0, 'upper': 25.0}, {'count': 0.0, 'lower': 25.0, 'upper': 26.0}, {'count': 0.0, 'lower': 26.0, 'upper': 27.0}, {'count': 0.0, 'lower': 27.0, 'upper': 28.0}, {'count': 0.0, 'lower': 28.0, 'upper': 29.0}, {'count': 0.0, 'lower': 29.0, 'upper': 30.0}, {'count': 0.0, 'lower': 30.0, 'upper': 31.0}, {'count': 0.0, 'lower': 31.0, 'upper': 32.0}, {'count': 0.0, 'lower': 32.0, 'upper': 33.0}, {'count': 0.0, 'lower': 33.0, 'upper': 34.0}, {'count': 0.0, 'lower': 34.0, 'upper': 35.0}, {'count': 0.0, 'lower': 35.0, 'upper': 36.0}, {'count': 0.0, 'lower': 36.0, 'upper': 37.0}, {'count': 0.0, 'lower': 37.0, 'upper': 38.0}, {'count': 0.0, 'lower': 38.0, 'upper': 39.0}, {'count': 0.0, 'lower': 39.0, 'upper': 40.0}, {'count': 0.0, 'lower': 40.0, 'upper': 41.0}, {'count': 0.0, 'lower': 41.0, 'upper': 42.0}, {'count': 0.0, 'lower': 42.0, 'upper': 43.0}, {'count': 0.0, 'lower': 43.0, 'upper': 44.0}, {'count': 0.0, 'lower': 44.0, 'upper': 45.0}, {'count': 0.0, 'lower': 45.0, 'upper': 46.0}, {'count': 0.0, 'lower': 46.0, 'upper': 47.0}, {'count': 0.0, 'lower': 47.0, 'upper': 48.0}, {'count': 0.0, 'lower': 48.0, 'upper': 49.0}, {'count': 0.0, 'lower': 49.0, 'upper': 50.0}, {'count': 0.0, 'lower': 50.0, 'upper': 51.0}, {'count': 0.0, 'lower': 51.0, 'upper': 52.0}, {'count': 0.0, 'lower': 52.0, 'upper': 53.0}, {'count': 0.0, 'lower': 53.0, 'upper': 54.0}, {'count': 0.0, 'lower': 54.0, 'upper': 55.0}, {'count': 0.0, 'lower': 55.0, 'upper': 56.0}, {'count': 0.0, 'lower': 56.0, 'upper': 57.0}, {'count': 0.0, 'lower': 57.0, 'upper': 58.0}, {'count': 0.0, 'lower': 58.0, 'upper': 59.0}, {'count': 0.0, 'lower': 59.0, 'upper': 60.0}], 'months': [{'count': 0.0, 'lower': 1.0, 'upper': 2.0}, {'count': 0.0, 'lower': 2.0, 'upper': 3.0}, {'count': 0.0, 'lower': 3.0, 'upper': 4.0}, {'count': 1.0, 'lower': 4.0,  ...

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.frequency", None, "json", None, numeric_col_B, 4)
t.run()
# Out:
# Creating test_cols_frequency() test function...
# INFO:optimus:test_cols_frequency()
# INFO:optimus:Using 'column_exp' to process column 'rank' with function _cast_to
# {'rank': [{'value': '10', 'count': 2}, {'value': '7', 'count': 2}, {'value': '8', 'count': 2}, {'value': None, 'count': 1}]}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.frequency", "all_columns", "json", None, "*", 4)
t.run()
# Out:
# Creating test_cols_frequency_all_columns() test function...
# INFO:optimus:test_cols_frequency_all_columns()
# INFO:optimus:`names`,`height(ft)`,`function`,`age`,`weight(t)`,`last position seen`,`date arrival`,`last date seen`,`timestamp`,`Cybertronian`,`NullType` column(s) was not processed because is/are not array,vector,byte,date,binary
# INFO:optimus:Using 'column_exp' to process column 'rank' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'japanese name' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'attributes' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Date Type' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'function(binary)' with function _cast_to
# {'names': [{'value': "Optim'us", 'count': 1}, {'value': 'bumbl#ebéé  ', 'count': 1}, {'value': 'ironhide&', 'count': 1}, {'value': 'Jazz', 'count': 1}], 'height(ft)': [{'value': None, 'count': 2}, {'value': -28, 'count': 1}, {'value': 17, 'count': 1}, {'value': 26, 'count': 1}], 'function': [{'value': 'Leader', 'count': 1}, {'value': 'Espionage', 'count': 1}, {'value': 'Security', 'count': 1}, {'value': 'First Lieutenant', 'count': 1}], 'rank': [{'value': '10', 'count': 2}, {'value': '7', 'count': 2}, {'value': '8', 'count': 2}, {'value': None, 'count': 1}], 'age': [{'value': 5000000, 'count': 6}, {'value': None, 'count': 1}], 'weight(t)': [{'value': None, 'count': 2}, {'value': 4.300000190734863, 'count': 1}, {'value': 2.0, 'count': 1}, {'value': 4.0, 'count': 1}], 'japanese name': [{'value': '[Inochi, Convoy]', 'count': 1}, {'value': '[Bumble, Goldback]', 'count': 1}, {'value': '[Roadbuster]', 'count': 1}, {'value': '[Meister]', 'count': 1}], 'last position seen': [{'value': None, 'count': 3}, {'value': '19.442735,-99.201111', 'count': 1}, {'value': '10.642707,-71.612534', 'count': 1}, {'value': '37.789563,-122.400356', 'count': 1}], 'date arrival': [{'value': '1980/04/10', 'count': 6}, {'value': None, 'count': 1}], 'last date seen': [{'value': '2016/09/10', 'count': 1}, {'value': '2015/08/10', 'count': 1}, {'value': '2014/07/10', 'count': 1}, {'value': '2013/06/10', 'count': 1}], 'attributes': [{'value': '[8.5344, 4300.0]', 'count': 1}, {'value': '[5.334, 2000.0]', 'count': 1}, {'value': '[7.9248, 4000.0]', 'count': 1}, {'value': '[3.9624, 1800.0]', 'count': 1}], 'Date Type': [{'value': '2016-09-10', 'count': 1}, {'value': '2015-08-10', 'count': 1}, {'value': '2014-06-24', 'count': 1}, {'value': '2013-06-24', 'count': 1}], 'timestamp': [{'value': datetime.datetime(2014, 6, 24, 0, 0), 'count': 6}, {'value': None, 'count': 1}], 'Cybertronian': [{'value': True, 'count': 6}, {'value': None, 'count': 1}], 'function(binary)': [{'value': 'Leader', 'count': 1}, {'value': 'Espionage', 'count': 1}, {'value': 'Security', 'count': 1}, {'value': 'First Lieutenant', 'count': 1}], 'NullType': [{'value': None, 'count': 7}]}
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.schema_dtype", None, "json", numeric_col_B)
# Out:
# Creating test_cols_schema_dtype() test function...
# ByteType
# Creating file ../test_df_cols.py
# Done

# %%
# Problems with casting
# t.delete(None, "cols.schema_dtype", "all_columns", "json", "*")
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.dtypes", None, "json", None, numeric_col_B)
# Out:
# Creating test_cols_dtypes() test function...
# INFO:optimus:test_cols_dtypes()
# {'rank': 'tinyint'}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.dtypes", "all_columns", "json", "*")
# Out:
# Creating test_cols_dtypes_all_columns() test function...
# {'names': 'string', 'height(ft)': 'smallint', 'function': 'string', 'rank': 'tinyint', 'age': 'int', 'weight(t)': 'float', 'japanese name': 'array<string>', 'last position seen': 'string', 'date arrival': 'string', 'last date seen': 'string', 'attributes': 'array<float>', 'Date Type': 'date', 'Tiemstamp': 'timestamp', 'Cybertronian': 'boolean', 'function(binary)': 'binary', 'NullType': 'null'}

# %%
t.create(None, "cols.select_by_dtypes", "str", "df", "str")
# Out:
# Creating test_cols_select_by_dtypes_str() test function...
# `height(ft)`,`rank`,`age`,`weight(t)`,`japanese name`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not str
# <div class="info_items">Viewing 7 of 7 rows / 5 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='37.789563,-122.400356'>37.789563,-122.400356</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2014/07/10'>2014/07/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Jazz'>Jazz</div>
#         </td>
#
#         <td>
#             <div title='First⸱Lieutenant'>First⸱Lieutenant</div>
#         </td>
#
#         <td>
#             <div title='33.670666,-117.841553'>33.670666,-117.841553</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2013/06/10'>2013/06/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Megatron'>Megatron</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2012/05/10'>2012/05/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Metroplex_)^$'>Metroplex_)^$</div>
#         </td>
#
#         <td>
#             <div title='Battle⸱Station'>Battle⸱Station</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2011/04/10'>2011/04/10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 5 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.select_by_dtypes", "int", "df", "int")
# Out:
# Creating test_cols_select_by_dtypes_int() test function...
# `names`,`height(ft)`,`function`,`rank`,`weight(t)`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not int
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">1 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.select_by_dtypes", "float", "df", "float")
# Out:
# Creating test_cols_select_by_dtypes_float() test function...
# `names`,`height(ft)`,`function`,`rank`,`age`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not float
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">1 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='1.7999999523162842'>1.7999999523162842</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='5.699999809265137'>5.699999809265137</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.select_by_dtypes", "array", "df", "array")
# Out:
# Creating test_cols_select_by_dtypes_array() test function...
# `names`,`height(ft)`,`function`,`rank`,`age`,`weight(t)`,`last position seen`,`date arrival`,`last date seen`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not array
# <div class="info_items">Viewing 7 of 7 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">1 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">2 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[7.924799919128418,⸱4000.0]'>[7.924799919128418,⸱4000.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Meister&#39;]'>[&#39;Meister&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[3.962399959564209,⸱1800.0]'>[3.962399959564209,⸱1800.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Megatron&#39;]'>[&#39;Megatron&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[None,⸱5700.0]'>[None,⸱5700.0]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='[&#39;Metroflex&#39;]'>[&#39;Metroflex&#39;]</div>
#         </td>
#
#         <td>
#             <div title='[91.44000244140625,⸱None]'>[91.44000244140625,⸱None]</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 2 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.names", None, "json")
# Out:
# Creating test_cols_names() test function...
# ['names', 'height(ft)', 'function', 'rank', 'age', 'weight(t)', 'japanese name', 'last position seen', 'date arrival', 'last date seen', 'attributes', 'Date Type', 'Tiemstamp', 'Cybertronian', 'function(binary)', 'NullType']

# %%
t.create(None, "cols.qcut", None, "df", numeric_col_B, 4)
# Out:
# Creating test_cols_qcut() test function...
# <div class="info_items">Viewing 6 of 6 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank_qcut</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='3.0'>3.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1.0'>1.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>

# %%
t.create(None, "cols.qcut", "all_columns", "df", "*", 4)
# Out:
# Creating test_cols_qcut_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 4 of 4 rows / 20 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)_qcut</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank_qcut</div>
#             <div class="data_type">18 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age_qcut</div>
#             <div class="data_type">19 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)_qcut</div>
#             <div class="data_type">20 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='0.0'>0.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='1.0'>1.0</div>
#         </td>
#
#         <td>
#             <div title='3.0'>3.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>

# %%
t.create(None, "cols.clip", None, "df", numeric_col_B, 3, 5)
# Out:
# Creating test_cols_clip() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadb

# %%
t.create(None, "cols.clip", "all_columns", "df", "*", 3, 5)
# Out:
# Creating test_cols_clip_all_columns() test function...
# `names`,`function`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)`,`NullType` column(s) was not processed because is/are not byte,short,big,int,double,float
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='3'>3</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='3.0'>3.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='5'>5</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>

# %%
t.create(None, "cols.replace", None, "df", string_col, ["Security", "Leader"], "Match")
# Out:
# Creating test_cols_replace() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim'us'>Optim'us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-28'>-28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Match'>Match
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.300000190734863'>4.300000190734863
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Inochi',&#8901;'Convoy']'>['Inochi',&#8901;'Convoy']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.53439998626709,&#8901;4300.0]'>[8.53439998626709,&#8901;4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24&#8901;00:00:00'>2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" true"
#                  title='True'>True
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='bytearray(b'Leader')'>bytearray(b'Leader')
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé&#8901;&#8901;'>bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Bumble',&#8901;'Goldback']'>['Bumble',&#8901;'Goldback']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334000110626221,&#8901;2000.0]'>[5.334000110626221,&#8901;2000.0

# %%
# Assert is failing I can see why
t.delete(None, "cols.replace", "all_columns", "df", "*", ["Jazz", "Leader"], "Match")
t.run()
# Out:
# Deleting file df_cols//cols_replace_all_columns.test...
# File NOT found
# Creating file ../test_df_cols.py
# Done

# %%
# Its necesary to save the function 
t.delete(None, "cols.apply_expr", None, "df", numeric_col_B, func)
# Out:
# Deleting file df_cols//cols_apply_expr.test...
# File NOT found

# %%
# Its necesary to save the function 
t.delete(None, "cols.apply_expr", "all_columns", "df", [numeric_col_B,numeric_col_C], func)
# Out:
# Deleting file df_cols//cols_apply_expr_all_columns.test...
# File NOT found

# %%
t.create(None, "cols.append", "number", "df", new_col, 1)
# Out:
# Creating test_cols_append_number() test function...
# <div class="info_items">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">new col</div>
#             <div class="data_type">17 (int)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='1'>1</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>

# %%
df_col = op.create.df(
    [
        ("new_col", "str", True),
       

    ],[
        ("q"),("w"), ("e"), ("r"),

    ])

# %%
t.create(None, "cols.append", "dataframes", "df", None, df_col)

# %%
#t.create(None, "cols.append", "advance", "df", [("new_col_4", "test"),
    #                                                ("new_col_5", df[numeric_col_B] * 2),
    #                                                ("new_col_6", [1, 2, 3])
    #                                                ]),

# %%
t.create(None, "cols.rename", None, "df", numeric_col_B, numeric_col_B + "(old)")
# Out:
# Creating test_cols_rename() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank(old)</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='

# %%
t.create(None, "cols.rename", "list", "df", [numeric_col, numeric_col + "(tons)", numeric_col_B, numeric_col_B + "(old)"])
# Out:
# Creating test_cols_rename_list() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.rename", "function", "df", str.upper)
# Out:
# Creating test_cols_rename_function() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">NAMES</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">HEIGHT(FT)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">FUNCTION</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">RANK</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">AGE</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">WEIGHT(T)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">JAPANESE NAME</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">LAST POSITION SEEN</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">DATE ARRIVAL</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">LAST DATE SEEN</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ATTRIBUTES</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">DATE TYPE</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">TIEMSTAMP</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">CYBERTRONIAN</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">FUNCTION(BINARY)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NULLTYPE</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.drop", None, "df", numeric_col_B)
# Out:
# Creating test_cols_drop() test function...
# <div class="info_items">Viewing 7 of 7 rows / 15 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">10 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">11 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">12 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">13 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">14 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">15 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>
#
#         <td>
#             <div title='37.789563,-122.400356'>37.789563,-122.400356</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2014/07/10'>2014/07/10</div>
#         </td>
#
#         <td>
#             <div title='[7.924799919128418,⸱4000.0]'>[7.924799919128418,⸱4000.0]</div>

# %%
t.create(None, "cols.cast", None, "df", string_col, "string")
# Out:
# Creating test_cols_cast() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.cast", "all_columns", "df", "*", "string")
# Out:
# Creating test_cols_cast_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Optim&#39;us'>Optim&#39;us
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='-28'>-28
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10'>10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4.3'>4.3
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[Inochi,⸱Convoy]'>[Inochi,⸱Convoy]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='19.442735,-99.201111'>19.442735,-99.201111
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016/09/10'>2016/09/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[8.5344,⸱4300.0]'>[8.5344,⸱4300.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2016-09-10'>2016-09-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='true'>true
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Leader'>Leader
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17'>17
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Espionage'>Espionage
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='7'>7
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5000000'>5000000
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2.0'>2.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[Bumble,⸱Goldback]'>[Bumble,⸱Goldback]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='10.642707,-71.612534'>10.642707,-71.612534
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1980/04/10'>1980/04/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015/08/10'>2015/08/10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='[5.334,⸱2000.0]'>[5.334,⸱2000.0]
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2015-08-10'>2015-08-10
#             </div>
#         </td>
#
#         <td>
#             <div class=" "

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
# Problems with precision
t.delete(None, "cols.cast", "vector", "df", array_col, Vectors)
# Out:
# Deleting file df_cols//cols_cast_vector.test...

# %%
t.create(None, "cols.keep", None, "df", numeric_col_B)
# Out:
# Creating test_cols_keep() test function...
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">1 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='8'>8</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='8'>8</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.move", "after", "df", numeric_col_B, "after", array_col)
# Out:
# Creating test_cols_move_after() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">10 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">11 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>

# %%
t.create(None, "cols.move", "before", "df", numeric_col_B, "before", array_col)
# Out:
# Creating test_cols_move_before() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">10 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>

# %%
t.create(None, "cols.move", "beginning", "df", numeric_col_B, "beginning")
# Out:
# Creating test_cols_move_beginning() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">1 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">3 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.create(None, "cols.move", "end", "df", numeric_col_B, "end")
# Out:
# Creating test_cols_move_end() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">5 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">6 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">10 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">11 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">12 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">13 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">14 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">15 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">16 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Roadbuster&#39;]</div>
#         </td>

# %%
t.create(None, "cols.select", None, "df", 0, numeric_col)
# Out:
# Creating test_cols_select() test function...
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Jazz'>Jazz</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Megatron'>Megatron</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Metroplex_)^$'>Metroplex_)^$</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
t.create(None, "cols.select", "regex", "df", "n.*", regex=True),
# Out:
# Creating test_cols_select_regex() test function...
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Jazz'>Jazz</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Megatron'>Megatron</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='Metroplex_)^$'>Metroplex_)^$</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 7 of 7 rows / 1 columns</div>
# <div class="info_items">8 partition(s)</div>
# (None,)

# %%
t.create(None, "cols.sort", None, "df")
t.run()
# Out:
# Creating test_cols_sort() test function...
# INFO:optimus:test_cols_sort()
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="[8.53439998626709,&#8901;4300.0]">[8.53439998626709,&#8901;4300.0]
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" color:#0000FF" title="True">True
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="1980/04/10">1980/04/10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="2016-09-10">2016-09-10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="bytearray(b'Leader')">bytearray(
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.sort", "desc", "df", None,"desc")
# Out:
# Creating test_cols_sort_desc() test function...
# INFO:optimus:test_cols_sort_desc()
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="2014-06-24&#8901;00:00:00">2014-06-24&#8901;00:00:00
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="color:#0000FF " title="None">None
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="19.442735,-99.201111">19.442735,-99.201111
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="2016/09/10">2016/0

# %%
t.create(None, "cols.sort", "asc", "df", None, "asc")
# Out:
# Creating test_cols_sort_asc() test function...
# INFO:optimus:test_cols_sort_asc()
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="[8.53439998626709,&#8901;4300.0]">[8.53439998626709,&#8901;4300.0]
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" color:#0000FF" title="True">True
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="1980/04/10">1980/04/10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="2016-09-10">2016-09-10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="bytearray(b'Leader')">bytearray(

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.fill_na", None, "df", numeric_col, "1")
# Out:
# Creating test_cols_fill_na() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26.0'>26.0</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div ti

# %%
t.create(None, "cols.fill_na", "array", "df", None, "japanese name", ["1","2"])
# Out:
# Creating test_cols_fill_na_array() test function...
# INFO:optimus:test_cols_fill_na_array()
# INFO:optimus:Using 'column_exp' to process column 'japanese name' with function func_col_exp
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28">
#
#                 -28
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10">
#
#                 10
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000">
#
#                 5000000
#
#             </

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.fill_na", "bool", "df", "Cybertronian", None, False)
# Out:
# Creating test_cols_fill_na_bool() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26'>26</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.fill_na", "all_columns", "df", ["names","height(ft)", "function", "rank", "age"], "2")
# Out:
# Creating test_cols_fill_na_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28.0'>-28.0</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10.0'>10.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17.0'>17.0</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='26.0'>26.0</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7.0'>7.0</div>
#         </td>
#
#         <td>
#             <div title='5000000.0'>5000000.0</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>

# %% [markdown]
# ## Nest

# %%
t.create(None, "cols.nest", None, "df", None, [numeric_col, numeric_col_B], separator=" ",output_col=new_col)
# Out:
# Creating test_cols_nest() test function...
# INFO:optimus:test_cols_nest()
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function func_col_exp
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">new col</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">17 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0

# %%
# t.create(None, "cols.nest", "mix", "df", [F.col(numeric_col_C), F.col(numeric_col_B)], "E", separator="--")

# %%
df_na = source_df.cols.drop("NullType").rows.drop_na("*")

t.create(df_na, "cols.nest", "vector_all_columns", "df", None,[numeric_col_C, numeric_col_B], shape="vector", output_col=new_col)
# Out:
# Creating test_cols_nest_vector_all_columns() test function...
# INFO:optimus:test_cols_nest_vector_all_columns()
# ['rank']
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 4 of 4 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">new col</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (vector)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
t.create(df_na, "cols.nest", "vector", "df", None, [numeric_col_C, numeric_col_B], shape="vector",output_col=new_col)
# Out:
# Creating test_cols_nest_vector() test function...
# INFO:optimus:test_cols_nest_vector()
# ['rank']
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 4 of 4 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">new col</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (vector)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
t.create(None, "cols.nest", "array", "df", None, [numeric_col, numeric_col_B,numeric_col_C], shape="array", output_col=new_col)
# Out:
# Creating test_cols_nest_array() test function...
# INFO:optimus:test_cols_nest_array()
# INFO:optimus:Using 'column_exp' to process column 'names' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'function' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'rank' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'age' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'weight(t)' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'japanese name' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'last position seen' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'date arrival' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'last date seen' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'attributes' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Date Type' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'timestamp' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Cybertronian' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'function(binary)' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'NullType' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function func_col_exp
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">new col</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">17 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">

# %%
t.create(None, "cols.count_by_dtypes", None, "json", None, "*", infer=False)
# Out:
# Creating test_cols_count_by_dtypes() test function...
# INFO:optimus:test_cols_count_by_dtypes()
# {'names': {'int': 0, 'decimal': 0, 'string': 6, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'height(ft)': {'int': 5, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 2, 'missing': 0}, 'function': {'int': 0, 'decimal': 0, 'string': 6, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'rank': {'int': 6, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'age': {'int': 6, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'weight(t)': {'int': 0, 'decimal': 5, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 2, 'missing': 0}, 'japanese name': {'int': 0, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'last position seen': {'int': 0, 'decimal': 0, 'string': 4, 'date': 0, 'boolean': 0, 'array': 0, 'null': 3, 'missing': 0}, 'date arrival': {'int': 0, 'decimal': 0, 'string': 6, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'last date seen': {'int': 0, 'decimal': 0, 'string': 6, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'attributes': {'int': 0, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'Date Type': {'int': 0, 'decimal': 0, 'string': 0, 'date': 6, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'timestamp': {'int': 0, 'decimal': 0, 'string': 0, 'date': 6, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'Cybertronian': {'int': 0, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'function(binary)': {'int': 0, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1, 'missing': 0}, 'NullType': {'int': 0, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 7, 'missing': 0}}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
dtypes_df = op.create.df(
    [
        ("col 1", "str", True),
        ("col 2", "str", True),
        ("col 3", "int", True),
    
    ],
    [
        ("male","male",1),
        ("optimus","bumblebee",1),
        ("3","4.1",1),
        ("true","False",1),
        ("[1,2,3,4]","(1,2,3,4)",1),
        ("{1,2,3,4}","{'key1' :1 , 'key2':2}",1),
        ("1.1.1.1","123.123.123.123",1),
        ("http://hi-optimuse.com","https://hi-bumblebee.com",1),
        ("optimus@cybertron.com","bumblebee@cybertron.com",1),
        ("5123456789123456","373655783158306",1),
        ("11529","30345",1),
        ("04/10/1980","04/10/1980",1),
        ("null","Null",1),
        ("","",1),
        (None,None,1) 
       
    ], infer_schema=True)

# %%
t.create(dtypes_df, "cols.count_by_dtypes", "infer", "json", None, "*", infer=True)
# Out:
# Creating test_cols_count_by_dtypes_infer() test function...
# INFO:optimus:test_cols_count_by_dtypes_infer()
# {'col 1': {'gender': 1, 'string': 1, 'int': 1, 'boolean': 1, 'array': 1, 'object': 1, 'ip': 1, 'url': 1, 'email': 1, 'credit_card_number': 1, 'zip_code': 1, 'date': 1, 'null': 2, 'missing': 1, 'decimal': 0}, 'col 2': {'gender': 1, 'string': 1, 'decimal': 1, 'boolean': 1, 'array': 1, 'object': 1, 'ip': 1, 'url': 1, 'email': 1, 'credit_card_number': 1, 'zip_code': 1, 'date': 1, 'null': 2, 'missing': 1, 'int': 0}, 'col 3': {'int': 15, 'decimal': 0, 'string': 0, 'boolean': 0, 'date': 0, 'array': 0, 'object': 0, 'gender': 0, 'ip': 0, 'url': 0, 'email': 0, 'credit_card_number': 0, 'zip_code': 0, 'null': 0, 'missing': 0}}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(dtypes_df, "cols.count_by_dtypes", None, "json", None, "*", infer=False)
# Out:
# Creating test_cols_count_by_dtypes() test function...
# INFO:optimus:test_cols_count_by_dtypes()
# {'col 1': {'int': 0, 'decimal': 0, 'string': 14, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1}, 'col 2': {'int': 0, 'decimal': 0, 'string': 14, 'date': 0, 'boolean': 0, 'array': 0, 'null': 1}, 'col 3': {'int': 15, 'decimal': 0, 'string': 0, 'date': 0, 'boolean': 0, 'array': 0, 'null': 0}}

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
t.create(None, "cols.unnest", "array_all_columns", "df", array_col, "-", index=1)
# Out:
# Creating test_cols_unnest_array_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 18 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_0</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_1</div>
#             <div class="data_type">18 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='8.53439998626709'>8.53439998626709</div>
#         </td>
#
#         <td>
#             <div title='4300.0'>4300.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;

# %%
t.create(None, "cols.unnest", "array", "df", array_col)
# Out:
# Creating test_cols_unnest_array() test function...
# <div class="info_items">Viewing 7 of 7 rows / 18 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_0</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_1</div>
#             <div class="data_type">18 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='8.53439998626709'>8.53439998626709</div>
#         </td>
#
#         <td>
#             <div title='4300.0'>4300.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;

# %%
t.create(None, "cols.unnest", "array_all_columns", "df", array_col)
# Out:
# Creating test_cols_unnest_array_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 18 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_0</div>
#             <div class="data_type">17 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes_1</div>
#             <div class="data_type">18 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#         <td>
#             <div title='8.53439998626709'>8.53439998626709</div>
#         </td>
#
#         <td>
#             <div title='4300.0'>4300.0</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='17'>17</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;

# %%
t.create(None, "cols.is_na", "all_columns", "df", "*")
# Out:
# Creating test_cols_is_na_all_columns() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='Fal

# %%
t.create(None, "cols.is_na", None, "df", numeric_col)
# Out:
# Creating test_cols_is_na() test function...
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (boolean)</div>
#             <div class="data_type">
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div title='10'>10</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div title='True'>True</div>
#         </td>
#
#         <td>
#             <div title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div title='False'>False</div>
#         </td>
#
#         <td>
#             <div title='Security'>Security</div>
#         </td>
#
#         <td>
#             <div title='7'>7</div>
#         </td>
#
#         <td>
#             <div title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div title='4.0'>4.0</div>
#         </td>
#
#         <td>
#             <div title='[&#39;Roadbuster&#39;]'>[&#39;Ro

# %%
t.run()
# Out:
# Creating file ../test_df_cols.py
# Done

# %%
from pyspark.sql.types import *
from optimus import Optimus
from optimus.helpers.json import json_enconding
from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector
import numpy as np
nan = np.nan
import datetime

# %%
actual_df =op.load.json('https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.json')
expected_df = op.create.df([('billingId', LongType(), True),('birth', StringType(), True),('dummyCol', StringType(), True),('firstName', StringType(), True),('id', LongType(), True),('lastName', StringType(), True),('price', LongType(), True),('product', StringType(), True)], [(123, '1980/07/07', 'never', 'Luis', 1, 'Alvarez$$%!', 10, 'Cake')])

# assert (expected_df.collect() == actual_df.collect())

from deepdiff import DeepDiff  # For Deep Difference of 2 objects

actual_df.table()
expected_df.table()

# source_df.table()
# print(actual_df.to_json())
# print(expected_df.to_json())
a1 = actual_df.to_json()
e1 = expected_df.to_json()
# Out:
# <div class="info_items">Viewing 19 of 19 rows / 8 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">1 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">5 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">price</div>
#             <div class="data_type">7 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='123'>123</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/07/07'>1980/07/07</div>
#         </td>
#
#         <td>
#             <div class="" title='never'>never</div>
#         </td>
#
#         <td>
#             <div class="" title='Luis'>Luis</div>
#         </td>
#
#         <td>
#             <div class="" title='1'>1</div>
#         </td>
#
#         <td>
#             <div class="" title='Alvarez$$%!'>Alvarez$$%!</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='Cake'>Cake</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='423'>423</div>
#         </td>
#
#         <td>
#             <div class="" title='1950/07/08'>1950/07/08</div>
#         </td>
#
#         <td>
#             <div class="" title='gonna'>gonna</div>
#         </td>
#
#         <td>
#             <div class="" title='André'>André</div>
#         </td>
#
#         <td>
#             <div class="" title='2'>2</div>
#         </td>
#
#         <td>
#             <div class="" title='Ampère'>Ampère</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='piza'>piza</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='551'>551</div>
#         </td>
#
#         <td>
#             <div class="" title='1990/07/09'>1990/07/09</div>
#         </td>
#
#         <td>
#             <div class="" title='give'>give</div>
#         </td>
#
#         <td>
#             <div class="" title='NiELS'>NiELS</div>
#         </td>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>
#
#         <td>
#             <div class="" title='Böhr//((%%'>Böhr//((%%</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='521'>521</div>
#         </td>
#
#         <td>
#             <div class="" title='1954/07/10'>1954/07/10</div>
#         </td>
#
#         <td>
#             <div class="" title='you'>you</div>
#         </td>
#
#         <td>
#             <div class="" title='PAUL'>PAUL</div>
#         </td>
#
#         <td>
#             <div class="" title='4'>4</div>
#         </td>
#
#         <td>
#             <div class="" title='dirac$'>dirac$</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='634'>634</div>
#         </td>
#
#         <td>
#             <div class="" title='1990/07/11'>1990/07/11</div>
#         </td>
#
#         <td>
#             <div class="" title='up'>up</div>
#         </td>
#
#         <td>
#             <div class="" title='Albert'>Albert</div>
#         </td>
#
#         <td>
#             <div class="" title='5'>5</div>
#         </td>
#
#         <td>
#             <div class="" title='Einstein'>Einstein</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='672'>672</div>
#         </td>
#
#         <td>
#             <div class="" title='1930/08/12'>1930/08/12</div>
#         </td>
#
#         <td>
#             <div class="" title='never'>never</div>
#         </td>
#
#         <td>
#             <div class="" title='Galileo'>Galileo</div>
#         </td>
#
#         <td>
#             <div class="" title='6'>6</div>
#         </td>
#
#         <td>
#             <div class="" title='⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI'>⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI</div>
#         </td>
#
#         <td>
#             <div class="" title='5'>5</div>
#         </td>
#
#         <td>
#             <div class="" title='arepa'>arepa</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='323'>323</div>
#         </td>
#
#         <td>
#             <div class="" title='1970/07/13'>1970/07/13</div>
#         </td>
#
#         <td>
#             <div class="" title='gonna'>gonna</div>
#         </td>
#
#         <td>
#             <div class="" title='CaRL'>CaRL</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='Ga%%%uss'>Ga%%%uss</div>
#         </td>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>
#
#         <td>
#             <div class="" title='taco'>taco</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='624'>624</div>
#         </td>
#
#         <td>
#             <div class="" title='1950/07/14'>1950/07/14</div>
#         </td>
#
#         <td>
#             <div class="" title='let'>let</div>
#         </td>
#
#         <td>
#             <div class="" title='David'>David</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='H$$$ilbert'>H$$$ilbert</div>
#         </td>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>
# <div class="info_items">Viewing 1 of 1 rows / 8 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">1 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">5 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">price</div>
#             <div class="data_type">7 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='123'>123</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/07/07'>1980/07/07</div>
#         </td>
#
#         <td>
#             <div class="" title='never'>never</div>
#         </td>
#
#         <td>
#             <div class="" title='Luis'>Luis</div>
#         </td>
#
#         <td>
#             <div class="" title='1'>1</div>
#         </td>
#
#         <td>
#             <div class="" title='Alvarez$$%!'>Alvarez$$%!</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='Cake'>Cake</div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 1 of 1 rows / 8 columns</div>
# <div class="info_items">8 partition(s)</div>

# %%
ddiff = DeepDiff(a1, e1, ignore_order=False)
print(ddiff)
# Out:
# {'iterable_item_removed': {'root[12]': {'billingId': 111, 'birth': '1994/01/04', 'dummyCol': 'run ', 'firstName': 'Max!!!', 'id': 13, 'lastName': 'Planck!!!', 'price': 4, 'product': 'hamburguer'}, 'root[14]': {'billingId': 116, 'birth': '1956/11/30', 'dummyCol': 'and', 'firstName': '(((   Heinrich )))))', 'id': 15, 'lastName': 'Hertz', 'price': 8, 'product': 'pizza'}, 'root[15]': {'billingId': 886, 'birth': '1958/03/26', 'dummyCol': 'desert', 'firstName': 'William', 'id': 16, 'lastName': 'Gilbert###', 'price': 2, 'product': 'BEER'}, 'root[13]': {'billingId': 553, 'birth': '1997/06/27', 'dummyCol': 'around', 'firstName': 'Fred', 'id': 14, 'lastName': 'Hoy&&&le', 'price': 8, 'product': 'pizzza'}, 'root[2]': {'billingId': 551, 'birth': '1990/07/09', 'dummyCol': 'give', 'firstName': 'NiELS', 'id': 3, 'lastName': 'Böhr//((%%', 'price': 8, 'product': 'pizza'}, 'root[1]': {'billingId': 423, 'birth': '1950/07/08', 'dummyCol': 'gonna', 'firstName': 'André', 'id': 2, 'lastName': 'Ampère', 'price': 8, 'product': 'piza'}, 'root[4]': {'billingId': 634, 'birth': '1990/07/11', 'dummyCol': 'up', 'firstName': 'Albert', 'id': 5, 'lastName': 'Einstein', 'price': 8, 'product': 'pizza'}, 'root[5]': {'billingId': 672, 'birth': '1930/08/12', 'dummyCol': 'never', 'firstName': 'Galileo', 'id': 6, 'lastName': '             GALiLEI', 'price': 5, 'product': 'arepa'}, 'root[8]': {'billingId': 735, 'birth': '1920/04/22', 'dummyCol': 'you', 'firstName': 'Johannes', 'id': 9, 'lastName': 'KEPLER', 'price': 3, 'product': 'taco'}, 'root[9]': {'billingId': 875, 'birth': '1923/03/12', 'dummyCol': 'down', 'firstName': 'JaMES', 'id': 10, 'lastName': 'M$$ax%%well', 'price': 3, 'product': 'taco'}, 'root[18]': {'billingId': 467, 'birth': '1921/05/03', 'dummyCol': '#', 'firstName': 'JAMES', 'id': 19, 'lastName': 'Chadwick', 'price': 10, 'product': 'null'}, 'root[11]': {'billingId': 234, 'birth': '1993/12/08', 'dummyCol': 'gonna', 'firstName': 'Emmy%%', 'id': 12, 'lastName': 'Nöether$', 'price': 9, 'product': 'pasta'}, 'root[17]': {'billingId': 812, 'birth': '1899/01/01', 'dummyCol': '#', 'firstName': 'Arthur', 'id': 18, 'lastName': 'COM%%%pton', 'price': 5, 'product': '110790'}, 'root[16]': {'billingId': 912, 'birth': '2000/03/22', 'dummyCol': 'you', 'firstName': 'Marie', 'id': 17, 'lastName': 'CURIE', 'price': 1, 'product': 'Rice'}, 'root[7]': {'billingId': 624, 'birth': '1950/07/14', 'dummyCol': 'let', 'firstName': 'David', 'id': 8, 'lastName': 'H$$$ilbert', 'price': 3, 'product': 'taaaccoo'}, 'root[3]': {'billingId': 521, 'birth': '1954/07/10', 'dummyCol': 'you', 'firstName': 'PAUL', 'id': 4, 'lastName': 'dirac$', 'price': 8, 'product': 'pizza'}, 'root[10]': {'billingId': 992, 'birth': '1999/02/15', 'dummyCol': 'never ', 'firstName': 'Isaac', 'id': 11, 'lastName': 'Newton', 'price': 9, 'product': 'pasta'}, 'root[6]': {'billingId': 323, 'birth': '1970/07/13', 'dummyCol': 'gonna', 'firstName': 'CaRL', 'id': 7, 'lastName': 'Ga%%%uss', 'price': 3, 'product': 'taco'}}}

# %%
# Out:
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Match'>Match</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Match'>Match</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""

# %% [markdown]
# # Rows Test

# %%
t = Test(op,df, "df_rows", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                         "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F",
                                        "from optimus.functions import abstract_udf as audf"])

# %%
rows = [
        ("Optim'us", 28, "Leader", 10, 5000000, 4.30, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
         "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True, bytearray("Leader", "utf-8"),
         None)
]

# %%
df = op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.csv")

# %%
t = Test(op, source_df, "op_io", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                        "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F"],path = "op_io", final_path="..")

# %%
t.create(op, "load.csv", "local_csv", "df", "../../examples/data/foo.csv")
t.create(op, "load.json", "local_json", "df", "../../examples/data/foo.json")
t.create(op, "load.parquet", "local_parquet", "df", "../../examples/data/foo.parquet")
t.create(op, "load.csv", "remote_csv", "df", "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.csv")

# %%
t.create(op, "load.json", "remote_json", "df", "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.json")
# Out:
# Creating test_load_json_remote_json() test function...
# <div class="info_items">Viewing 19 of 19 rows / 8 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">1 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">5 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">price</div>
#             <div class="data_type">7 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='123'>123</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/07/07'>1980/07/07</div>
#         </td>
#
#         <td>
#             <div class="" title='never'>never</div>
#         </td>
#
#         <td>
#             <div class="" title='Luis'>Luis</div>
#         </td>
#
#         <td>
#             <div class="" title='1'>1</div>
#         </td>
#
#         <td>
#             <div class="" title='Alvarez$$%!'>Alvarez$$%!</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='Cake'>Cake</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='423'>423</div>
#         </td>
#
#         <td>
#             <div class="" title='1950/07/08'>1950/07/08</div>
#         </td>
#
#         <td>
#             <div class="" title='gonna'>gonna</div>
#         </td>
#
#         <td>
#             <div class="" title='André'>André</div>
#         </td>
#
#         <td>
#             <div class="" title='2'>2</div>
#         </td>
#
#         <td>
#             <div class="" title='Ampère'>Ampère</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='piza'>piza</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='551'>551</div>
#         </td>
#
#         <td>
#             <div class="" title='1990/07/09'>1990/07/09</div>
#         </td>
#
#         <td>
#             <div class="" title='give'>give</div>
#         </td>
#
#         <td>
#             <div class="" title='NiELS'>NiELS</div>
#         </td>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>
#
#         <td>
#             <div class="" title='Böhr//((%%'>Böhr//((%%</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='521'>521</div>
#         </td>
#
#         <td>
#             <div class="" title='1954/07/10'>1954/07/10</div>
#         </td>
#
#         <td>
#             <div class="" title='you'>you</div>
#         </td>
#
#         <td>
#             <div class="" title='PAUL'>PAUL</div>
#         </td>
#
#         <td>
#             <div class="" title='4'>4</div>
#         </td>
#
#         <td>
#             <div class="" title='dirac$'>dirac$</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='634'>634</div>
#         </td>
#
#         <td>
#             <div class="" title='1990/07/11'>1990/07/11</div>
#         </td>
#
#         <td>
#             <div class="" title='up'>up</div>
#         </td>
#
#         <td>
#             <div class="" title='Albert'>Albert</div>
#         </td>
#
#         <td>
#             <div class="" title='5'>5</div>
#         </td>
#
#         <td>
#             <div class="" title='Einstein'>Einstein</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='672'>672</div>
#         </td>
#
#         <td>
#             <div class="" title='1930/08/12'>1930/08/12</div>
#         </td>
#
#         <td>
#             <div class="" title='never'>never</div>
#         </td>
#
#         <td>
#             <div class="" title='Galileo'>Galileo</div>
#         </td>
#
#         <td>
#             <div class="" title='6'>6</div>
#         </td>
#
#         <td>
#             <div class="" title='⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI'>⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI</div>
#         </td>
#
#         <td>
#             <div class="" title='5'>5</div>
#         </td>
#
#         <td>
#             <div class="" title='arepa'>arepa</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='323'>323</div>
#         </td>
#
#         <td>
#             <div class="" title='1970/07/13'>1970/07/13</div>
#         </td>
#
#         <td>
#             <div class="" title='gonna'>gonna</div>
#         </td>
#
#         <td>
#             <div class="" title='CaRL'>CaRL</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='Ga%%%uss'>Ga%%%uss</div>
#         </td>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>
#
#         <td>
#             <div class="" title='taco'>taco</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='624'>624</div>
#         </td>
#
#         <td>
#             <div class="" title='1950/07/14'>1950/07/14</div>
#         </td>
#
#         <td>
#             <div class="" title='let'>let</div>
#         </td>
#
#         <td>
#             <div class="" title='David'>David</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='H$$$ilbert'>H$$$ilbert</div>
#         </td>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>

# %%
t.create(op, "load.parquet", "remote_parquet", "df", "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.parquet")
# Out:
# Creating test_load_parquet_remote_parquet() test function...
# <div class="info_items">Viewing 19 of 19 rows / 8 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">firstName</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">lastName</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">billingId</div>
#             <div class="data_type">4 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">product</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">price</div>
#             <div class="data_type">6 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">birth</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">dummyCol</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='1'>1</div>
#         </td>
#
#         <td>
#             <div class="" title='Luis'>Luis</div>
#         </td>
#
#         <td>
#             <div class="" title='Alvarez$$%!'>Alvarez$$%!</div>
#         </td>
#
#         <td>
#             <div class="" title='123'>123</div>
#         </td>
#
#         <td>
#             <div class="" title='Cake'>Cake</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/07/07'>1980/07/07</div>
#         </td>
#
#         <td>
#             <div class="" title='never'>never</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='2'>2</div>
#         </td>
#
#         <td>
#             <div class="" title='André'>André</div>
#         </td>
#
#         <td>
#             <div class="" title='Ampère'>Ampère</div>
#         </td>
#
#         <td>
#             <div class="" title='423'>423</div>
#         </td>
#
#         <td>
#             <div class="" title='piza'>piza</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='1950/07/08'>1950/07/08</div>
#         </td>
#
#         <td>
#             <div class="" title='gonna'>gonna</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>
#
#         <td>
#             <div class="" title='NiELS'>NiELS</div>
#         </td>
#
#         <td>
#             <div class="" title='Böhr//((%%'>Böhr//((%%</div>
#         </td>
#
#         <td>
#             <div class="" title='551'>551</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='1990/07/09'>1990/07/09</div>
#         </td>
#
#         <td>
#             <div class="" title='give'>give</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='4'>4</div>
#         </td>
#
#         <td>
#             <div class="" title='PAUL'>PAUL</div>
#         </td>
#
#         <td>
#             <div class="" title='dirac$'>dirac$</div>
#         </td>
#
#         <td>
#             <div class="" title='521'>521</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='1954/07/10'>1954/07/10</div>
#         </td>
#
#         <td>
#             <div class="" title='you'>you</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='5'>5</div>
#         </td>
#
#         <td>
#             <div class="" title='Albert'>Albert</div>
#         </td>
#
#         <td>
#             <div class="" title='Einstein'>Einstein</div>
#         </td>
#
#         <td>
#             <div class="" title='634'>634</div>
#         </td>
#
#         <td>
#             <div class="" title='pizza'>pizza</div>
#         </td>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='1990/07/11'>1990/07/11</div>
#         </td>
#
#         <td>
#             <div class="" title='up'>up</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='6'>6</div>
#         </td>
#
#         <td>
#             <div class="" title='Galileo'>Galileo</div>
#         </td>
#
#         <td>
#             <div class="" title='⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI'>⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱⸱GALiLEI</div>
#         </td>
#
#         <td>
#             <div class="" title='672'>672</div>
#         </td>
#
#         <td>
#             <div class="" title='arepa'>arepa</div>
#         </td>
#
#         <td>
#             <div class="" title='5'>5</div>
#         </td>
#
#         <td>
#             <div class="" title='1930/08/12'>1930/08/12</div>
#         </td>
#
#         <td>
#             <div class="" title='never'>never</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='CaRL'>CaRL</div>
#         </td>
#
#         <td>
#             <div class="" title='Ga%%%uss'>Ga%%%uss</div>
#         </td>
#
#         <td>
#             <div class="" title='323'>323</div>
#         </td>
#
#         <td>
#             <div class="" title='taco'>taco</div>
#         </td>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>
#
#         <td>
#             <div class="" title='1970/07/13'>1970/07/13</div>
#         </td>
#
#         <td>
#             <div class="" title='gonna'>gonna</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='8'>8</div>
#         </td>
#
#         <td>
#             <div class="" title='David'>David</div>
#         </td>
#
#         <td>
#             <div class="" title='H$$$ilbert'>H$$$ilbert</div>
#         </td>
#
#         <td>
#             <div class="" title='624'>624</div>
#         </td>
#
#         <td>
#             <div class="" title='taaaccoo'>taaaccoo</div>
#         </td>
#
#         <td>
#             <div class="" title='3'>3</div>
#         </td>
#
#         <td>
#             <div class="" title='1950/07/14'>1950/07/14</div>
#         </td>

# %%
# df_string = source_df.cols.cast("*","str")
t.create(source_df, "save.csv", None, None, "test.csv")
# Out:
# Creating test_save_csv() test function...
# `names`,`height(ft)`,`function`,`rank`,`age`,`weight(t)`,`last position seen`,`date arrival`,`last date seen`,`Tiemstamp`,`Cybertronian` column(s) was not processed because is/are not date,array,vector,binary,null

# %%
t.create(None, "save.json", None, None, "test.json")
# Out:
# Creating test_save_json() test function...

# %%
t.create(None, "save.parquet", None, None, "test.parquet")
# Out:
# Creating test_save_parquet() test function...
# `names`,`height(ft)`,`function`,`rank`,`age`,`weight(t)`,`japanese name`,`last position seen`,`date arrival`,`last date seen`,`attributes`,`Date Type`,`Tiemstamp`,`Cybertronian`,`function(binary)` column(s) was not processed because is/are not null

# %%
t.run()
# Out:
# Creating file ../test_op_io.py
# Done

# %%
source_df.table()
# Out:
# <div class="info_items">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items">8 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">names</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">height(ft)</div>
#             <div class="data_type">2 (smallint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">rank</div>
#             <div class="data_type">4 (tinyint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">age</div>
#             <div class="data_type">5 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">weight(t)</div>
#             <div class="data_type">6 (float)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">japanese name</div>
#             <div class="data_type">7 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last position seen</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">date arrival</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">last date seen</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">attributes</div>
#             <div class="data_type">11 (array&lt;float&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Date Type</div>
#             <div class="data_type">12 (date)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tiemstamp</div>
#             <div class="data_type">13 (timestamp)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Cybertronian</div>
#             <div class="data_type">14 (boolean)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">function(binary)</div>
#             <div class="data_type">15 (binary)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NullType</div>
#             <div class="data_type">16 (null)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class="" title='Optim&#39;us'>Optim&#39;us</div>
#         </td>
#
#         <td>
#             <div class="" title='-28'>-28</div>
#         </td>
#
#         <td>
#             <div class="" title='Leader'>Leader</div>
#         </td>
#
#         <td>
#             <div class="" title='10'>10</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='4.300000190734863'>4.300000190734863</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]'>[&#39;Inochi&#39;,⸱&#39;Convoy&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='19.442735,-99.201111'>19.442735,-99.201111</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2016/09/10'>2016/09/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[8.53439998626709,⸱4300.0]'>[8.53439998626709,⸱4300.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2016-09-10'>2016-09-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Leader&#39;)'>bytearray(b&#39;Leader&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='bumbl#ebéé⸱⸱'>bumbl#ebéé⸱⸱</div>
#         </td>
#
#         <td>
#             <div class="" title='17'>17</div>
#         </td>
#
#         <td>
#             <div class="" title='Espionage'>Espionage</div>
#         </td>
#
#         <td>
#             <div class="" title='7'>7</div>
#         </td>
#
#         <td>
#             <div class="" title='5000000'>5000000</div>
#         </td>
#
#         <td>
#             <div class="" title='2.0'>2.0</div>
#         </td>
#
#         <td>
#             <div class="" title='[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]'>[&#39;Bumble&#39;,⸱&#39;Goldback&#39;]</div>
#         </td>
#
#         <td>
#             <div class="" title='10.642707,-71.612534'>10.642707,-71.612534</div>
#         </td>
#
#         <td>
#             <div class="" title='1980/04/10'>1980/04/10</div>
#         </td>
#
#         <td>
#             <div class="" title='2015/08/10'>2015/08/10</div>
#         </td>
#
#         <td>
#             <div class="" title='[5.334000110626221,⸱2000.0]'>[5.334000110626221,⸱2000.0]</div>
#         </td>
#
#         <td>
#             <div class="" title='2015-08-10'>2015-08-10</div>
#         </td>
#
#         <td>
#             <div class="" title='2014-06-24⸱00:00:00'>2014-06-24⸱00:00:00</div>
#         </td>
#
#         <td>
#             <div class="" title='True'>True</div>
#         </td>
#
#         <td>
#             <div class="" title='bytearray(b&#39;Espionage&#39;)'>bytearray(b&#39;Espionage&#39;)</div>
#         </td>
#
#         <td>
#             <div class=" none " title='None'>None</div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class="" title='ironhide&amp;'>ironhide&amp;</div>
#         </td>
#
#         <td>
#             <div class="" title='26'>26</div>
#         </td>
#
#         <td>
#             <div class=""

# %% [markdown]
# # Ouliers

# %%
t = Test(op, source_df, "df_outliers", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                        "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F"], path = "df_outliers", final_path="..")

# %%
from pyspark.sql import functions as F


def func(col_name, attrs):
    return F.col(col_name) * 2

numeric_col = "height(ft)"
numeric_col_B = "rank"
numeric_col_C = "rank"
string_col = "function"
date_col = "date arrival"
date_col_B = "last date seen"
new_col = "new col"
array_col = "attributes"

# %% [markdown]
# ## Tukey

# %%
t.create(None, "outliers.tukey", None, "df","select", numeric_col)
# Out:
# Creating test_outliers_tukey_select() test function...
# INFO:optimus:test_outliers_tukey_select()
# INFO:optimus:percentile() executed in 2.59 sec
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 2 of 2 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
t.create(None, "outliers.tukey", None, "df","drop", numeric_col)
# Out:
# Creating test_outliers_tukey_drop() test function...
# INFO:optimus:test_outliers_tukey_drop()
# INFO:optimus:percentile() executed in 1.76 sec
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 3 of 3 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="bumbl#ebéé&#8901;&#8901;">bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="17">17
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Espionage">Espionage
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="7">7
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="2.0">2.0
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Bumble',&#8901;'Goldback']">['Bumble',&#8901;'Goldback']
#             </div>
#         </td>

# %%
t.create(None, "outliers.tukey", None, "json", "whiskers", numeric_col)
# Out:
# Creating test_outliers_tukey_whiskers() test function...
# INFO:optimus:test_outliers_tukey_whiskers()
# INFO:optimus:percentile() executed in 1.68 sec
# {'lower_bound': -6.5, 'upper_bound': 45.5, 'iqr1': 13, 'iqr3': 26}

# %%
t.create(None, "outliers.tukey", None, "json", "count", numeric_col)
# Out:
# Creating test_outliers_tukey_count() test function...
# INFO:optimus:test_outliers_tukey_count()
# 7

# %%
t.create(None, "outliers.tukey", None, "json", "non_outliers_count", numeric_col)
# Out:
# Creating test_outliers_tukey_non_outliers_count() test function...
# INFO:optimus:test_outliers_tukey_non_outliers_count()
# INFO:optimus:percentile() executed in 1.63 sec
# 3

# %%
t.create(None, "outliers.tukey", None, "json", "info", numeric_col)
# Out:
# Creating test_outliers_tukey_info() test function...
# INFO:optimus:test_outliers_tukey_info()
# INFO:optimus:percentile() executed in 1.66 sec
# INFO:optimus:percentile() executed in 1.62 sec
# {'count_outliers': 7, 'count_non_outliers': 3, 'lower_bound': -6.5, 'upper_bound': 45.5, 'iqr1': 13, 'iqr3': 26}

# %%
t.run()
# Out:
# Creating file ../test_df_outliers.py
# Done

# %% [markdown]
# ## Zscore

# %%
threshold = 0.5

# %%
t.create(None, "outliers.z_score", None, "df","select", numeric_col, threshold)
# Out:
# Creating test_outliers_z_score_select() test function...
# INFO:optimus:test_outliers_z_score_select()
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _z_score
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 2 of 2 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
source_df.outliers.z_score('height(ft)',0.5).select()
# Out:
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _z_score
# DataFrame[names: string, height(ft): smallint, function: string, rank: tinyint, age: int, weight(t): float, japanese name: array<string>, last position seen: string, date arrival: string, last date seen: string, attributes: array<float>, Date Type: date, timestamp: timestamp, Cybertronian: boolean, function(binary): binary, NullType: null]

# %%
t.create(None, "outliers.z_score", None, "df","drop", numeric_col, threshold)
# Out:
# Creating test_outliers_z_score_drop() test function...
# INFO:optimus:test_outliers_z_score_drop()
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _z_score
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 3 of 3 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="bumbl#ebéé&#8901;&#8901;">bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="17">17
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Espionage">Espionage
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="7">7
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="2.0">2.0
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Bumble',&#8901;'Goldback']">['Bumble',&#8901;'Goldback']
#             </div>
#         </td>

# %%
t.create(None, "outliers.z_score", None, "json", "count", numeric_col, threshold)
# Out:
# Creating test_outliers_z_score_count() test function...
# INFO:optimus:test_outliers_z_score_count()
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _z_score
# 2

# %%
t.create(None, "outliers.z_score", None, "json", "non_outliers_count", numeric_col, threshold)
# Out:
# Creating test_outliers_z_score_non_outliers_count() test function...
# INFO:optimus:test_outliers_z_score_non_outliers_count()
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _z_score
# 3

# %%
t.create(None, "outliers.z_score", None, "json", "info", numeric_col, threshold)
# Out:
# Creating test_outliers_z_score_info() test function...
# INFO:optimus:test_outliers_z_score_info()
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _z_score
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _z_score
# INFO:optimus:Using 'column_exp' to process column 'height(ft)' with function _z_score
# {'count_outliers': 2, 'count_non_outliers': 3, 'max_z_score': 1.76684}

# %%
t.run()
# Out:
# Creating file ../test_df_outliers.py
# Done

# %% [markdown]
# ## Modified Zscore

# %%
threshold = 0.5
relative_error = 10000

# %%
t.create(None, "outliers.modified_z_score", None, "df","select", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_modified_z_score_select() test function...
# INFO:optimus:test_outliers_modified_z_score_select()
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 3 of 3 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
t.create(None, "outliers.modified_z_score", None, "df","drop", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_modified_z_score_drop() test function...
# INFO:optimus:test_outliers_modified_z_score_drop()
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 2 of 2 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="bumbl#ebéé&#8901;&#8901;">bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="17">17
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Espionage">Espionage
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="7">7
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="2.0">2.0
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Bumble',&#8901;'Goldback']">['Bumble',&#8901;'Goldback']
#             </div>
#         </td>

# %%
t.create(None, "outliers.modified_z_score", None, "json","count", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_modified_z_score_count() test function...
# INFO:optimus:test_outliers_modified_z_score_count()
# 3

# %%
t.create(None, "outliers.modified_z_score", None, "json","non_outliers_count", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_modified_z_score_non_outliers_count() test function...
# INFO:optimus:test_outliers_modified_z_score_non_outliers_count()
# 2

# %%
t.create(None, "outliers.modified_z_score", None, "json","info", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_modified_z_score_info() test function...
# INFO:optimus:test_outliers_modified_z_score_info()
# {'count_outliers': 3, 'count_non_outliers': 2, 'max_m_z_score': 21.20928}

# %%
t.run()
# Out:
# Creating file ../test_df_outliers.py
# Done

# %% [markdown]
# ## Mad

# %%
threshold = 0.5
relative_error = 10000

# %%
t.create(None, "outliers.mad", None, "df","select", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_mad_select() test function...
# INFO:optimus:test_outliers_mad_select()
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 3 of 3 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="Optim'us">Optim'us
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="-28">-28
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Leader">Leader
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="10">10
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="4.300000190734863">4.300000190734863
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Inochi',&#8901;'Convoy']">['Inochi',&#8901;'Convoy']
#             </div>
#         </td>

# %%
t.create(None, "outliers.mad", None, "df","drop", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_mad_drop() test function...
# INFO:optimus:test_outliers_mad_drop()
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 2 of 2 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s)</div>
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (smallint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (tinyint)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (int)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (array&lt;string&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (string)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (array&lt;float&gt;)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (date)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (timestamp)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (boolean)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (null)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style=" " title="bumbl#ebéé&#8901;&#8901;">bumbl#ebéé&#8901;&#8901;
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="17">17
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="Espionage">Espionage
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="7">7
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="5000000">5000000
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="2.0">2.0
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style=" " title="['Bumble',&#8901;'Goldback']">['Bumble',&#8901;'Goldback']
#             </div>
#         </td>

# %%
t.create(None, "outliers.mad", None, "json","count", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_mad_count() test function...
# INFO:optimus:test_outliers_mad_count()
# 3

# %%
t.create(None, "outliers.mad", None, "json","non_outliers_count", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_mad_non_outliers_count() test function...
# INFO:optimus:test_outliers_mad_non_outliers_count()
# 2

# %%
t.create(None, "outliers.mad", None, "json","info", numeric_col, threshold, relative_error)
# Out:
# Creating test_outliers_mad_info() test function...
# INFO:optimus:test_outliers_mad_info()
# {'count_outliers': 3, 'count_non_outliers': 2, 'lower_bound': 12.5, 'upper_bound': 21.5}

# %%
t.run()
# Out:
# Creating file ../test_df_outliers.py
# Done

# %% [markdown]
# ## Keycolision

# %%
source_df = op.read.csv("../../examples/data/random.csv",header=True, sep=";").limit(100)

# %%
t = Test(op, df, "df_keycollision", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                        "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F",
                                        "from optimus.ml import keycollision as keyCol"], 
         path = "df_keycollision", final_path="..")

from optimus.ml import keycollision as keyCol

# %%
t.create(keyCol, "fingerprint",  None, "df",None, source_df, "STATE")
t.run()
# Out:
# Creating test_fingerprint() test function...
# INFO:optimus:test_fingerprint()
# INFO:optimus:Using 'column_exp' to process column 'STATE_FINGERPRINT' with function _trim
# INFO:optimus:Using 'column_exp' to process column 'STATE_FINGERPRINT' with function _lower
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function multiple_replace
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function _remove_accents
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function _split_sort_remove_join
# <div class="info_items">Viewing 10 of 100 rows / 137 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">LOCNCODE</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">LOCNDSCR</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ADDRESS1</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ADDRESS2</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ADDRESS3</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">CITY</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ZIPCODE</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">COUNTRY</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Location_Segment</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">PAQ</div>
#             <div class="data_type">11 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">TIPUNI</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tipo_unidad</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ITEMNMBR</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ITMSHNAM</div>
#             <div class="data_type">15 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">MZ</div>
#             <div class="data_type">16 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">LT</div>
#             <div class="data_type">17 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">EDIF</div>
#             <div class="data_type">18 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NIVEL</div>
#             <div class="data_type">19 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NOUNI</div>
#             <div class="data_type">20 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">CONDO</div>
#             <div class="data_type">21 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">REGIMEN</div>
#             <div class="data_type">22 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ETAPA</div>
#             <div class="data_type">23 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">PROTO</div>
#             <div class="data_type">24 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ITEMDESC</div>
#             <div class="data_type">25 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NIVELES</div>
#             <div class="data_type">26 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">COCHERA</div>
#             <div class="data_type">27 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">RECAM</div>
#             <div class="data_type">28 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ALCOB</div>
#             <div class="data_type">29 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">BANOS</div>
#             <div class="data_type">30 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Num_Balcon</div>
#             <div class="data_type">31 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </
# Creating file ../test_df_keycollision.py
# Done

# %%
t.create(keyCol, "fingerprint_cluster", None, "df", None, source_df, "STATE")
# Out:
# Creating test_fingerprint_cluster() test function...
# INFO:optimus:test_fingerprint_cluster()
# INFO:optimus:Using 'column_exp' to process column 'STATE_FINGERPRINT' with function _trim
# INFO:optimus:Using 'column_exp' to process column 'STATE_FINGERPRINT' with function _lower
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function multiple_replace
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function _remove_accents
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function _split_sort_remove_join
# <div class="info_items">Viewing 1 of 1 rows / 4 columns</div>
# <div class="info_items">200 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">STATE_CLUSTER_SIZE</div>
#             <div class="data_type">1 (int)</div>
#             <div class="data_type">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_CLUSTER</div>
#             <div class="data_type">2 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_COUNT</div>
#             <div class="data_type">3 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_RECOMMENDED</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Distrito&#8901;Federal']'>['Distrito&#8901;Federal']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='100'>100
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Distrito&#8901;Federal'>Distrito&#8901;Federal
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 1 of 1 rows / 4 columns</div>
# <div class="info_items">200 partition(s)</div>

# %%
t.create(keyCol, "n_gram_fingerprint", None, "df", None, source_df, "STATE")
# Out:
# Creating test_n_gram_fingerprint() test function...
# INFO:optimus:test_n_gram_fingerprint()
# INFO:optimus:Using 'column_exp' to process column 'STATE_NGRAM' with function _lower
# INFO:optimus:Using 'column_exp' to process column 'STATE_NGRAM' with function _remove_white_spaces
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_NGRAM' with function multiple_replace
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_NGRAM' with function _remove_accents
# INFO:optimus:Using 'column_exp' to process column 'LOCNCODE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'LOCNDSCR' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ADDRESS1' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ADDRESS2' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ADDRESS3' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'CITY' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'STATE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ZIPCODE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'COUNTRY' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Location_Segment' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'PAQ' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'TIPUNI' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Tipo_unidad' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ITEMNMBR' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ITMSHNAM' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'MZ' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'LT' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'EDIF' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'NIVEL' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'NOUNI' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'CONDO' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'REGIMEN' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ETAPA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'PROTO' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ITEMDESC' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'NIVELES' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'COCHERA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'RECAM' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ALCOB' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'BANOS' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Num_Balcon' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'SALA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'COMEDOR' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'COCINA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Cuarto_Lavado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Cuarto_Servicio' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'OTROX' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'OTROX1' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'SupCons' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'PATIOSERV' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'TERRAZA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'BALCON' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'AZOTEA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Otros' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'AREATOT' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FRENTE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Sup_Terreno' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'EXCEDENTE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'OTRO1' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'OTRO2' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'TAMANO' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'UBICAVER' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'UBICAHORI' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'QTYONHND_' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'QTYSOLD' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'INACTIVE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'UOMPRICE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'MONTOAPA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'PAGINI' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ENGANCHE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHESCRIPRO' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHAENTREGA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHASALIDAVENTAS' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'LIBERADO_NOLIBERADO' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'ACTIVO_INACTIVO' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Estatus1Vivienda' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Estatus2Vivienda' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'CUSTNMBR' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Nombre_Completo' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cNombre' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cApellidoPaterno' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cApellidoMaterno' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cRfc' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cCurp' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'fkIdGradoInteres' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cSexo' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cEmail' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cTelefonoCasa' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cTelefonoCelular' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cTelefonoTrabajo' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cNumeroSeguroSocial' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'dFechaNacimiento' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cEstadoCivil' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cRegimenConyugal' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cNacionalidad' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cLugarNacimiento' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cRecomendadoPor' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'fkIdMedio' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cMedioContacto' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cCalle' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cNumeroExterior' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cNumeroInterior' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cColonia' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cMunicipio' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cEstado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cPais' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cCodigoPostal' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'nTiempoResidencia' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cComentario' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cNumeroIdentificacion' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'cTipoIdentificación' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'REFERENCIA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FACTURA' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'NOTACR' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Precio_cierre' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Precio_cierre_Tot' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Aumento_al_Contrato' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Condonacón' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Precio_Escritura_Total' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Precio_Dev' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Precio_Dev_Total' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Notarios_Proyectados' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Gatos_A_terceros' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Depositos' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Saldo' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'dFechaCreacion' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'dFechaModificacion' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_Cotizado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_SolApartado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_AutApartado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'Vigencia_Apartado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FechaVencimientoApartado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_SolDictamen' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_ProcDictamen' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_DictaminadoLlamada' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_DictaminadoFirma' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_Dictaminado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_Rechazado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_EscrituraAvaluo' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_EscrituraFolio' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FolioEscsritura' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_EscrituraReal' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_Cancelado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_Liberado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'FECHA_Entregado' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'MotivoCancelacion' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'STATE_NGRAM' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'STATE_NGRAM' with function func_col_exp
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_NGRAM_FINGERPRINT' with function remote_white_spaces_remove_sort_join
# <div class="info_items">Viewing 10 of 100 rows / 138 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">LOCNCODE</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">LOCNDSCR</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ADDRESS1</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ADDRESS2</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ADDRESS3</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">CITY</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ZIPCODE</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">COUNTRY</div>
#             <div class="data_type">9 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Location_Segment</div>
#             <div class="data_type">10 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">PAQ</div>
#             <div class="data_type">11 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">TIPUNI</div>
#             <div class="data_type">12 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Tipo_unidad</div>
#             <div class="data_type">13 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ITEMNMBR</div>
#             <div class="data_type">14 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ITMSHNAM</div>
#             <div class="data_type">15 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">MZ</div>
#             <div class="data_type">16 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">LT</div>
#             <div class="data_type">17 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">EDIF</div>
#             <div class="data_type">18 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NIVEL</div>
#             <div class="data_type">19 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NOUNI</div>
#             <div class="data_type">20 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">CONDO</div>
#             <div class="data_type">21 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">REGIMEN</div>
#             <div class="data_type">22 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ETAPA</div>
#             <div class="data_type">23 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">PROTO</div>
#             <div class="data_type">24 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ITEMDESC</div>
#             <div class="data_type">25 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">NIVELES</div>
#             <div class="data_type">26 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">COCHERA</div>
#             <div class="data_type">27 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">RECAM</div>
#             <div class="data_type">28 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">ALCOB</div>
#             <div class="data_type">29 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">BANOS</div>
#             <div class="data_type">30 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Num_Balcon</div>
#             <div class="data_type">31 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </

# %%
t.create(keyCol, "n_gram_fingerprint_cluster", None, "df", None, source_df, "STATE", 2)
# Out:
# Creating test_n_gram_fingerprint_cluster() test function...
# INFO:optimus:test_n_gram_fingerprint_cluster()
# INFO:optimus:Using 'column_exp' to process column 'STATE_NGRAM' with function _lower
# INFO:optimus:Using 'column_exp' to process column 'STATE_NGRAM' with function _remove_white_spaces
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_NGRAM' with function multiple_replace
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_NGRAM' with function _remove_accents
# INFO:optimus:Using 'column_exp' to process column 'count' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'STATE' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'STATE_NGRAM' with function _cast_to
# INFO:optimus:Using 'column_exp' to process column 'STATE_NGRAM' with function func_col_exp
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_NGRAM_FINGERPRINT' with function remote_white_spaces_remove_sort_join
# <div class="info_items">Viewing 1 of 1 rows / 4 columns</div>
# <div class="info_items">200 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">STATE_CLUSTER_SIZE</div>
#             <div class="data_type">1 (int)</div>
#             <div class="data_type">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_CLUSTER</div>
#             <div class="data_type">2 (array&lt;string&gt;)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_COUNT</div>
#             <div class="data_type">3 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_RECOMMENDED</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='1'>1
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='['Distrito&#8901;Federal']'>['Distrito&#8901;Federal']
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='100.0'>100.0
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Distrito&#8901;Federal'>Distrito&#8901;Federal
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 1 of 1 rows / 4 columns</div>
# <div class="info_items">200 partition(s)</div>

# %%
t.run()
# Out:
# Creating file ../test_df_keycollision.py
# Done

# %% [markdown]
# ## Distance cluster

# %%
source_df = op.read.csv("../../examples/data/random.csv",header=True, sep=";").limit(1000)

# %%
t = Test(op, source_df, "df_distance_cluster", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                        "import numpy as np",
                                        "nan = np.nan",
                                        "import datetime",
                                        "from pyspark.sql import functions as F",
                                        "from optimus.ml import distancecluster as dc"], path = "df_distance_cluster", final_path="..")

from optimus.ml import distancecluster as dc

# %%
t.create(dc, "levenshtein_matrix", None, 'df', None, source_df, "STATE")
# Out:
# Creating test_levenshtein_matrix() test function...
# INFO:optimus:test_levenshtein_matrix()
# INFO:optimus:Using 'column_exp' to process column 'STATE_FINGERPRINT' with function _trim
# INFO:optimus:Using 'column_exp' to process column 'STATE_FINGERPRINT' with function _lower
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function multiple_replace
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function _remove_accents
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function _split_sort_remove_join
# <div class="info_items">Viewing 4 of 4 rows / 3 columns</div>
# <div class="info_items">200 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">STATE_LEVENSHTEIN_1</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_LEVENSHTEIN_2</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_LEVENSHTEIN_DISTANCE</div>
#             <div class="data_type">3 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='estadodemexico'>estadodemexico
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='estadodemexico'>estadodemexico
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0'>0
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='estadodemexico'>estadodemexico
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='distritofederal'>distritofederal
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11'>11
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='distritofederal'>distritofederal
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='estadodemexico'>estadodemexico
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11'>11
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='distritofederal'>distritofederal
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='distritofederal'>distritofederal
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='0'>0
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 4 of 4 rows / 3 columns</div>
# <div class="info_items">200 partition(s)</div>

# %%
t.create(dc, "levenshtein_filter", None, 'df', None, source_df, "STATE")
# Out:
# Creating test_levenshtein_filter() test function...
# INFO:optimus:test_levenshtein_filter()
# INFO:optimus:Using 'column_exp' to process column 'STATE_FINGERPRINT' with function _trim
# INFO:optimus:Using 'column_exp' to process column 'STATE_FINGERPRINT' with function _lower
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function multiple_replace
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function _remove_accents
# INFO:optimus:Using 'pandas_udf' to process column 'STATE_FINGERPRINT' with function _split_sort_remove_join
# <div class="info_items">Viewing 2 of 2 rows / 3 columns</div>
# <div class="info_items">200 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">STATE_FROM</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_LEVENSHTEIN_DISTANCE</div>
#             <div class="data_type">2 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">STATE_TO</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='estadodemexico'>estadodemexico
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11'>11
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='distritofederal'>distritofederal
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='distritofederal'>distritofederal
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11'>11
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='estadodemexico'>estadodemexico
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 3 columns</div>
# <div class="info_items">200 partition(s)</div>

# %%
t.run()
# Out:
# Creating file ../test_df_distance_cluster.py
# Done

# %%
df_cancer = op.spark.read.csv('../data_cancer.csv', sep=',', header=True, inferSchema=True)

# %%
columns = ['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean',
           'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean',
           'fractal_dimension_mean']

# %%
df_model, rf_model = op.ml.gbt(df_cancer, columns, "diagnosis")

# %%
df_model.table()
# Out:
# <div class="info_items">Viewing 10 of 569 rows / 37 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">id</div>
#             <div class="data_type">1 (int)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">diagnosis</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">radius_mean</div>
#             <div class="data_type">3 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">texture_mean</div>
#             <div class="data_type">4 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">perimeter_mean</div>
#             <div class="data_type">5 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">area_mean</div>
#             <div class="data_type">6 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">smoothness_mean</div>
#             <div class="data_type">7 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">compactness_mean</div>
#             <div class="data_type">8 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">concavity_mean</div>
#             <div class="data_type">9 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">concave points_mean</div>
#             <div class="data_type">10 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">symmetry_mean</div>
#             <div class="data_type">11 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">fractal_dimension_mean</div>
#             <div class="data_type">12 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">radius_se</div>
#             <div class="data_type">13 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">texture_se</div>
#             <div class="data_type">14 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">perimeter_se</div>
#             <div class="data_type">15 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">area_se</div>
#             <div class="data_type">16 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">smoothness_se</div>
#             <div class="data_type">17 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">compactness_se</div>
#             <div class="data_type">18 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">concavity_se</div>
#             <div class="data_type">19 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">concave points_se</div>
#             <div class="data_type">20 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">symmetry_se</div>
#             <div class="data_type">21 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">fractal_dimension_se</div>
#             <div class="data_type">22 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">radius_worst</div>
#             <div class="data_type">23 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">texture_worst</div>
#             <div class="data_type">24 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">perimeter_worst</div>
#             <div class="data_type">25 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">area_worst</div>
#             <div class="data_type">26 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">smoothness_worst</div>
#             <div class="data_type">27 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">compactness_worst</div>
#             <div class="data_type">28 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">concavity_worst</div>
#             <div class="data_type">29 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">concave points_worst</div>
#             <div class="data_type">30 (double)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <

# %%
source_df = op.create.df([
    ("words", "str", True),
    ("num", "int", True),
    ("animals", "str", True),
    ("thing", StringType(), True),
    ("second", "int", True),
    ("filter", StringType(), True)
],
    [
        ("  I like     fish  ", 1, "dog dog", "housé", 5, "a"),
        ("    zombies", 2, "cat", "tv", 6, "b"),
        ("simpsons   cat lady", 2, "frog", "table", 7, "1"),
        (None, 3, "eagle", "glass", 8, "c"),
    ])

# %%
source_df.show()
# Out:
# +-------------------+---+-------+-----+------+------+
# |              words|num|animals|thing|second|filter|
# +-------------------+---+-------+-----+------+------+
# |  I like     fish  |  1|dog dog|housé|     5|     a|
# |            zombies|  2|    cat|   tv|     6|     b|
# |simpsons   cat lady|  2|   frog|table|     7|     1|
# |               null|  3|  eagle|glass|     8|     c|
# +-------------------+---+-------+-----+------+------+

# %%
actual_df = source_df.rows.append([("this is a word", 2, "this is an animal",
                                           "this is a thing", 64, "this is a filter",)])
# Out:
# True
