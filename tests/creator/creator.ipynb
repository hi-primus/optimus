# %% [markdown]
# # This notebook creates a test file

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../..")

# %%
from optimus import Optimus

# %%
op = Optimus("pandas")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/Angel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
from datetime import date, datetime

source_df = op.create.dataframe({'NullType': (None, None, None, None, None, None),
    'attributes': ([8.5344, 4300.0], [5.334, 2000.0], [7.9248, 4000.0], [3.9624, 1800.0], [None, 5700.0], [91.44, None]),
    'date arrival': ('1980/04/10', '1980/04/10', '1980/04/10', '1980/04/10', '1980/04/10', '1980/04/10'),
    'function(binary)': (bytearray('Leader', 'utf-8'), bytearray('Espionage', 'utf-8'), bytearray('Security', 'utf-8'), bytearray('First Lieutenant', 'utf-8'), bytearray('None', 'utf-8'), bytearray('Battle Station', 'utf-8')),
    'height(ft)': (-28, 17, 26, 13, None, 300),
    'japanese name': (['Inochi', 'Convoy'], ['Bumble', 'Goldback'], ['Roadbuster'], ['Meister'], ['Megatron'], ['Metroflex']),
    ('last date seen', 'date'): ('2016/09/10', '2015/08/10', '2014/07/10', '2013/06/10', '2012/05/10', '2011/04/10'),
    'last position seen': ('19.442735,-99.201111', '10.642707,-71.612534', '37.789563,-122.400356', '33.670666,-117.841553', None, None),
    'rank': (10, 7, 7, 8, 10, 8),
    ('Cybertronian', 'bool'): (True, True, True, True, True, False),
    ('Date Type'): (date(2016, 9, 10), date(2015, 8, 10), date(2014, 6, 24), date(2013, 6, 24), date(2012, 5, 10), date(2011, 4, 10)),
    ('age', 'int'): (5000000, 5000000, 5000000, 5000000, 5000000, 5000000),
    ('function', 'string'): ('Leader', 'Espionage', 'Security', 'First Lieutenant', 'None', 'Battle Station'),
    ('names', 'str'): ('Optimus', 'bumbl#ebéé  ', 'ironhide&', 'Jazz', 'Megatron', 'Metroplex_)^$'),
    ('timestamp', 'time'): (datetime(2014, 6, 24, 0, 0), datetime(2014, 6, 24, 0, 0), datetime(2014, 6, 24, 0, 0), datetime(2014, 6, 24, 0, 0), datetime(2014, 6, 24, 0, 0), datetime(2014, 6, 24, 0, 0)),
    ('weight(t)', 'float'): (4.3, 2.0, 4.0, 1.8, 5.7, None)}, n_partitions=1)

source_df.to_json() == source_df.to_json()
# Out:
# True

# %%
source_df.display()
# Out:
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 6 of 6 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <span class="optimus_table_container" style="display: inline-flex; flex-direction: column;">
#     <table class="optimus_table" style="font-size: 12px; margin: 0;">
#         <thead style="border-bottom: 1px solid currentColor;">
#         <tr>
#
#             <th style="font-family: sans-serif; ">
#                 <div class="column_name" style="font-size: 1.2em;">NullType</div>
#                 <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#
#             </th>
#
#             <th style="font-family: sans-serif; ">
#                 <div class="column_name" style="font-size: 1.2em;">attributes</div>
# ...

# %%
source_df.cols.clip("rank", 999, 10000)
# Out:
# NullType    attributes        date arrival    function(binary)                  height(ft)  japanese name           last date seen       last position seen            rank  Cybertronian    Date Type          age  function          names          timestamp              weight(t)
# (object)    (object)          (object)        (object)                           (float64)  (object)                (datetime64[ns])     (object)                 (float64)  (bool)          (object)       (int64)  (string)          (string)       (datetime64[ns])       (float64)
# ----------  ----------------  --------------  ------------------------------  ------------  ----------------------  -------------------  ---------------------  -----------  --------------  -----------  ---------  ----------------  -------------  -------------------  -----------
# ...

# %%
from optimus.helpers.test import Test

t = Test(op, source_df, "df_ext", imports=["import datetime"], path = "df_ext", final_path="..")

# %%
source_df.rows.count()
# Out:
# 6

# %%
t.create(None, "buffer_window", "1", 'df', None, "*", 0, 3)
t.create(None, "buffer_window", "2", 'df', None, ["rank","age","names"], 6, 0)
t.create(None, "buffer_window", "3", 'df', None, "last position seen", 4, 5)
# Out:
# Creating test_buffer_window_1() test function...
# Creating test_buffer_window_2() test function...
# Creating test_buffer_window_3() test function...

# %%
t.create(None, "stratified_sample", None, 'df', None, "rank", 12)
# Out:
# Creating test_stratified_sample() test function...

# %%
t.create(None, "cols.cos", "1", 'df', None, "weight(t)")
t.create(None, "cols.cos", "2", 'df', None, "age")
# Out:
# Creating test_cols_cos_1() test function...
# Creating test_cols_cos_2() test function...

# %%
t.create(None, "cols.string_to_index", "1", "df", None, "names")
t.create(None, "cols.string_to_index", "2", "df", None, ["names","function"])
t.create(None, "cols.string_to_index", "1", "df", None, "*")
# Out:
# Creating test_cols_string_to_index_1() test function...
# Creating test_cols_string_to_index_2() test function...
# Creating test_cols_string_to_index_1() test function...

# %%
t.create(None, "cols.remove", "1", "df", None, "function", ["a", "i", "Es"])
t.create(None, "cols.remove", "2", "df", None, "*", ["s", "zz"])
t.create(None, "cols.remove", "3", "df", None, "*", " ")
# Out:
# Creating test_cols_remove_1() test function...
# Creating test_cols_remove_2() test function...
# Creating test_cols_remove_3() test function...

# %%
t.create(None, "cols.abs", "1", "df", None, "weight(t)")
t.create(None, "cols.abs", "2", "df", None, ["function","rank","height(ft)"])
# Out:
# Creating test_cols_abs_1() test function...
# Creating test_cols_abs_2() test function...

# %%
t.create(None, "cols.unique", "1", "df", None, "rank")
t.create(None, "cols.unique", "2", "df", None, ["Cybertronian","age","date arrival"])
# Out:
# Creating test_cols_unique_1() test function...
# Creating test_cols_unique_2() test function...

# %%
t.create(None, "cols.z_score", "1", "df", None, "weight(t)")
t.create(None, "cols.z_score", "2", "df", None, ["names","height(ft)"])
# Out:
# Creating test_cols_z_score_1() test function...
# Creating test_cols_z_score_2() test function...

# %%
t.create(None, "cols.lower", "1", "df", None, ["japanese name","function(binary)","Cybertronian"])
t.create(None, "cols.lower", "2", "df", None, "*")
t.create(None, "cols.lower", "3", "df", None, "function")
t.create(None, "cols.lower", "4", "df", None, "age")
# Out:
# Creating test_cols_lower_1() test function...
# Creating test_cols_lower_2() test function...
# Creating test_cols_lower_3() test function...
# Creating test_cols_lower_4() test function...

# %%
t.create(None, "cols.upper", "1", "df", None, ["japanese name","function(binary)","Cybertronian"])
t.create(None, "cols.upper", "2", "df", None, "*")
t.create(None, "cols.upper", "3", "df", None, "function")
t.create(None, "cols.upper", "4", "df", None, "age")
# Out:
# Creating test_cols_upper_1() test function...
# Creating test_cols_upper_2() test function...
# Creating test_cols_upper_3() test function...
# Creating test_cols_upper_4() test function...

# %%
t.create(None, "cols.trim", "1", "df", None, ["japanese name","function(binary)","Cybertronian"])
t.create(None, "cols.trim", "2", "df", None, "*")
t.create(None, "cols.trim", "3", "df", None, "function")
t.create(None, "cols.trim", "4", "df", None, "age")
# Out:
# Creating test_cols_trim_1() test function...
# Creating test_cols_trim_2() test function...
# Creating test_cols_trim_3() test function...
# Creating test_cols_trim_4() test function...

# %%
t.create(None, "cols.reverse", "1", "df", None, ["japanese name","function(binary)","Cybertronian"])
t.create(None, "cols.reverse", "2", "df", None, "*")
t.create(None, "cols.reverse", "3", "df", None, "function")
# Out:
# Creating test_cols_reverse_1() test function...
# Creating test_cols_reverse_2() test function...
# Creating test_cols_reverse_3() test function...

# %%
t.create(None, "cols.remove_special_chars", "1", "df", None, ["japanese name","function(binary)","Cybertronian"])
t.create(None, "cols.remove_special_chars", "2", "df", None, "*")
t.create(None, "cols.remove_special_chars", "3", "df", None, "names")
t.create(None, "cols.remove_special_chars", "4", "df", None, "age")
# Out:
# Creating test_cols_remove_special_chars_1() test function...
# Creating test_cols_remove_special_chars_2() test function...
# Creating test_cols_remove_special_chars_3() test function...
# Creating test_cols_remove_special_chars_4() test function...

# %%
t.create(None, "cols.remove_white_spaces", "1", "df", None, ["japanese name","function(binary)","Cybertronian"])
t.create(None, "cols.remove_white_spaces", "2", "df", None, "*")
t.create(None, "cols.remove_white_spaces", "3", "df", None, "names")
t.create(None, "cols.remove_white_spaces", "4", "df", None, "age")
# Out:
# Creating test_cols_remove_white_spaces_1() test function...
# Creating test_cols_remove_white_spaces_2() test function...
# Creating test_cols_remove_white_spaces_3() test function...
# Creating test_cols_remove_white_spaces_4() test function...

# %%
t.create(None, "cols.date_format", "1", "df", None, ["japanese name","function(binary)","Cybertronian"])
t.create(None, "cols.date_format", "2", "df", None, "*")
t.create(None, "cols.date_format", "3", "df", None, "last date seen")
t.create(None, "cols.date_format", "4", "df", None, "timestamp")
# Out:
# Creating test_cols_date_format_1() test function...
# Creating test_cols_date_format_2() test function...
# Creating test_cols_date_format_3() test function...
# Creating test_cols_date_format_4() test function...

# %%
t.create(None, "cols.impute", "1", "df", None, "height(ft)")
t.create(None, "cols.impute", "2", "df", None, ["rank","Cybertronian","age"])
# Out:
# Creating test_cols_impute_1() test function...
# Creating test_cols_impute_2() test function...

# %%
t.create(None, "cols.qcut", "1", "df", None, "last date seen", 87)
t.create(None, "cols.qcut", "2", "df", None, "last date seen", 33)
t.create(None, "cols.qcut", "3", "df", None, ["rank","height(ft)","weight(t)"],4) #This one doesn´t admit a quantile input higher than 4 (have to check) 
t.create(None, "cols.qcut", "4", "df", None, ["rank","height(ft)","weight(t)"],1)
# Out:
# Creating test_cols_qcut_1() test function...
# Creating test_cols_qcut_2() test function...
# Creating test_cols_qcut_3() test function...
# Creating test_cols_qcut_4() test function...

# %%
t.create(None, "cols.clip", "1", "df", None, ["function(binary)","Cybertronian"],-34,10)
t.create(None, "cols.clip", "2", "df", None, "rank",0.1,0.2)
t.create(None, "cols.clip", "3", "df", None, "age",0,0)
t.create(None, "cols.clip", "4", "df", None, "date arrival",3447,123)
# Out:
# Creating test_cols_clip_1() test function...
# Creating test_cols_clip_2() test function...
# Creating test_cols_clip_3() test function...
# Creating test_cols_clip_4() test function...

# %%
t.run()
# Out:
# Creating file ../test_df_ext.py
# Done
