# %% [markdown]
# # This notebook create the tests in python code. All this cells must be run to executed the tests

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("../..")

# %%
from optimus import Optimus
from optimus.helpers.test import Test

# %%
from optimus import Optimus
op = Optimus("dask", n_workers=1, threads_per_worker=8, processes=False, memory_limit="3G", comm=True)
# Out:
# Open Bumblebee: <a target='_blank' href ='https://app.hi-bumblebee.com/?session=a6348c7c-4416-4460-87a8-a417a3a89220&key=hAuDDxxZiVk7HsmYdBaTjYRJLZ-OfdT-T1oo5QsfxFE=&view=0'>https://app.hi-bumblebee.com</a><div>If you really care about privacy get your keys in bumblebee.ini and put them<a href ='https://app.hi-bumblebee.com'> here</a></div>

# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
from pyspark.sql.types import *
from datetime import date, datetime

cols = [
    ("names", "str"),
    ("height(ft)", ShortType()),
    ("function", "str"),
    ("rank", ByteType()),
    ("age", "int"),
    ("weight(t)", "float"),
    "japanese name",
    "last position seen",
    "date arrival",
    "last date seen",
    ("attributes", ArrayType(FloatType())),
    ("Date Type", DateType()),
    ("timestamp", TimestampType()),
    ("Cybertronian", BooleanType()),
    ("function(binary)", BinaryType()),
    ("NullType", NullType())

]

rows = [
    ("Optim'us", -28, "Leader", 10, 5000000, 4.30, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
     "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True, bytearray("Leader", "utf-8"),
     None),
    ("bumbl#ebéé  ", 17, "Espionage", 7, 5000000, 2.0, ["Bumble", "Goldback"], "10.642707,-71.612534", "1980/04/10",
     "2015/08/10", [5.334, 2000.0], date(2015, 8, 10), datetime(2014, 6, 24), True, bytearray("Espionage", "utf-8"),
     None),
    ("ironhide&", 26, "Security", 7, 5000000, 4.0, ["Roadbuster"], "37.789563,-122.400356", "1980/04/10",
     "2014/07/10", [7.9248, 4000.0], date(2014, 6, 24), datetime(2014, 6, 24), True, bytearray("Security", "utf-8"),
     None),
    ("Jazz", 13, "First Lieutenant", 8, 5000000, 1.80, ["Meister"], "33.670666,-117.841553", "1980/04/10",
     "2013/06/10", [3.9624, 1800.0], date(2013, 6, 24), datetime(2014, 6, 24), True,
     bytearray("First Lieutenant", "utf-8"), None),
    ("Megatron", None, "None", 10, 5000000, 5.70, ["Megatron"], None, "1980/04/10", "2012/05/10", [None, 5700.0],
     date(2012, 5, 10), datetime(2014, 6, 24), True, bytearray("None", "utf-8"), None),
    ("Metroplex_)^$", 300, "Battle Station", 8, 5000000, None, ["Metroflex"], None, "1980/04/10", "2011/04/10",
     [91.44, None], date(2011, 4, 10), datetime(2014, 6, 24), True, bytearray("Battle Station", "utf-8"), None),
    (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),

]

source_df = pd.DataFrame(columns = ['names','height(ft)','function',
                      'rank','age','weight(t)','japanese name','last position seen',
                      'date arrival','last date seen','attributes','Date Type','timestamp',
                      'Cybertronian','function(binary)','NullType'], 
             data= rows,
#              dtype = (object,object,object,
#                                 object,object,object,object,object,
#                                 object,object,object,object,object,
#                                 object,object)
            )

# from dask import dataframe as dd

# a=pd.DataFrame(source_df.to_dict())
from dask import dataframe as dd
source_df = dd.from_pandas(source_df, npartitions=1)

# %%
source_df
# Out:
# Dask DataFrame Structure:
#                 names height(ft) function     rank      age weight(t) japanese name last position seen date arrival last date seen attributes Date Type       timestamp Cybertronian function(binary) NullType
# npartitions=1
# 0              object    float64   object  float64  float64   float64        object             object       object         object     object    object  datetime64[ns]       object           object   object
# 6                 ...        ...      ...      ...      ...       ...           ...                ...          ...            ...        ...       ...             ...          ...              ...      ...
# Dask Name: from_pandas, 1 tasks

# %% [markdown]
# ### End Init Section

# %% [markdown]
# # Test

# %% [markdown]
# ## Columns Test

# %%
t = Test(op, source_df, "df_cols_dask", imports=["import numpy as np",
                                            "nan = np.nan",
                                            "import datetime",], path="df_cols_dask", final_path="..")

# %%
from pyspark.sql import functions as F


def func(col_name, attrs):
    return F.col(col_name) * 2


numeric_col = "height(ft)"
numeric_col_B = "rank"
numeric_col_C = "rank"
string_col = "function"
date_col = "date arrival"
date_col_B = "last date seen"
new_col = "new col"
array_col = "attributes"

# %%
t.create(source_df, "cols.string_to_index", None, "df", None, "names")

t.create(None, "cols.hist", None, "json", None, ["height(ft)", numeric_col_B], 4)
# Out:
# Creating test_cols_string_to_index() test function...
# ["'names'"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-240-3a6c8e8331fb> in <module>
# ----> 1 t.create(source_df, "cols.string_to_index", None, "df", None, "names")
#       2
#       3 t.create(None, "cols.hist", None, "json", None, ["height(ft)", numeric_col_B], 4)
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     218                 df_func = getattr(df_func, f)
#     219
# --> 220             df_result = df_func(*args, **kwargs)
#     221
#     222
#
# ~\Documents\Optimus\optimus\engines\base\dask\columns.py in string_to_index(self, input_cols, output_cols, columns)
#     283         df = self.df
#     284
# --> 285         df = ml_string_to_index(df, input_cols, output_cols, columns)
#     286
#     287         return df
#
# ~\Documents\Optimus\optimus\engines\dask\ml\encoding.py in string_to_index(df, input_cols, output_cols, columns, **kargs)
#      57
#      58     indexers = [StringIndexer(inputCol=input_col, outputCol=output_col, **kargs).fit(df) for input_col, output_col
# ---> 59                 in zip(list(set(input_cols)), list(set(output_cols)))]
#      60
#      61     pipeline = Pipeline(stages=indexers)
#
# TypeError: 'NoneType' object is not iterable

# %%
source_df_index_to_string = source_df_string_to_index.cols.string_to_index("rank")

# %%
# FIX at creation time we los the metadata. Need to find a way to put it on the dataframe creation
t.delete(source_df_index_to_string, "cols.index_to_string", None, "df", None, "rank***STRING_TO_INDEX")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-241-6fbffdeafb9f> in <module>
#       1 # FIX at creation time we los the metadata. Need to find a way to put it on the dataframe creation
# ----> 2 t.delete(source_df_index_to_string, "cols.index_to_string", None, "df", None, "rank***STRING_TO_INDEX")
#
# NameError: name 'source_df_index_to_string' is not defined

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(source_df_string_to_index, "cols.values_to_cols", None, "df", None, "rank")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-456744b82efb> in <module>
# ----> 1 t.create(source_df_string_to_index, "cols.values_to_cols", None, "df", None, "rank")
#
# NameError: name 'source_df_string_to_index' is not defined

# %%
t.run()

# %%
t.create(source_df_string_to_index, "cols.values_to_cols", "all_columns", "df", None, ["names", "height(ft)"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-244-77c1ec96b4fa> in <module>
# ----> 1 t.create(source_df_string_to_index, "cols.values_to_cols", "all_columns", "df", None, ["names", "height(ft)"])
#
# NameError: name 'source_df_string_to_index' is not defined

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
print(source_df.cols.remove(string_col))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-246-872fffa7bd9b> in <module>
# ----> 1 print(source_df.cols.remove(string_col))
#
# ~\Documents\Optimus\optimus\engines\base\dask\columns.py in remove(self, input_cols, search, search_by, output_cols)
#     650     def remove(self, input_cols, search=None, search_by="chars", output_cols=None):
#     651         return self.replace(input_cols=input_cols, search=search, replace_by="", search_by=search_by,
# --> 652                             output_cols=output_cols)
#     653
#     654     def reverse(self, input_cols, output_cols=None):
#
# ~\Documents\Optimus\optimus\engines\base\dask\columns.py in replace(self, input_cols, search, replace_by, search_by, ignore_case, output_cols)
#    1256         search = val_to_list(search)
#    1257         if search_by == "chars":
# -> 1258             str_regex = "|".join(map(re.escape, search))
#    1259         elif search_by == "words":
#    1260             str_regex = (r'\b%s\b' % r'\b|\b'.join(map(re.escape, search)))
#
# TypeError: 'NoneType' object is not iterable

# %%
t.create(None, "cols.remove", None, "df", None, string_col, "i")

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.remove", "list", "df", None, string_col, ["a", "i", "Es"])
# Out:
# Creating test_cols_remove_list() test function...
# ["'function'", "['a','i','Es']"]
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leder">
#
#                 Leder
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
t.create(None, "cols.remove", "list_output", "df", None, string_col, ["a", "i", "Es"], output_cols=string_col + "_new")
# Out:
# Creating test_cols_remove_list_output() test function...
# ["'function'", "['a','i','Es']"]
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 17 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function_new</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">17 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 1

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.min", None, "json", None, numeric_col)
# Out:
# Creating test_cols_min() test function...
# ["'height(ft)'"]
# {'height(ft)': -28.0}

# %%
source_df.cols.names()
# Out:
# ['names',
#  'height(ft)',
#  'function',
#  'rank',
#  'age',
#  'weight(t)',
#  'japanese name',
#  'last position seen',
#  'date arrival',
#  'last date seen',
#  'attributes',
#  'Date Type',
#  'timestamp',
#  'Cybertronian',
#  'function(binary)',
#  'NullType']

# %%
t.create(None, "cols.min", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_min_all_columns() test function...
# ["'*'"]
# {'Cybertronian': True, 'NullType': nan, 'age': 5000000.0, 'height(ft)': -28.0, 'rank': 7.0, 'timestamp': Timestamp('2014-06-24 00:00:00'), 'weight(t)': 1.8}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.max", None, "json", None, numeric_col)
# Out:
# Creating test_cols_max() test function...
# ["'height(ft)'"]
# {'height(ft)': 300.0}

# %%
t.create(None, "cols.max", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_max_all_columns() test function...
# ["'*'"]
# {'Cybertronian': True, 'NullType': nan, 'age': 5000000.0, 'height(ft)': 300.0, 'rank': 10.0, 'timestamp': Timestamp('2014-06-24 00:00:00'), 'weight(t)': 5.7}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.range", None, "json", None, numeric_col)
# Out:
# Creating test_cols_range() test function...
# ["'height(ft)'"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-256-9441f6278b5e> in <module>
# ----> 1 t.create(None, "cols.range", None, "json", None, numeric_col)
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     218                 df_func = getattr(df_func, f)
#     219
# --> 220             df_result = df_func(*args, **kwargs)
#     221
#     222
#
# ~\Documents\Optimus\optimus\engines\base\columns.py in range(self, columns)
#     452     def range(self, columns):
#     453         df = self.df
# --> 454         return self.agg_exprs(columns, df.functions.range_agg)
#     455
#     456     def percentile(self, columns, values=None, relative_error=RELATIVE_ERROR):
#
# TypeError: agg_exprs() missing 1 required positional argument: 'df'

# %%
t.create(None, "cols.range", "all_columns", "json", None, "*")

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
source_df.mean().compute()
# Out:
# height(ft)    6.560000e+01
# rank          8.333333e+00
# age           5.000000e+06
# weight(t)     3.560000e+00
# dtype: float64

# %%
t.create(None, "cols.median", None, "json", None, numeric_col)
# Out:
# Creating test_cols_median() test function...
# ["'height(ft)'"]
# 17.0

# %%
t.create(None, "cols.median", "all_columns", "json", None, "*")
# Out:
# Creating test_cols_median_all_columns() test function...
# ["'*'"]
# {'height(ft)': 17.0, 'rank': 8.0, 'age': 5000000.0, 'weight(t)': 4.0}

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.percentile", None, "json", None, numeric_col, [0.05, 0.25], 1)
# Out:
# Creating test_cols_percentile() test function...
# ["'height(ft)'", '[0.05,0.25]', '1']
# {'percentile': {0.05: -19.8, 0.25: 13.0}}

# %%
t.create(None, "cols.percentile", "all_columns", "json", None, "*", [0.05, 0.25], 1)
# Out:
# Creating test_cols_percentile_all_columns() test function...
# ["'*'", '[0.05,0.25]', '1']
# {'percentile': {'height(ft)': {0.05: -19.8, 0.25: 13.0}, 'rank': {0.05: 7.0, 0.25: 7.25}, 'age': {0.05: 5000000.0, 0.25: 5000000.0}, 'weight(t)': {0.05: 1.8400000000000003, 0.25: 2.0}}}

# %% [markdown]
# ## MAD

# %%
t.create(None, "cols.mad", None, "json", None, numeric_col)
# Out:
# Creating test_cols_mad() test function...
# ["'height(ft)'"]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-264-a13244eb63fd> in <module>
# ----> 1 t.create(None, "cols.mad", None, "json", None, numeric_col)
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     218                 df_func = getattr(df_func, f)
#     219
# --> 220             df_result = df_func(*args, **kwargs)
#     221
#     222
#
# ~\Documents\Optimus\optimus\engines\base\columns.py in mad(self, columns, relative_error, more)
#     475         funcs = [df.functions.mad_agg]
#     476
# --> 477         return self.agg_exprs(columns, funcs, more)
#     478
#     479     def std(self, columns):
#
# ~\Documents\Optimus\optimus\engines\base\columns.py in agg_exprs(self, columns, funcs, df, *args)
#     434         :return:
#     435         """
# --> 436         columns = parse_columns(df, columns)
#     437         return self.exec_agg(self.create_exprs(columns, funcs, *args))
#     438
#
# ~\Documents\Optimus\optimus\helpers\columns.py in parse_columns(df, cols_args, get_args, is_regex, filter_by_column_dtypes, accepts_missing_cols, invert)
#     167     # if columns value is * get all dataframes columns
#     168
# --> 169     df_columns = columns_names(df)
#     170
#     171     if is_regex is True:
#
# ~\Documents\Optimus\optimus\helpers\columns.py in columns_names(df)
#     139         columns_names = list(df.columns)
#     140     else:
# --> 141         columns_names = list(df.columns)
#     142
#     143     return columns_names
#
# AttributeError: 'NoneType' object has no attribute 'columns'

# %%
t.create(None, "cols.mad", "all_columns", "json", None, "*")

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
source_df.min().compute()
# Out:
# height(ft)                      -28
# rank                              7
# age                           5e+06
# weight(t)                       1.8
# timestamp       2014-06-24 00:00:00
# Cybertronian                   True
# NullType                       None
# dtype: object

# %%
source_df.cols.std("*")
# Out:
# {'stddev': {'height(ft)': 132.66612227694,
#   'rank': 1.3662601021279464,
#   'age': 0.0,
#   'weight(t)': 1.6471186963907611}}

# %%
t.create(None, "cols.std", None, "json", None, numeric_col)
# Out:
# Creating test_cols_std() test function...
# ["'height(ft)'"]
# {'stddev': {'height(ft)': 132.66612227694}}

# %%
t.create(None, "cols.std", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_std_all_columns() test function...
# ["'*'"]
# {'stddev': {'height(ft)': 132.66612227694, 'rank': 1.3662601021279464, 'age': 0.0, 'weight(t)': 1.6471186963907611}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.kurt", None, "json", None, numeric_col)
t.run()
# Out:
# Creating test_cols_kurt() test function...
# ["'height(ft)'"]
# {'kurtosis': {'height(ft)': nan}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.kurt", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_kurt_all_columns() test function...
# ["'*'"]
# {'kurtosis': {'height(ft)': nan, 'rank': nan, 'age': nan, 'weight(t)': nan}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.mean", None, "json",None, numeric_col)
# Out:
# Creating test_cols_mean() test function...
# ["'height(ft)'"]
# {'mean': {'height(ft)': 65.6}}

# %%
t.create(None, "cols.mean", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_mean_all_columns() test function...
# ["'*'"]
# {'mean': {'height(ft)': 65.6, 'rank': 8.333333333333334, 'age': 5000000.0, 'weight(t)': 3.56}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.skewness", None, "json", None, numeric_col)
# Out:
# Creating test_cols_skewness() test function...
# ["'height(ft)'"]
# {'skewness': {'height(ft)': nan}}

# %%
t.create(None, "cols.skewness", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_skewness_all_columns() test function...
# ["'*'"]
# {'skewness': {'height(ft)': nan, 'rank': nan, 'age': nan, 'weight(t)': nan}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.sum", None, "json", None,numeric_col)
# Out:
# Creating test_cols_sum() test function...
# ["'height(ft)'"]
# 328.0

# %%
t.create(None, "cols.sum", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_sum_all_columns() test function...
# ["'*'"]
# {'height(ft)': 328.0, 'rank': 50.0, 'age': 30000000.0, 'weight(t)': 17.8}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.variance", None, "json",None, numeric_col)
# Out:
# Creating test_cols_variance() test function...
# ["'height(ft)'"]
# 17600.3

# %%
t.create(None, "cols.variance", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_variance_all_columns() test function...
# ["'*'"]
# {'height(ft)': 17600.3, 'rank': 1.8666666666666665, 'age': 0.0, 'weight(t)': 2.713}
# Creating file ../test_df_cols_dask.py
# Done

# %%
source_df.ext.table()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
t.create(None, "cols.abs", None, "df", None, "weight(t)")
# Out:
# Creating test_cols_abs() test function...
# ["'weight(t)'"]
# columns <zip object at 0x000001D80677E648>
# output_cols <class 'zip'> <zip object at 0x000001D80677E648>
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
t.create(None, "cols.abs", "all_columns", "df", None, "*")
# Out:
# Creating test_cols_abs_all_columns() test function...
# ["'*'"]
# columns <zip object at 0x000001D806B48CC8>
# output_cols <class 'zip'> <zip object at 0x000001D806B48CC8>
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
source_df.ext.table()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
source_df.mode(dropna=True)
# Out:
# Dask DataFrame Structure:
#                 names height(ft) function     rank      age weight(t) japanese name last position seen date arrival last date seen attributes Date Type       timestamp Cybertronian function(binary) NullType
# npartitions=1
#                object    float64   object  float64  float64   float64        object             object       object         object     object    object  datetime64[ns]       object           object   object
#                   ...        ...      ...      ...      ...       ...           ...                ...          ...            ...        ...       ...             ...          ...              ...      ...
# Dask Name: concat, 66 tasks

# %%
t.create(None, "cols.mode", None, "json", None, numeric_col)
# Out:
# Creating test_cols_mode() test function...
# ["'height(ft)'"]
# {'mode': {'height(ft)': [-28.0, 13.0, 17.0, 26.0, 300.0]}}

# %%
# %%time
t.create(None, "cols.mode", "all_columns", "json", None, "*")
# Out:
# Creating test_cols_mode_all_columns() test function...
# ["'*'"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'bytearray'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1653, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1653, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1653, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# TypeErrorTypeError: distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# unhashable type: 'bytearray'
# : unhashable type: 'list'
# distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# distributed.sizeof - WARNING - Sizeof calculation failed.  Defaulting to 1MB
# Traceback (most recent call last):
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\distributed\sizeof.py", line 14, in safe_sizeof
#     return sizeof(obj)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\utils.py", line 507, in __call__
#     return meth(arg, *args, **kwargs)
#   File "C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\sizeof.py", line 104, in sizeof_pandas_dataframe
#     for name, col in df.iteritems():
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 901, in iteritems
#     yield from self.items()
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 897, in items
#     yield k, self._ixs(i, axis=1)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 2760, in _ixs
#     result = self._box_col_values(values, label)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py", line 3078, in _box_col_values
#     return klass(values, index=self.index, name=items, fastpath=True)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 310, in __init__
#     self.name = name
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py", line 5296, in __setattr__
#     object.__setattr__(self, name, value)
#   File "C:\Users\argenisleon\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py", line 435, in name
#     raise TypeError("Series.name must be a hashable type")
# TypeError: Series.name must be a hashable type
# distributed.worker - WARNING -  Compute Failed
# Function:  execute_task
# args:      (< could not convert arg to str >)
# kwargs:    {}
# Exception: TypeError("'<' not supported between instances of 'NoneType' and 'float'")
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in _try_kind_sort(arr)
#    2947                 # if kind==mergesort, it can fail for object dtype
# -> 2948                 return arr.argsort(kind=kind)
#    2949             except TypeError:
#
# TypeError: '<' not supported between instances of 'NoneType' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <timed eval> in <module>
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     218                 df_func = getattr(df_func, f)
#     219
# --> 220             df_result = df_func(*args, **kwargs)
#     221
#     222
#
# ~\Documents\Optimus\optimus\engines\dask\columns.py in mode(columns)
#      87                 return {"mode": {col_name: p.to_list() for p in parts for col_name in columns}}
#      88
# ---> 89             return _mode(f).compute()
#      90
#      91     return Cols(self)
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2593                     should_rejoin = False
#    2594             try:
# -> 2595                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2596             finally:
#    2597                 for f in futures.values():
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in gather(self, futures, errors, direct, asynchronous)
#    1892                 direct=direct,
#    1893                 local_worker=local_worker,
# -> 1894                 asynchronous=asynchronous,
#    1895             )
#    1896
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     776         else:
#     777             return sync(
# --> 778                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     779             )
#     780
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
# --> 348         raise exc.with_traceback(tb)
#     349     else:
#     350         return result[0]
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in f()
#     330             if callback_timeout is not None:
#     331                 future = asyncio.wait_for(future, callback_timeout)
# --> 332             result[0] = yield future
#     333         except Exception as exc:
#     334             error[0] = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\tornado\gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in _gather(self, futures, errors, direct, local_worker)
#    1751                             exc = CancelledError(key)
#    1752                         else:
# -> 1753                             raise exception.with_traceback(traceback)
#    1754                         raise exc
#    1755                     if errors == "skip":
#
# ~\Anaconda3\lib\site-packages\dask\utils.py in apply(func, args, kwargs)
#      29 def apply(func, args, kwargs=None):
#      30     if kwargs:
# ---> 31         return func(*args, **kwargs)
#      32     else:
#      33         return func(*args)
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in _reduction_aggregate(x, aca_aggregate, **kwargs)
#    6085     if isinstance(x, list):
#    6086         x = pd.Series(x)
# -> 6087     return aca_aggregate(x, **kwargs)
#    6088
#    6089
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in _mode_aggregate(df, dropna)
#    6135     max_val = value_count_series.max(skipna=dropna)
#    6136     mode_series = (
# -> 6137         value_count_series[value_count_series == max_val]
#    6138         .index.to_series()
#    6139         .sort_values()
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index)
#    2960         idx = ibase.default_index(len(self))
#    2961
# -> 2962         argsorted = _try_kind_sort(arr[good])
#    2963
#    2964         if is_list_like(ascending):
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in _try_kind_sort(arr)
#    2950                 # stable sort not available for object dtype
#    2951                 # uses the argsort default quicksort
# -> 2952                 return arr.argsort(kind="quicksort")
#    2953
#    2954         arr = self._values
#
# TypeError: '<' not supported between instances of 'NoneType' and 'float'

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.count", None, "json")
# Out:
# Creating test_cols_count() test function...
# []
# 16

# %% [markdown]
# ## Count na

# %%
t.create(None, "cols.count_na", None, "json", None, numeric_col)
# Out:
# Creating test_cols_count_na() test function...
# ["'height(ft)'"]
# {'count_na': {'height(ft)': 2}}

# %%
t.create(None, "cols.count_na", "all_columns", "json", None, "*")
# Out:
# Creating test_cols_count_na_all_columns() test function...
# ["'*'"]
# {'count_na': {'names': 1, 'height(ft)': 2, 'function': 1, 'rank': 1, 'age': 1, 'weight(t)': 2, 'japanese name': 1, 'last position seen': 3, 'date arrival': 1, 'last date seen': 1, 'attributes': 1, 'Date Type': 1, 'timestamp': 1, 'Cybertronian': 1, 'function(binary)': 1, 'NullType': 7}}

# %%
t.run()
# Out:
# Creating file ../test_df_cols_dask.py
# Done

# %%
source_df.cols.names("rank", ["str", "int", "float"], True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-352-e7ad9a8317e7> in <module>
# ----> 1 source_df.cols.names("rank", ["str", "int", "float"], True)
#
# ~\Documents\Optimus\optimus\engines\base\columns.py in names(self, col_names, by_dtypes, invert)
#     997
#     998     def names(self, col_names="*", by_dtypes=None, invert=False):
# --> 999         columns = parse_columns(self.df, col_names, filter_by_column_dtypes=by_dtypes, invert=invert)
#    1000         return columns
#    1001
#
# ~\Documents\Optimus\optimus\helpers\columns.py in parse_columns(df, cols_args, get_args, is_regex, filter_by_column_dtypes, accepts_missing_cols, invert)
#     210         # Get columns for every data type
#     211         # print("filter", filter_by_column_dtypes)
# --> 212         columns_filtered = filter_col_name_by_dtypes(df, filter_by_column_dtypes)
#     213         # Intersect the columns filtered per data type from the whole spark with the columns passed to the function
#     214         final_columns = list(OrderedSet(cols).intersection(columns_filtered))
#
# ~\Documents\Optimus\optimus\helpers\columns.py in filter_col_name_by_dtypes(df, data_type)
#     368     for col_name in df.cols.names():
#     369         for dt in data_type:
# --> 370             if (df.cols.schema_dtype(col_name) is dt) or (isinstance(df.cols.schema_dtype(col_name), dt)):
#     371                 result.append(col_name)
#     372     return result
#
# TypeError: isinstance() arg 2 must be a type or tuple of types

# %%
t.create(None, "cols.count_zeros", None, "json", None, numeric_col)
# Out:
# Creating test_cols_count_zeros() test function...
# ["'height(ft)'"]
# {'zeros': {'height(ft)': 0}}

# %%
source_df.compute()
# Out:
#            names  height(ft)          function  rank        age  weight(t)  \
# 0       Optim'us       -28.0            Leader  10.0  5000000.0        4.3
# 1   bumbl#ebéé          17.0         Espionage   7.0  5000000.0        2.0
# 2      ironhide&        26.0          Security   7.0  5000000.0        4.0
# 3           Jazz        13.0  First Lieutenant   8.0  5000000.0        1.8
# 4       Megatron         NaN              None  10.0  5000000.0        5.7
# 5  Metroplex_)^$       300.0    Battle Station   8.0  5000000.0        NaN
# 6           None         NaN              None   NaN        NaN        NaN
#
#         japanese name     last position seen date arrival last date seen  \
# 0    [Inochi, Convoy]   19.442735,-99.201111   1980/04/10     2016/09/10
# 1  [Bumble, Goldback]   10.642707,-71.612534   1980/04/10     2015/08/10
# 2        [Roadbuster]  37.789563,-122.400356   1980/04/10     2014/07/10
# 3           [Meister]  33.670666,-117.841553   1980/04/10     2013/06/10
# 4          [Megatron]                   None   1980/04/10     2012/05/10
# 5         [Metroflex]                   None   1980/04/10     2011/04/10
# 6                None                   None         None           None
#
#          attributes   Date Type  timestamp Cybertronian  \
# 0  [8.5344, 4300.0]  2016-09-10 2014-06-24         True
# 1   [5.334, 2000.0]  2015-08-10 2014-06-24         True
# 2  [7.9248, 4000.0]  2014-06-24 2014-06-24         True
# 3  [3.9624, 1800.0]  2013-06-24 2014-06-24         True
# 4    [None, 5700.0]  2012-05-10 2014-06-24         True
# 5     [91.44, None]  2011-04-10 2014-06-24         True
# 6              None        None        NaT         None
#
#                                     function(binary) NullType
# 0                       [76, 101, 97, 100, 101, 114]     None
# 1        [69, 115, 112, 105, 111, 110, 97, 103, 101]     None
# 2             [83, 101, 99, 117, 114, 105, 116, 121]     None
# 3  [70, 105, 114, 115, 116, 32, 76, 105, 101, 117...     None
# 4                                [78, 111, 110, 101]     None
# 5  [66, 97, 116, 116, 108, 101, 32, 83, 116, 97, ...     None
# 6                                               None     None

# %%
t.create(None, "cols.count_zeros", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_count_zeros_all_columns() test function...
# ["'*'"]
# {'zeros': {'names': 0, 'height(ft)': 0, 'function': 0, 'rank': 0, 'age': 0, 'weight(t)': 0, 'japanese name': 0, 'last position seen': 0, 'date arrival': 0, 'last date seen': 0, 'attributes': 0, 'Date Type': 0, 'Cybertronian': 0, 'function(binary)': 0, 'NullType': 0}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
source_df.cols.names()
# Out:
# ['names',
#  'height(ft)',
#  'function',
#  'rank',
#  'age',
#  'weight(t)',
#  'japanese name',
#  'last position seen',
#  'date arrival',
#  'last date seen',
#  'attributes',
#  'Date Type',
#  'timestamp',
#  'Cybertronian',
#  'function(binary)',
#  'NullType']

# %% [markdown]
# ## Value counts

# %%
t.create(None, "cols.value_counts", None, "json", None, numeric_col)
t.run()
# Out:
# Creating test_cols_value_counts() test function...
# ["'height(ft)'"]
# col_name height(ft)
# {'height(ft)': {300.0: 1, 26.0: 1, 17.0: 1, 13.0: 1, -28.0: 1}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.value_counts", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_value_counts_all_columns() test function...
# ["'*'"]
# col_name names
# col_name height(ft)
# col_name function
# col_name rank
# col_name age
# col_name weight(t)
# col_name japanese name
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1653, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# distributed.worker - WARNING -  Compute Failed
# Function:  execute_task
# args:      ((<function apply at 0x000001D87AC5D678>, <function value_counts_aggregate at 0x000001D87B815DC8>, [(<function _concat at 0x000001D87B5573A8>, [(<function apply at 0x000001D87AC5D678>, <methodcaller: value_counts>, [(subgraph_callable,            names  height(ft)          function  rank        age  weight(t)  \
# 0       Optim'us       -28.0            Leader  10.0  5000000.0        4.3
# 1   bumbl#ebéé          17.0         Espionage   7.0  5000000.0        2.0
# 2      ironhide&        26.0          Security   7.0  5000000.0        4.0
# 3           Jazz        13.0  First Lieutenant   8.0  5000000.0        1.8
# 4       Megatron         NaN              None  10.0  5000000.0        5.7
# 5  Metroplex_)^$       300.0    Battle Station   8.0  5000000.0        NaN
# 6           None         NaN              None   NaN        NaN        NaN
#
#         japanese name     last position seen date arrival last date seen  \
# 0    [Inochi, Convoy]   19.442735,-99.201111   1980/04/10     2
# kwargs:    {}
# Exception: TypeError("unhashable type: 'list'")
# col_name last position seen
# col_name date arrival
# col_name last date seen
# col_name attributes
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1653, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# distributed.worker - WARNING -  Compute Failed
# Function:  execute_task
# args:      ((<function apply at 0x000001D87AC5D678>, <function value_counts_aggregate at 0x000001D87B815DC8>, [(<function _concat at 0x000001D87B5573A8>, [(<function apply at 0x000001D87AC5D678>, <methodcaller: value_counts>, [(subgraph_callable,            names  height(ft)          function  rank        age  weight(t)  \
# 0       Optim'us       -28.0            Leader  10.0  5000000.0        4.3
# 1   bumbl#ebéé          17.0         Espionage   7.0  5000000.0        2.0
# 2      ironhide&        26.0          Security   7.0  5000000.0        4.0
# 3           Jazz        13.0  First Lieutenant   8.0  5000000.0        1.8
# 4       Megatron         NaN              None  10.0  5000000.0        5.7
# 5  Metroplex_)^$       300.0    Battle Station   8.0  5000000.0        NaN
# 6           None         NaN              None   NaN        NaN        NaN
#
#         japanese name     last position seen date arrival last date seen  \
# 0    [Inochi, Convoy]   19.442735,-99.201111   1980/04/10     2
# kwargs:    {}
# Exception: TypeError("unhashable type: 'list'")
# col_name Date Type
# col_name timestamp
# col_name Cybertronian
# col_name function(binary)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'bytearray'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1653, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'bytearray'
# distributed.worker - WARNING -  Compute Failed
# Function:  execute_task
# args:      ((<function apply at 0x000001D87AC5D678>, <function value_counts_aggregate at 0x000001D87B815DC8>, [(<function _concat at 0x000001D87B5573A8>, [(<function apply at 0x000001D87AC5D678>, <methodcaller: value_counts>, [(subgraph_callable,            names  height(ft)          function  rank        age  weight(t)  \
# 0       Optim'us       -28.0            Leader  10.0  5000000.0        4.3
# 1   bumbl#ebéé          17.0         Espionage   7.0  5000000.0        2.0
# 2      ironhide&        26.0          Security   7.0  5000000.0        4.0
# 3           Jazz        13.0  First Lieutenant   8.0  5000000.0        1.8
# 4       Megatron         NaN              None  10.0  5000000.0        5.7
# 5  Metroplex_)^$       300.0    Battle Station   8.0  5000000.0        NaN
# 6           None         NaN              None   NaN        NaN        NaN
#
#         japanese name     last position seen date arrival last date seen  \
# 0    [Inochi, Convoy]   19.442735,-99.201111   1980/04/10     2
# kwargs:    {}
# Exception: TypeError("unhashable type: 'bytearray'")
# col_name NullType
# {'names': {'ironhide&': 1, 'bumbl#ebéé  ': 1, "Optim'us": 1, 'Metroplex_)^$': 1, 'Megatron': 1, 'Jazz': 1}, 'height(ft)': {300.0: 1, 26.0: 1, 17.0: 1, 13.0: 1, -28.0: 1}, 'function': {'Security': 1, 'None': 1, 'Leader': 1, 'First Lieutenant': 1, 'Espionage': 1, 'Battle Station': 1}, 'rank': {10.0: 2, 8.0: 2, 7.0: 2}, 'age': {5000000.0: 6}, 'weight(t)': {5.7: 1, 4.3: 1, 4.0: 1, 2.0: 1, 1.8: 1}, 'last position seen': {'37.789563,-122.400356': 1, '33.670666,-117.841553': 1, '19.442735,-99.201111': 1, '10.642707,-71.612534': 1}, 'date arrival': {'1980/04/10': 6}, 'last date seen': {'2016/09/10': 1, '2015/08/10': 1, '2014/07/10': 1, '2013/06/10': 1, '2012/05/10': 1, '2011/04/10': 1}, 'Date Type': {datetime.date(2016, 9, 10): 1, datetime.date(2015, 8, 10): 1, datetime.date(2014, 6, 24): 1, datetime.date(2013, 6, 24): 1, datetime.date(2012, 5, 10): 1, datetime.date(2011, 4, 10): 1}, 'timestamp': {Timestamp('2014-06-24 00:00:00'): 6}, 'Cybertronian': {True: 6}, 'NullType': {}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.count_uniques", None, "json", None, numeric_col)
t.run()
# Out:
# Creating test_cols_count_uniques() test function...
# ["'height(ft)'"]
# {'height(ft)': {'count_uniques': 5}}
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.count_uniques", "all_columns", "json", None, "*")
t.run()
# Out:
# distributed.worker - WARNING -  Compute Failed
# Function:  _count_uniques
# args:      (0    [8.5344, 4300.0]
# 1     [5.334, 2000.0]
# 2    [7.9248, 4000.0]
# 3    [3.9624, 1800.0]
# 4      [None, 5700.0]
# 5       [91.44, None]
# 6                None
# Name: attributes, dtype: object)
# kwargs:    {}
# Exception: TypeError("unhashable type: 'list'")
# Creating test_cols_count_uniques_all_columns() test function...
# ["'*'"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-425-d31854f60df8> in <module>
# ----> 1 t.create(None, "cols.count_uniques", "all_columns", "json", None, "*")
#       2 t.run()
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     218                 df_func = getattr(df_func, f)
#     219
# --> 220             df_result = df_func(*args, **kwargs)
#     221
#     222
#
# ~\Documents\Optimus\optimus\engines\base\dask\columns.py in count_uniques(self, columns, estimate, compute)
#     143
#     144         if compute is True:
# --> 145             result = result.compute()
#     146
#     147         return result
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2593                     should_rejoin = False
#    2594             try:
# -> 2595                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2596             finally:
#    2597                 for f in futures.values():
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in gather(self, futures, errors, direct, asynchronous)
#    1892                 direct=direct,
#    1893                 local_worker=local_worker,
# -> 1894                 asynchronous=asynchronous,
#    1895             )
#    1896
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     776         else:
#     777             return sync(
# --> 778                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     779             )
#     780
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
# --> 348         raise exc.with_traceback(tb)
#     349     else:
#     350         return result[0]
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in f()
#     330             if callback_timeout is not None:
#     331                 future = asyncio.wait_for(future, callback_timeout)
# --> 332             result[0] = yield future
#     333         except Exception as exc:
#     334             error[0] = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\tornado\gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in _gather(self, futures, errors, direct, local_worker)
#    1751                             exc = CancelledError(key)
#    1752                         else:
# -> 1753                             raise exception.with_traceback(traceback)
#    1754                         raise exc
#    1755                     if errors == "skip":
#
# ~\Documents\Optimus\optimus\engines\base\dask\columns.py in _count_uniques(_df)
#     133         @delayed
#     134         def _count_uniques(_df):
# --> 135             return _df.nunique()
#     136
#     137         @delayed
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\base.py in nunique(self, dropna)
#    1282         4
#    1283         """
# -> 1284         uniqs = self.unique()
#    1285         n = len(uniqs)
#    1286         if dropna and isna(uniqs).any():
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in unique(self)
#    1814         Categories (3, object): [a < b < c]
#    1815         """
# -> 1816         result = super().unique()
#    1817         return result
#    1818
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\base.py in unique(self)
#    1244             result = values.unique()
#    1245         else:
# -> 1246             result = unique1d(values)
#    1247
#    1248         return result
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\algorithms.py in unique(values)
#     380
#     381     table = htable(len(values))
# --> 382     uniques = table.unique(values)
#     383     uniques = _reconstruct_data(uniques, original.dtype, original)
#     384     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
source_df.compute()
# Out:
#            names  height(ft)          function  rank        age  weight(t)  \
# 0       Optim'us       -28.0            Leader  10.0  5000000.0        4.3
# 1   bumbl#ebéé          17.0         Espionage   7.0  5000000.0        2.0
# 2      ironhide&        26.0          Security   7.0  5000000.0        4.0
# 3           Jazz        13.0  First Lieutenant   8.0  5000000.0        1.8
# 4       Megatron         NaN              None  10.0  5000000.0        5.7
# 5  Metroplex_)^$       300.0    Battle Station   8.0  5000000.0        NaN
# 6           None         NaN              None   NaN        NaN        NaN
#
#         japanese name     last position seen date arrival last date seen  \
# 0    [Inochi, Convoy]   19.442735,-99.201111   1980/04/10     2016/09/10
# 1  [Bumble, Goldback]   10.642707,-71.612534   1980/04/10     2015/08/10
# 2        [Roadbuster]  37.789563,-122.400356   1980/04/10     2014/07/10
# 3           [Meister]  33.670666,-117.841553   1980/04/10     2013/06/10
# 4          [Megatron]                   None   1980/04/10     2012/05/10
# 5         [Metroflex]                   None   1980/04/10     2011/04/10
# 6                None                   None         None           None
#
#          attributes   Date Type  timestamp Cybertronian  \
# 0  [8.5344, 4300.0]  2016-09-10 2014-06-24         True
# 1   [5.334, 2000.0]  2015-08-10 2014-06-24         True
# 2  [7.9248, 4000.0]  2014-06-24 2014-06-24         True
# 3  [3.9624, 1800.0]  2013-06-24 2014-06-24         True
# 4    [None, 5700.0]  2012-05-10 2014-06-24         True
# 5     [91.44, None]  2011-04-10 2014-06-24         True
# 6              None        None        NaT         None
#
#                                     function(binary) NullType
# 0                       [76, 101, 97, 100, 101, 114]     None
# 1        [69, 115, 112, 105, 111, 110, 97, 103, 101]     None
# 2             [83, 101, 99, 117, 114, 105, 116, 121]     None
# 3  [70, 105, 114, 115, 116, 32, 76, 105, 101, 117...     None
# 4                                [78, 111, 110, 101]     None
# 5  [66, 97, 116, 116, 108, 101, 32, 83, 116, 97, ...     None
# 6                                               None     None

# %%
t.create(None, "cols.unique", None, "json", None, numeric_col)
t.run()
# Out:
# Creating test_cols_unique() test function...
# ["'height(ft)'"]
# 0    -28.0
# 1     17.0
# 2     26.0
# 3     13.0
# 4      NaN
# 5    300.0
# Name: height(ft), dtype: float64
# Creating file ../test_df_cols_dask.py
# Done

# %%
t.create(None, "cols.unique", "all_columns", "json", None, "*")
t.run()
# Out:
# Creating test_cols_unique_all_columns() test function...
# ["'*'"]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '*'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-436-2e96d6f84b3c> in <module>
# ----> 1 t.create(None, "cols.unique", "all_columns", "json", None, "*")
#       2 t.run()
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     218                 df_func = getattr(df_func, f)
#     219
# --> 220             df_result = df_func(*args, **kwargs)
#     221
#     222
#
# ~\Documents\Optimus\optimus\engines\base\dask\columns.py in unique(self, columns)
#     410     def unique(self, columns):
#     411         df = self.df
# --> 412         return df[columns].drop_duplicates().compute()
#     413
#     414     def value_counts(self, columns):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in __getitem__(self, key)
#    3491
#    3492             # error is raised from pandas
# -> 3493             meta = self._meta[_extract_meta(key)]
#    3494             dsk = partitionwise_graph(operator.getitem, name, self, key)
#    3495             graph = HighLevelGraph.from_collections(name, dsk, dependencies=[self])
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '*'

# %%
t.create(None, "cols.add", None, "df", None, [numeric_col, numeric_col_B])
# Out:
# Creating test_cols_add() test function...
# ["['height(ft)','rank']"]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-437-86f4635934dd> in <module>
# ----> 1 t.create(None, "cols.add", None, "df", None, [numeric_col, numeric_col_B])
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     227         if output == "df":
#     228
# --> 229             df_result.ext.table()
#     230             expected = "\texpected_df = op.create.df(" + df_result.ext.export() + ")\n"
#     231         elif output == "json":
#
# AttributeError: 'NoneType' object has no attribute 'ext'

# %%
t.create(None, "cols.add", "all_columns", "df", "*"),

# %%
t.create(None, "cols.sub", None, "df", [numeric_col, numeric_col_B])

# %%
t.create(None, "cols.sub", "all_columns", "df", "*")

# %%
t.create(None, "cols.mul", None, "df", [numeric_col, numeric_col_B])

# %%
t.create(None, "cols.mul", "all_columns", "df", "*")

# %%
t.create(None, "cols.div", None, "df", [numeric_col, numeric_col_B])

# %%
t.create(None, "cols.div", "all_columns", "df", "*")

# %%
t.create(None, "cols.z_score", None, "df", numeric_col)

# %%
t.create(None, "cols.z_score", "all_columns", "df", "*")

# %%
t.create(None, "cols.iqr", None, "json", None, numeric_col)

# %%
t.create(None, "cols.iqr", "all_columns", "json", None, "*")

# %%
t.run()

# %%
source_df.cols.names()
# Out:
# ['names',
#  'height(ft)',
#  'function',
#  'rank',
#  'age',
#  'weight(t)',
#  'japanese name',
#  'last position seen',
#  'date arrival',
#  'last date seen',
#  'attributes',
#  'Date Type',
#  'timestamp',
#  'Cybertronian',
#  'function(binary)',
#  'NullType']

# %%
source_df["names"].str.lower().compute()
# Out:
# 0         optim'us
# 1     bumbl#ebéé
# 2        ironhide&
# 3             jazz
# 4         megatron
# 5    metroplex_)^$
# 6             None
# Name: names, dtype: object

# %%
source_df.ext.display()
# Out:
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
t.create(None, "cols.lower", None, "df", None, string_col)
# Out:
# Creating test_cols_lower() test function...
# ["'function'"]
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="leader">
#
#                 leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
t.create(None, "cols.lower", "all_columns", "df", None, "*")
# Out:
# distributed.worker - WARNING -  Compute Failed
# Function:  execute_task
# args:      ((<function safe_head at 0x000001D87B8541F8>, (subgraph_callable, ['names', 'height(ft)', 'function', 'rank', 'age', 'weight(t)', 'japanese name', 'last position seen', 'date arrival', 'last date seen', 'attributes', 'Date Type', 'timestamp', 'Cybertronian', 'function(binary)', 'NullType'], ['names', 'height(ft)', 'function', 'rank', 'age', 'weight(t)', 'japanese name', 'last position seen', 'date arrival', 'last date seen', 'attributes', 'Date Type', 'timestamp', 'Cybertronian', 'function(binary)', 'NullType'],            names  height(ft)          function  rank        age  weight(t)  \
# 0       Optim'us       -28.0            Leader  10.0  5000000.0        4.3
# 1   bumbl#ebéé          17.0         Espionage   7.0  5000000.0        2.0
# 2      ironhide&        26.0          Security   7.0  5000000.0        4.0
# 3           Jazz        13.0  First Lieutenant   8.0  5000000.0        1.8
# 4       Megatron         NaN              None  10.0  5000000.0        5.7
# 5  Metroplex_)
# kwargs:    {}
# Exception: AttributeError("'Series' object has no attribute 'lower'")
# Creating test_cols_lower_all_columns() test function...
# ["'*'"]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-454-ab05c78a49d0> in <module>
# ----> 1 t.create(None, "cols.lower", "all_columns", "df", None, "*")
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     227         if output == "df":
#     228
# --> 229             df_result.ext.table()
#     230             expected = "\texpected_df = op.create.df(" + df_result.ext.export() + ")\n"
#     231         elif output == "json":
#
# ~\Documents\Optimus\optimus\engines\base\extension.py in table(self, limit, columns, title, truncate)
#     456             if __IPYTHON__:
#     457                 # TODO: move the html param to the ::: if __IPYTHON__ and engine.output is "html":
# --> 458                 result = df.ext.table_html(title=title, limit=limit, columns=columns, truncate=truncate)
#     459                 print_html(result)
#     460             else:
#
# ~\Documents\Optimus\optimus\engines\base\extension.py in table_html(self, limit, columns, title, full, truncate, count)
#     405             data = df.cols.select(columns).ext.to_dict()
#     406         else:
# --> 407             data = collect_as_dict(df.cols.select(columns).rows.limit(limit))
#     408
#     409         # Load the Jinja template
#
# ~\Documents\Optimus\optimus\engines\base\dask\rows.py in limit(self, count)
#      56         # return _limit(df, count)
#      57         df = self.df
# ---> 58         return df.head(count)
#      59
#      60     def select(self, condition):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in _head(self, n, npartitions, compute, safe)
#    1036
#    1037         if compute:
# -> 1038             result = result.compute()
#    1039         return result
#    1040
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2593                     should_rejoin = False
#    2594             try:
# -> 2595                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2596             finally:
#    2597                 for f in futures.values():
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in gather(self, futures, errors, direct, asynchronous)
#    1892                 direct=direct,
#    1893                 local_worker=local_worker,
# -> 1894                 asynchronous=asynchronous,
#    1895             )
#    1896
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     776         else:
#     777             return sync(
# --> 778                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     779             )
#     780
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
# --> 348         raise exc.with_traceback(tb)
#     349     else:
#     350         return result[0]
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in f()
#     330             if callback_timeout is not None:
#     331                 future = asyncio.wait_for(future, callback_timeout)
# --> 332             result[0] = yield future
#     333         except Exception as exc:
#     334             error[0] = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\tornado\gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in _gather(self, futures, errors, direct, local_worker)
#    1751                             exc = CancelledError(key)
#    1752                         else:
# -> 1753                             raise exception.with_traceback(traceback)
#    1754                         raise exc
#    1755                     if errors == "skip":
#
# ~\Anaconda3\lib\site-packages\dask\optimization.py in __call__(self, *args)
#    1020         if not len(args) == len(self.inkeys):
#    1021             raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# -> 1022         return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#    1023
#    1024     def __reduce__(self):
#
# ~\Anaconda3\lib\site-packages\dask\core.py in get(dsk, out, cache)
#     149     for key in toposort(dsk):
#     150         task = dsk[key]
# --> 151         result = _execute_task(task, cache)
#     152         cache[key] = result
#     153     result = _execute_task(out, cache)
#
# ~\Anaconda3\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~\Anaconda3\lib\site-packages\dask\utils.py in apply(func, args, kwargs)
#      29 def apply(func, args, kwargs=None):
#      30     if kwargs:
# ---> 31         return func(*args, **kwargs)
#      32     else:
#      33         return func(*args)
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in apply_and_enforce(*args, **kwargs)
#    5235     func = kwargs.pop("_func")
#    5236     meta = kwargs.pop("_meta")
# -> 5237     df = func(*args, **kwargs)
#    5238     if is_dataframe_like(df) or is_series_like(df) or is_index_like(df):
#    5239         if not len(df):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\accessor.py in _delegate_method(obj, accessor, attr, args, kwargs)
#      46     @staticmethod
#      47     def _delegate_method(obj, accessor, attr, args, kwargs):
# ---> 48         out = getattr(getattr(obj, accessor, obj), attr)(*args, **kwargs)
#      49         return maybe_wrap_pandas(obj, out)
#      50
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
t.create(None, "cols.upper", None, "df", None, string_col)
# Out:
# Creating test_cols_upper() test function...
# ["'function'"]
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="LEADER">
#
#                 LEADER
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
t.create(None, "cols.upper", "all_columns", "df", None, "*")
# Out:
# distributed.worker - WARNING -  Compute Failed
# Function:  execute_task
# args:      ((<function safe_head at 0x000001D87B8541F8>, (subgraph_callable, ['names', 'height(ft)', 'function', 'rank', 'age', 'weight(t)', 'japanese name', 'last position seen', 'date arrival', 'last date seen', 'attributes', 'Date Type', 'timestamp', 'Cybertronian', 'function(binary)', 'NullType'], ['names', 'height(ft)', 'function', 'rank', 'age', 'weight(t)', 'japanese name', 'last position seen', 'date arrival', 'last date seen', 'attributes', 'Date Type', 'timestamp', 'Cybertronian', 'function(binary)', 'NullType'],            names  height(ft)          function  rank        age  weight(t)  \
# 0       Optim'us       -28.0            Leader  10.0  5000000.0        4.3
# 1   bumbl#ebéé          17.0         Espionage   7.0  5000000.0        2.0
# 2      ironhide&        26.0          Security   7.0  5000000.0        4.0
# 3           Jazz        13.0  First Lieutenant   8.0  5000000.0        1.8
# 4       Megatron         NaN              None  10.0  5000000.0        5.7
# 5  Metroplex_)
# kwargs:    {}
# Exception: AttributeError("'Series' object has no attribute 'upper'")
# Creating test_cols_upper_all_columns() test function...
# ["'*'"]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-460-cebc4041eeb7> in <module>
# ----> 1 t.create(None, "cols.upper", "all_columns", "df", None, "*")
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     227         if output == "df":
#     228
# --> 229             df_result.ext.table()
#     230             expected = "\texpected_df = op.create.df(" + df_result.ext.export() + ")\n"
#     231         elif output == "json":
#
# ~\Documents\Optimus\optimus\engines\base\extension.py in table(self, limit, columns, title, truncate)
#     456             if __IPYTHON__:
#     457                 # TODO: move the html param to the ::: if __IPYTHON__ and engine.output is "html":
# --> 458                 result = df.ext.table_html(title=title, limit=limit, columns=columns, truncate=truncate)
#     459                 print_html(result)
#     460             else:
#
# ~\Documents\Optimus\optimus\engines\base\extension.py in table_html(self, limit, columns, title, full, truncate, count)
#     405             data = df.cols.select(columns).ext.to_dict()
#     406         else:
# --> 407             data = collect_as_dict(df.cols.select(columns).rows.limit(limit))
#     408
#     409         # Load the Jinja template
#
# ~\Documents\Optimus\optimus\engines\base\dask\rows.py in limit(self, count)
#      56         # return _limit(df, count)
#      57         df = self.df
# ---> 58         return df.head(count)
#      59
#      60     def select(self, condition):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in _head(self, n, npartitions, compute, safe)
#    1036
#    1037         if compute:
# -> 1038             result = result.compute()
#    1039         return result
#    1040
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2593                     should_rejoin = False
#    2594             try:
# -> 2595                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2596             finally:
#    2597                 for f in futures.values():
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in gather(self, futures, errors, direct, asynchronous)
#    1892                 direct=direct,
#    1893                 local_worker=local_worker,
# -> 1894                 asynchronous=asynchronous,
#    1895             )
#    1896
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     776         else:
#     777             return sync(
# --> 778                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     779             )
#     780
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
# --> 348         raise exc.with_traceback(tb)
#     349     else:
#     350         return result[0]
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in f()
#     330             if callback_timeout is not None:
#     331                 future = asyncio.wait_for(future, callback_timeout)
# --> 332             result[0] = yield future
#     333         except Exception as exc:
#     334             error[0] = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\tornado\gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in _gather(self, futures, errors, direct, local_worker)
#    1751                             exc = CancelledError(key)
#    1752                         else:
# -> 1753                             raise exception.with_traceback(traceback)
#    1754                         raise exc
#    1755                     if errors == "skip":
#
# ~\Anaconda3\lib\site-packages\dask\optimization.py in __call__(self, *args)
#    1020         if not len(args) == len(self.inkeys):
#    1021             raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# -> 1022         return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#    1023
#    1024     def __reduce__(self):
#
# ~\Anaconda3\lib\site-packages\dask\core.py in get(dsk, out, cache)
#     149     for key in toposort(dsk):
#     150         task = dsk[key]
# --> 151         result = _execute_task(task, cache)
#     152         cache[key] = result
#     153     result = _execute_task(out, cache)
#
# ~\Anaconda3\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~\Anaconda3\lib\site-packages\dask\utils.py in apply(func, args, kwargs)
#      29 def apply(func, args, kwargs=None):
#      30     if kwargs:
# ---> 31         return func(*args, **kwargs)
#      32     else:
#      33         return func(*args)
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in apply_and_enforce(*args, **kwargs)
#    5235     func = kwargs.pop("_func")
#    5236     meta = kwargs.pop("_meta")
# -> 5237     df = func(*args, **kwargs)
#    5238     if is_dataframe_like(df) or is_series_like(df) or is_index_like(df):
#    5239         if not len(df):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\accessor.py in _delegate_method(obj, accessor, attr, args, kwargs)
#      46     @staticmethod
#      47     def _delegate_method(obj, accessor, attr, args, kwargs):
# ---> 48         out = getattr(getattr(obj, accessor, obj), attr)(*args, **kwargs)
#      49         return maybe_wrap_pandas(obj, out)
#      50
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
t.create(None, "cols.trim", None, "df", None, string_col)
# Out:
# Creating test_cols_trim() test function...
# ["'function'"]
# C:\Users\argenisleon\Anaconda3\lib\site-packages\dask\dataframe\core.py:6157: UserWarning: Insufficient elements for `head`. 10 elements requested, only 7 elements available. Try passing larger `npartitions` to `head`.
#   warnings.warn(msg.format(n, len(r)))
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">Viewing 7 of 7 rows / 16 columns</div>
# <div class="info_items" style="margin: 10px 0; font-family: sans-serif; font-size: 10px;">1 partition(s) </div>
#
#
# <table class="optimus_table" style="font-size: 12px;">
#     <thead style="border-bottom: 1px solid black;">
#     <tr>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">names</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">1 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">height(ft)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">2 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">3 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">rank</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">4 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">age</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">5 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">weight(t)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">6 (float64)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">japanese name</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">7 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last position seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">8 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">date arrival</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">9 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">last date seen</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">10 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">attributes</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">11 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Date Type</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">12 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">timestamp</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">13 (datetime64[ns])</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">Cybertronian</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">14 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">function(binary)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">15 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#         <th style="font-family: sans-serif;">
#             <div class="column_name" style="font-size: 1.2em;">NullType</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">16 (object)</div>
#             <div class="data_type" style="font-size: 0.8em; font-weight: normal;">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody style="font-family: monospace; border-bottom: 1px solid #cccccc;">
#
#     <tr>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Optim'us">
#
#                 Optim'us
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="-28.0">
#
#                 -28.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="Leader">
#
#                 Leader
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="10.0">
#
#                 10.0
#
#             </div>
#         </td>
#
#         <td style="border: 0px;">
#             <div style="min-height: 14px;" title="5000000.0">

# %%
t.create(None, "cols.trim", "all_columns", "df", None, "*")
# Out:
# distributed.worker - WARNING -  Compute Failed
# Function:  execute_task
# args:      ((<function safe_head at 0x000001D87B8541F8>, (subgraph_callable, ['names', 'height(ft)', 'function', 'rank', 'age', 'weight(t)', 'japanese name', 'last position seen', 'date arrival', 'last date seen', 'attributes', 'Date Type', 'timestamp', 'Cybertronian', 'function(binary)', 'NullType'], ['names', 'height(ft)', 'function', 'rank', 'age', 'weight(t)', 'japanese name', 'last position seen', 'date arrival', 'last date seen', 'attributes', 'Date Type', 'timestamp', 'Cybertronian', 'function(binary)', 'NullType'],            names  height(ft)          function  rank        age  weight(t)  \
# 0       Optim'us       -28.0            Leader  10.0  5000000.0        4.3
# 1   bumbl#ebéé          17.0         Espionage   7.0  5000000.0        2.0
# 2      ironhide&        26.0          Security   7.0  5000000.0        4.0
# 3           Jazz        13.0  First Lieutenant   8.0  5000000.0        1.8
# 4       Megatron         NaN              None  10.0  5000000.0        5.7
# 5  Metroplex_)
# kwargs:    {}
# Exception: AttributeError("'Series' object has no attribute 'strip'")
# Creating test_cols_trim_all_columns() test function...
# ["'*'"]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-465-8024856b8645> in <module>
# ----> 1 t.create(None, "cols.trim", "all_columns", "df", None, "*")
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     227         if output == "df":
#     228
# --> 229             df_result.ext.table()
#     230             expected = "\texpected_df = op.create.df(" + df_result.ext.export() + ")\n"
#     231         elif output == "json":
#
# ~\Documents\Optimus\optimus\engines\base\extension.py in table(self, limit, columns, title, truncate)
#     456             if __IPYTHON__:
#     457                 # TODO: move the html param to the ::: if __IPYTHON__ and engine.output is "html":
# --> 458                 result = df.ext.table_html(title=title, limit=limit, columns=columns, truncate=truncate)
#     459                 print_html(result)
#     460             else:
#
# ~\Documents\Optimus\optimus\engines\base\extension.py in table_html(self, limit, columns, title, full, truncate, count)
#     405             data = df.cols.select(columns).ext.to_dict()
#     406         else:
# --> 407             data = collect_as_dict(df.cols.select(columns).rows.limit(limit))
#     408
#     409         # Load the Jinja template
#
# ~\Documents\Optimus\optimus\engines\base\dask\rows.py in limit(self, count)
#      56         # return _limit(df, count)
#      57         df = self.df
# ---> 58         return df.head(count)
#      59
#      60     def select(self, condition):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in head(self, n, npartitions, compute)
#    1003             Whether to compute the result, default is True.
#    1004         """
# -> 1005         return self._head(n=n, npartitions=npartitions, compute=compute, safe=True)
#    1006
#    1007     def _head(self, n, npartitions, compute, safe):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in _head(self, n, npartitions, compute, safe)
#    1036
#    1037         if compute:
# -> 1038             result = result.compute()
#    1039         return result
#    1040
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\Anaconda3\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2593                     should_rejoin = False
#    2594             try:
# -> 2595                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2596             finally:
#    2597                 for f in futures.values():
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in gather(self, futures, errors, direct, asynchronous)
#    1892                 direct=direct,
#    1893                 local_worker=local_worker,
# -> 1894                 asynchronous=asynchronous,
#    1895             )
#    1896
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     776         else:
#     777             return sync(
# --> 778                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     779             )
#     780
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     346     if error[0]:
#     347         typ, exc, tb = error[0]
# --> 348         raise exc.with_traceback(tb)
#     349     else:
#     350         return result[0]
#
# ~\Anaconda3\lib\site-packages\distributed\utils.py in f()
#     330             if callback_timeout is not None:
#     331                 future = asyncio.wait_for(future, callback_timeout)
# --> 332             result[0] = yield future
#     333         except Exception as exc:
#     334             error[0] = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\tornado\gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# ~\Anaconda3\lib\site-packages\distributed\client.py in _gather(self, futures, errors, direct, local_worker)
#    1751                             exc = CancelledError(key)
#    1752                         else:
# -> 1753                             raise exception.with_traceback(traceback)
#    1754                         raise exc
#    1755                     if errors == "skip":
#
# ~\Anaconda3\lib\site-packages\dask\optimization.py in __call__(self, *args)
#    1020         if not len(args) == len(self.inkeys):
#    1021             raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# -> 1022         return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#    1023
#    1024     def __reduce__(self):
#
# ~\Anaconda3\lib\site-packages\dask\core.py in get(dsk, out, cache)
#     149     for key in toposort(dsk):
#     150         task = dsk[key]
# --> 151         result = _execute_task(task, cache)
#     152         cache[key] = result
#     153     result = _execute_task(out, cache)
#
# ~\Anaconda3\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# ~\Anaconda3\lib\site-packages\dask\utils.py in apply(func, args, kwargs)
#      29 def apply(func, args, kwargs=None):
#      30     if kwargs:
# ---> 31         return func(*args, **kwargs)
#      32     else:
#      33         return func(*args)
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in apply_and_enforce(*args, **kwargs)
#    5235     func = kwargs.pop("_func")
#    5236     meta = kwargs.pop("_meta")
# -> 5237     df = func(*args, **kwargs)
#    5238     if is_dataframe_like(df) or is_series_like(df) or is_index_like(df):
#    5239         if not len(df):
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\accessor.py in _delegate_method(obj, accessor, attr, args, kwargs)
#      46     @staticmethod
#      47     def _delegate_method(obj, accessor, attr, args, kwargs):
# ---> 48         out = getattr(getattr(obj, accessor, obj), attr)(*args, **kwargs)
#      49         return maybe_wrap_pandas(obj, out)
#      50
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
t.create(None, "cols.reverse", None, "df", string_col)
# Out:
# Creating test_cols_reverse_function() test function...
# []
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-466-61e7b410115e> in <module>
# ----> 1 t.create(None, "cols.reverse", None, "df", string_col)
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     218                 df_func = getattr(df_func, f)
#     219
# --> 220             df_result = df_func(*args, **kwargs)
#     221
#     222
#
# TypeError: reverse() missing 1 required positional argument: 'input_cols'

# %%
t.create(None, "cols.reverse", "all_columns", "df", "*")

# %%
t.create(None, "cols.remove_accents", None, "df", None,string_col)
# Out:
# Creating test_cols_remove_accents() test function...
# ["'function'"]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-468-d160b212fb6a> in <module>
# ----> 1 t.create(None, "cols.remove_accents", None, "df", None,string_col)
#
# ~\Documents\Optimus\optimus\helpers\test.py in create(self, obj, method, suffix, output, additional_method, *args, **kwargs)
#     218                 df_func = getattr(df_func, f)
#     219
# --> 220             df_result = df_func(*args, **kwargs)
#     221
#     222
#
# ~\Documents\Optimus\optimus\engines\base\dask\columns.py in remove_accents(self, input_cols, output_cols)
#     654         return df.cols.apply(input_cols, _remove_accents, func_return_type=str,
#     655                              filter_col_by_dtypes=df.constants.STRING_TYPES,
# --> 656                              output_cols=output_cols)
#     657
#     658     def remove(self, input_cols, search=None, search_by="chars", output_cols=None):
#
# ~\Documents\Optimus\optimus\engines\base\dask\columns.py in apply(self, input_cols, func, func_return_type, args, func_type, when, filter_col_by_dtypes, output_cols, skip_output_cols_processing, meta_action, w)
#    1001             # Preserve actions for the profiler
#    1002             df = df.meta.preserve(df, meta_action, output_col)
# -> 1003         df = df.assign(**result)
#    1004         return df.cols.select(output_ordered_columns)
#    1005
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in assign(self, **kwargs)
#    3805         # Figure out columns of the output
#    3806         df2 = self._meta_nonempty.assign(**_extract_meta(kwargs, nonempty=True))
# -> 3807         return elemwise(methods.assign, self, *pairs, meta=df2)
#    3808
#    3809     @derived_from(pd.DataFrame, ua_args=["index"])
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\core.py in elemwise(op, *args, **kwargs)
#    4699     from .multi import _maybe_align_partitions
#    4700
# -> 4701     args = _maybe_align_partitions(args)
#    4702     dasks = [arg for arg in args if isinstance(arg, (_Frame, Scalar, Array))]
#    4703     dfs = [df for df in dasks if isinstance(df, _Frame)]
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\multi.py in _maybe_align_partitions(args)
#     163     divisions = dfs[0].divisions
#     164     if not all(df.divisions == divisions for df in dfs):
# --> 165         dfs2 = iter(align_partitions(*dfs)[0])
#     166         return [a if not isinstance(a, _Frame) else next(dfs2) for a in args]
#     167     return args
#
# ~\Anaconda3\lib\site-packages\dask\dataframe\multi.py in align_partitions(*dfs)
#     118     if not all(df.known_divisions for df in dfs1):
#     119         raise ValueError(
# --> 120             "Not all divisions are known, can't align "
#     121             "partitions. Please use `set_index` "
#     122             "to set the index."
#
# ValueError: Not all divisions are known, can't align partitions. Please use `set_index` to set the index.

# %%
t.create(None, "cols.remove_accents", "all_columns", "df", string_col)

# %%
source_df.table()

# %%
t.create(None, "cols.remove_special_chars", None, "df", string_col)

# %%
t.create(None, "cols.remove_special_chars", "all_columns", "df", None, "*")
t.run()
# t.create(None, "cols.value_counts", None, "json", None, numeric_col)

# %%
source_df.cols.remove_special_chars("*").table()

# %%
t.create(None, "cols.remove_white_spaces", None, "df", string_col)

# %%
t.create(None, "cols.remove_white_spaces", "all_columns", "df", "*")

# %%
t.create(None, "cols.date_transform", None, "df", date_col, "yyyy/MM/dd", "dd-MM-YYYY")

# %%
t.run()

# %%
t.create(None, "cols.date_transform", "all_columns", "df", [date_col, date_col_B], "yyyy/MM/dd", "dd-MM-YYYY")

# %%
# t.create(None, "cols.years_between", None, "df", date_col, "yyyy/MM/dd")
t.delete(None, "cols.years_between", None, "df", date_col, "yyyy/MM/dd")

# %%
# t.create(None, "cols.years_between", "multiple_columns", "df", [date_col, date_col_B], "yyyy/MM/dd")
t.delete(None, "cols.years_between", "multiple_columns", "df", [date_col, date_col_B], "yyyy/MM/dd")

# %%
t.run()

# %%
t.create(None, "cols.impute", None, "df", numeric_col_B)

# %%
# %%time
t.create(None, "cols.impute", "all_columns", "df", None, "names", "categorical")

# %%
t.run()

# %% [markdown]
# ## Hist

# %%
t.create(None, "cols.hist", None, "json", None, ["height(ft)", numeric_col_B], 4)
t.run()

# %%
t.create(None, "cols.hist", "all_columns", "json", None, "Date Type", 4)

# %%
t.run()

# %%
t.create(None, "cols.frequency", None, "dict", None, numeric_col_B, 4)
t.run()

# %%
t.create(None, "cols.frequency", "all_columns", "dict", None, "*", 4)
t.run()

# %%
t.create(None, "cols.schema_dtype", None, "json", numeric_col_B)

# %%
# Problems with casting
# t.delete(None, "cols.schema_dtype", "all_columns", "json", "*")
t.run()

# %%
t.create(None, "cols.dtypes", None, "json", None, numeric_col_B)

# %%
t.run()

# %%
t.create(None, "cols.dtypes", "all_columns", "json", "*")

# %%
t.create(None, "cols.select_by_dtypes", "str", "df", None, "str")

# %%
t.create(None, "cols.select_by_dtypes", "int", "df", "int")

# %%
t.create(None, "cols.select_by_dtypes", "float", "df", "float")

# %%
t.create(None, "cols.select_by_dtypes", "array", "df", "array")

# %%
t.create(None, "cols.names", None, "json")

# %%
t.create(None, "cols.qcut", None, "df", numeric_col_B, 4)

# %%
t.create(None, "cols.qcut", "all_columns", "df", "*", 4)

# %%
t.create(None, "cols.clip", None, "df", numeric_col_B, 3, 5)

# %%
t.create(None, "cols.clip", "all_columns", "df", "*", 3, 5)

# %%
t.create(None, "cols.replace", "full", "df", None, string_col, ["First Lieutenant", "Battle"], "Match",
         search_by="full")

# %%
t.create(None, "cols.replace", "words", "df", None, string_col, ["Security", "Leader"], "Match", search_by="words")
t.run()

# %%
t.create(None, "cols.replace", "chars", "df", None, string_col, ["F", "E"], "Match", search_by="chars")

# %%
t.create(None, "cols.replace", "numeric", "df", None, "age", 5000000, 5, search_by="numeric")

# %%
t.run()

# %%
# Assert is failing I can see why
t.create(None, "cols.replace", "all_columns", "df", None, "*", ["Jazz", "Leader"], "Match")
t.run()

# %%
# Its necesary to save the function
t.delete(None, "cols.apply_expr", None, "df", numeric_col_B, func)

# %%
# Its necesary to save the function
t.delete(None, "cols.apply_expr", "all_columns", "df", [numeric_col_B, numeric_col_C], func)

# %%
t.create(None, "cols.append", "number", "df", new_col, 1)

# %%
df_col = op.create.df(
    [
        ("new_col", "str", True),

    ], [
        ("q"), ("w"), ("e"), ("r"),

    ])

# %%
t.create(None, "cols.append", "dataframes", "df", None, df_col)

# %% [markdown]
# t.create(None, "cols.append", "advance", "df", [("new_col_4", "test"),
#                                                ("new_col_5", df[numeric_col_B] * 2),
#                                                ("new_col_6", [1, 2, 3])
#                                                ]),

# %%
t.create(None, "cols.rename", None, "df", numeric_col_B, numeric_col_B + "(old)")

# %%
t.create(None, "cols.rename", "list", "df",
         [numeric_col, numeric_col + "(tons)", numeric_col_B, numeric_col_B + "(old)"])

# %%
t.create(None, "cols.rename", "function", "df", str.upper)

# %%
t.create(None, "cols.drop", None, "df", numeric_col_B)

# %%
t.create(None, "cols.cast", None, "df", string_col, "string")

# %%
t.create(None, "cols.cast", "all_columns", "df", "*", "string")

# %%
t.run()

# %%
# Problems with precision
t.delete(None, "cols.cast", "vector", "df", array_col, Vectors)

# %%
t.create(None, "cols.keep", None, "df", numeric_col_B)

# %%
t.create(None, "cols.move", "after", "df", numeric_col_B, "after", array_col)

# %%
t.create(None, "cols.move", "before", "df", numeric_col_B, "before", array_col)

# %%
t.create(None, "cols.move", "beginning", "df", numeric_col_B, "beginning")

# %%
t.create(None, "cols.move", "end", "df", numeric_col_B, "end")

# %%
t.create(None, "cols.select", None, "df", 0, numeric_col)

# %%
t.create(None, "cols.select", "regex", "df", "n.*", regex=True),

# %%
t.create(None, "cols.sort", None, "df")
t.run()

# %%
t.create(None, "cols.sort", "desc", "df", None, "desc")

# %%
t.create(None, "cols.sort", "asc", "df", None, "asc")

# %%
t.run()

# %%
t.create(None, "cols.fill_na", None, "df", numeric_col, "1")

# %%
t.create(None, "cols.fill_na", "array", "df", None, "japanese name", ["1", "2"])

# %%
t.run()

# %%
t.create(None, "cols.fill_na", "bool", "df", None, "Cybertronian", False)

# %%
t.run()

# %%
t.create(None, "cols.fill_na", "all_columns", "df", ["names", "height(ft)", "function", "rank", "age"], "2")

# %% [markdown]
# ## Nest

# %%
t.create(None, "cols.nest", None, "df", None, [numeric_col, numeric_col_B], separator=" ", output_col=new_col)

# %%
# t.create(None, "cols.nest", "mix", "df", [F.col(numeric_col_C), F.col(numeric_col_B)], "E", separator="--")

# %%
df_na = source_df.cols.drop("NullType").rows.drop_na("*")

t.create(df_na, "cols.nest", "vector_all_columns", "df", None, [numeric_col_C, numeric_col_B], shape="vector",
         output_col=new_col)

# %%
t.create(df_na, "cols.nest", "vector", "df", None, [numeric_col_C, numeric_col_B], shape="vector", output_col=new_col)

# %%
t.create(None, "cols.nest", "array", "df", None, [numeric_col, numeric_col_B, numeric_col_C], shape="array",
         output_col=new_col)

# %%
t.create(None, "cols.count_by_dtypes", None, "dict", None, "*", infer=False)

# %%
t.create(None, "cols.count_by_dtypes", "infer", "dict", None, "*", infer=True)

# %%
t.run()

# %%
dtypes_df = op.create.df(
    [
        ("col 1", "str", True),
        ("col 2", "str", True),
        ("col 3", "int", True),

    ],
    [
        ("male", "male", 1),
        ("optimus", "bumblebee", 1),
        ("3", "4.1", 1),
        ("true", "False", 1),
        ("[1,2,3,4]", "(1,2,3,4)", 1),
        ("{1,2,3,4}", "{'key1' :1 , 'key2':2}", 1),
        ("1.1.1.1", "123.123.123.123", 1),
        ("http://hi-optimuse.com", "https://hi-bumblebee.com", 1),
        ("optimus@cybertron.com", "bumblebee@cybertron.com", 1),
        ("5123456789123456", "373655783158306", 1),
        ("11529", "30345", 1),
        ("04/10/1980", "04/10/1980", 1),
        ("null", "Null", 1),
        ("", "", 1),
        (None, None, 1)

    ], infer_schema=True)

# %%
t.create(dtypes_df, "cols.count_by_dtypes", "infer", "dict", None, "*", infer=True)

# %%
t.run()

# %%
t.create(source_df, "cols.count_by_dtypes", None, "dict", None, "*", infer=False)

# %%
t.run()

# %%
source_df.table()

# %%
import logging
import sys
from datetime import date, datetime

from pyspark.sql.types import *

from optimus import Optimus

mismatch_df = op.create.df(
    [
        ("names", "str", True),
        ("height(ft)", "int", True),
        ("function", "str", True),
        ("rank", "int", True),
        ("age", "int", True),
        ("weight(t)", "float", True),
        ("japanese name", ArrayType(StringType()), True),
        ("last position seen", "str", True),
        ("date arrival", "str", True),
        ("last date seen", "str", True),
        ("attributes", ArrayType(FloatType()), True),
        ("DateType", DateType()),
        ("Timestamp", TimestampType()),
        ("Cybertronian", "bool", True),
        ("function(binary)", "binary", False),
        ("NullType", "null", True),

    ],
    [
        ("31/12/2019", 28, "1978-12-20", 10, 5000000, 4.30, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
         "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True, bytearray("Leader", "utf-8"),
         None),
        ("bumbl#ebéé  ", 17, "Espionage", 7, 5000000, 2.0, ["Bumble", "Goldback"], "10.642707,-71.612534", "1980/04/10",
         "2015/08/10", [5.334, 2000.0], date(2015, 8, 10), datetime(2014, 6, 24), True, bytearray("Espionage", "utf-8"),
         None),
        ("ironhide&", 26, "Security", 7, 5000000, 4.0, ["Roadbuster"], "37.789563,-122.400356", "1980/04/10",
         "2014/07/10", [7.9248, 4000.0], date(2014, 6, 24), datetime(2014, 6, 24), True, bytearray("Security", "utf-8"),
         None),
        ("Jazz", 13, "First Lieutenant", 8, 5000000, 1.80, ["Meister"], "33.670666,-117.841553", "1980/04/10",
         "2013/06/10", [3.9624, 1800.0], date(2013, 6, 24), datetime(2014, 6, 24), True,
         bytearray("First Lieutenant", "utf-8"), None),
        ("Megatron", None, "None", 10, 5000000, 5.70, ["Megatron"], None, "1980/04/10", "2012/05/10", [None, 5700.0],
         date(2012, 5, 10), datetime(2014, 6, 24), True, bytearray("None", "utf-8"), None),
        ("Metroplex_)^$", 300, "Battle Station", 8, 5000000, None, ["Metroflex"], None, "1980/04/10", "2011/04/10",
         [91.44, None], date(2011, 4, 10), datetime(2014, 6, 24), True, bytearray("Battle Station", "utf-8"), None),
        ("1", 2, "3", 4, 5, 6.0, ["7"], 8, "1980/04/10", "2011/04/10",
         [11.0], date(2011, 4, 10), datetime(2014, 6, 24), True, bytearray("15", "utf-8"), None)
    ], infer_schema=True)

# %%
mismatch = {"names": "dd/mm/yyyy", "height(ft)": r'^([0-2][0-9]|(3)[0-1])(\/)(((0)[0-9])|((1)[0-2]))(\/)\d{4}$',
            "function": "yyyy-mm-dd"}

# %%
m = {"names": "int"}

# %%
mismatch_df.table()

# %%
t.create(mismatch_df, "cols.count_mismatch", None, "dict", None, {"names": "int"})

# %%
t.run()

# %% [markdown]
# ## Unnest String

# %%
t.create(None, "cols.unnest", "string_multi_index", "df", None, date_col, "/", splits=3, index=2)

# %%
t.create(None, "cols.unnest", "string_multi_index", "df", None, date_col, "/", splits=3, index=[1, 2])

# %%
t.create(None, "cols.unnest", "string_infer_split", "df", None, date_col, "/")

# %%
t.create(None, "cols.unnest", "string_no_index", "df", None, date_col, "/", splits=3)

# %%
t.create(None, "cols.unnest", "string_output_columns", "df", None, date_col, "/", splits=3,
         output_cols=[("year", "month", "day")])

# %%
t.create(None, "cols.unnest", "array_index", "df", None, array_col, index=2)

# %%
t.create(None, "cols.unnest", "array_multi_index", "df", None, array_col, index=[1, 2])

# %%
t.run()

# %%
t.create(None, "cols.unnest", "string_multi_colum_multi_index_multi_output", "df", None,
         ["date arrival", "last date seen"], "/", index=[(1, 2), (1, 2)],
         output_cols=[("year1", "month1"), ("year2", "month2")])

# %%
t.create(None, "cols.unnest", "string_multi_colum_multi_output", "df", None, ["date arrival", "last date seen"], "/",
         output_cols=[("year1", "month1"), ("year2", "month2")])

# %%
t.create(None, "cols.unnest", "array", "df", array_col)

# %%
t.create(None, "cols.unnest", "array_all_columns", "df", array_col)

# %%
t.create(None, "cols.is_na", "all_columns", "df", "*")

# %%
t.create(None, "cols.is_na", None, "df", numeric_col)

# %%
t.run()

# %%
from pyspark.sql.types import *
from optimus import Optimus
from optimus.helpers.json import json_enconding
from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector
import numpy as np

# %%
nan = np.nan
import datetime

# %%
actual_df = op.load.json('https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.json')
expected_df = op.create.df(
    [('billingId', LongType(), True), ('birth', StringType(), True), ('dummyCol', StringType(), True),
     ('firstName', StringType(), True), ('id', LongType(), True), ('lastName', StringType(), True),
     ('price', LongType(), True), ('product', StringType(), True)],
    [(123, '1980/07/07', 'never', 'Luis', 1, 'Alvarez$$%!', 10, 'Cake')])

# assert (expected_df.collect() == actual_df.collect())

from deepdiff import DeepDiff  # For Deep Difference of 2 objects

actual_df.table()
expected_df.table()

# source_df.table()
# print(actual_df.to_json())
# print(expected_df.to_json())
a1 = actual_df.to_json()
e1 = expected_df.to_json()

# %%
ddiff = DeepDiff(a1, e1, ignore_order=False)
print(ddiff)

# %% [markdown]
# # Rows Test

# %%
t = Test(op, df, "df_rows", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                     "import numpy as np",
                                     "nan = np.nan",
                                     "import datetime",
                                     "from pyspark.sql import functions as F",
                                     "from optimus.functions import abstract_udf as audf"])

# %%
rows = [
    ("Optim'us", 28, "Leader", 10, 5000000, 4.30, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
     "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True, bytearray("Leader", "utf-8"),
     None)
]

# %%
df = op.load.url("https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.csv")

# %%
t = Test(op, source_df, "op_io", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                          "import numpy as np",
                                          "nan = np.nan",
                                          "import datetime",
                                          "from pyspark.sql import functions as F"], path="op_io", final_path="..")

# %%
t.create(op, "load.csv", "local_csv", "df", "../../examples/data/foo.csv")
t.create(op, "load.json", "local_json", "df", "../../examples/data/foo.json")
t.create(op, "load.parquet", "local_parquet", "df", "../../examples/data/foo.parquet")
t.create(op, "load.csv", "remote_csv", "df",
         "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.csv")

# %%
t.create(op, "load.json", "remote_json", "df",
         "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.json")

# %%
t.create(op, "load.parquet", "remote_parquet", "df",
         "https://raw.githubusercontent.com/ironmussa/Optimus/master/examples/data/foo.parquet")

# %%
from optimus.profiler.profiler import Profiler

p = Profiler()

print(p.run(source_df1, "japanese name"))

# %%
# df_string = source_df.cols.cast("*","str")
t.create(source_df, "save.csv", None, None, "test.csv")

# %%
t.create(None, "save.json", None, None, "test.json")

# %%
t.create(None, "save.parquet", None, None, "test.parquet")

# %%
t.run()

# %%
source_df.table()

# %% [markdown]
# # Ouliers

# %%
import pandas as pd
from pyspark.sql.types import *
from datetime import date, datetime

cols = [
    ("names", "str"),
    ("height(ft)", ShortType()),
    ("function", "str"),
    ("rank", ByteType()),
    ("age", "int"),
    ("weight(t)", "float"),
    "japanese name",
    "last position seen",
    "date arrival",
    "last date seen",
    ("attributes", ArrayType(FloatType())),
    ("Date Type", DateType()),
    ("timestamp", TimestampType()),
    ("Cybertronian", BooleanType()),
    ("function(binary)", BinaryType()),
    ("NullType", NullType())

]

rows = [
    ("Optim'us", -28, "Leader", 10, 5000000, 4.30, ["Inochi", "Convoy"], "19.442735,-99.201111", "1980/04/10",
     "2016/09/10", [8.5344, 4300.0], date(2016, 9, 10), datetime(2014, 6, 24), True, bytearray("Leader", "utf-8"),
     None),
    ("bumbl#ebéé  ", 17, "Espionage", 7, 5000000, 2.0, ["Bumble", "Goldback"], "10.642707,-71.612534", "1980/04/10",
     "2015/08/10", [5.334, 2000.0], date(2015, 8, 10), datetime(2014, 6, 24), True, bytearray("Espionage", "utf-8"),
     None),
    ("ironhide&", 26, "Security", 7, 5000000, 4.0, ["Roadbuster"], "37.789563,-122.400356", "1980/04/10",
     "2014/07/10", [7.9248, 4000.0], date(2014, 6, 24), datetime(2014, 6, 24), True, bytearray("Security", "utf-8"),
     None),
    ("Jazz", 13, "First Lieutenant", 8, 5000000, 1.80, ["Meister"], "33.670666,-117.841553", "1980/04/10",
     "2013/06/10", [3.9624, 1800.0], date(2013, 6, 24), datetime(2014, 6, 24), True,
     bytearray("First Lieutenant", "utf-8"), None),
    ("Megatron", None, "None", 10, 5000000, 5.70, ["Megatron"], None, "1980/04/10", "2012/05/10", [None, 5700.0],
     date(2012, 5, 10), datetime(2014, 6, 24), True, bytearray("None", "utf-8"), None),
    ("Metroplex_)^$", 300, "Battle Station", 8, 5000000, None, ["Metroflex"], None, "1980/04/10", "2011/04/10",
     [91.44, None], date(2011, 4, 10), datetime(2014, 6, 24), True, bytearray("Battle Station", "utf-8"), None),
    (None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),

]
source_df = op.create.df(cols, rows)
source_df.table()

# %%
t = Test(op, source_df, "df_outliers", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                                "import numpy as np",
                                                "nan = np.nan",
                                                "import datetime",
                                                "from pyspark.sql import functions as F"], path="df_outliers",
         final_path="..")

# %%
from pyspark.sql import functions as F


def func(col_name, attrs):
    return F.col(col_name) * 2


numeric_col = "height(ft)"
numeric_col_B = "rank"
numeric_col_C = "rank"
string_col = "function"
date_col = "date arrival"
date_col_B = "last date seen"
new_col = "new col"
array_col = "attributes"

# %%
source_df.table()

# %% [markdown]
# ## Tukey

# %%
t.create(None, "outliers.tukey", None, "df", "select", numeric_col)

# %%
source_df.outliers.tukey(numeric_col).drop().table()

# %%
t.create(None, "outliers.tukey", None, "df", "drop", numeric_col)

# %%
t.create(None, "outliers.tukey", None, "json", "whiskers", numeric_col)

# %%
t.create(None, "outliers.tukey", None, "json", "count", numeric_col)

# %%
t.create(None, "outliers.tukey", None, "json", "non_outliers_count", numeric_col)

# %%
t.create(None, "outliers.tukey", None, "json", "info", numeric_col)

# %%
t.run()

# %% [markdown]
# ## Zscore

# %%
threshold = 0.5

# %%
t.create(None, "outliers.z_score", None, "df", "select", numeric_col, threshold)

# %%
source_df.outliers.z_score('height(ft)', 0.5).select()

# %%
t.create(None, "outliers.z_score", None, "df", "drop", numeric_col, threshold)

# %%
t.create(None, "outliers.z_score", None, "json", "count", numeric_col, threshold)

# %%
t.create(None, "outliers.z_score", None, "json", "non_outliers_count", numeric_col, threshold)

# %%
t.create(None, "outliers.z_score", None, "json", "info", numeric_col, threshold)

# %%
t.run()

# %% [markdown]
# ## Modified Zscore

# %%
threshold = 0.5
relative_error = 10000

# %%
t.create(None, "outliers.modified_z_score", None, "df", "select", numeric_col, threshold, relative_error)

# %%
t.create(None, "outliers.modified_z_score", None, "df", "drop", numeric_col, threshold, relative_error)

# %%
t.create(None, "outliers.modified_z_score", None, "json", "count", numeric_col, threshold, relative_error)

# %%
t.create(None, "outliers.modified_z_score", None, "json", "non_outliers_count", numeric_col, threshold, relative_error)

# %%
t.create(None, "outliers.modified_z_score", None, "json", "info", numeric_col, threshold, relative_error)

# %%
t.run()

# %% [markdown]
# ## Mad

# %%
threshold = 0.5
relative_error = 10000

# %%
t.create(None, "outliers.mad", None, "df", "select", numeric_col, threshold, relative_error)

# %%
t.create(None, "outliers.mad", None, "df", "drop", numeric_col, threshold, relative_error)

# %%
t.create(None, "outliers.mad", None, "json", "count", numeric_col, threshold, relative_error)

# %%
t.create(None, "outliers.mad", None, "json", "non_outliers_count", numeric_col, threshold, relative_error)

# %%
t.create(None, "outliers.mad", None, "json", "info", numeric_col, threshold, relative_error)

# %%
t.run()

# %% [markdown]
# ## Keycolision

# %%
source_df = op.read.csv("../../examples/data/random.csv", header=True, sep=";").limit(10)

# %%
source_df.table()

# %%
t = Test(op, source_df, "df_keycollision", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                                    "import numpy as np",
                                                    "nan = np.nan",
                                                    "import datetime",
                                                    "from pyspark.sql import functions as F",
                                                    "from optimus.ml import keycollision as keyCol"],
         path="df_keycollision", final_path="..")

from optimus.ml import keycollision as keyCol

# %%
t.create(keyCol, "fingerprint", None, "df", None, source_df, "STATE")
t.run()

# %%
t.create(keyCol, "fingerprint_cluster", None, "json", None, source_df, "STATE")

# %%
t.run()

# %%
t.create(keyCol, "n_gram_fingerprint", None, "df", None, source_df, "STATE")

# %%
t.create(keyCol, "n_gram_fingerprint_cluster", None, "json", None, source_df, "STATE", 2)

# %%
t.run()

# %% [markdown]
# ## Distance cluster

# %%
source_df = op.read.csv("../../examples/data/random.csv", header=True, sep=";").limit(1000)

# %%
t = Test(op, source_df, "df_distance_cluster", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                                        "import numpy as np",
                                                        "nan = np.nan",
                                                        "import datetime",
                                                        "from pyspark.sql import functions as F",
                                                        "from optimus.ml import distancecluster as dc"],
         path="df_distance_cluster", final_path="..")

from optimus.ml import distancecluster as dc

# %%
df.table()

# %%
t.create(dc, "levenshtein_cluster", None, 'dict', None, source_df, "STATE")

# %%
t.run()

# %%
df_cancer = op.spark.read.csv('../data_cancer.csv', sep=',', header=True, inferSchema=True)

# %%
columns = ['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean',
           'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean',
           'fractal_dimension_mean']

# %%
df_model, rf_model = op.ml.gbt(df_cancer, columns, "diagnosis")

# %%
df_model.table()

# %% [markdown]
# ## Row

# %%
source_df = op.create.df([
    ("words", "str", True),
    ("num", "int", True),
    ("animals", "str", True),
    ("thing", StringType(), True),
    ("second", "int", True),
    ("filter", StringType(), True)
],
    [
        ("  I like     fish  ", 1, "dog dog", "housé", 5, "a"),
        ("    zombies", 2, "cat", "tv", 6, "b"),
        ("simpsons   cat lady", 2, "frog", "table", 7, "1"),
        (None, 3, "eagle", "glass", 8, "c"),
    ])

# %%
from optimus.audf import abstract_udf as audf

# %%
t = Test(op, source_df, "df_rows", imports=["from pyspark.ml.linalg import Vectors, VectorUDT, DenseVector",
                                            "import numpy as np",
                                            "nan = np.nan",
                                            "from optimus.audf import abstract_udf as audf",
                                            "import datetime",
                                            "from pyspark.sql import functions as F"], path="df_rows", final_path="..")

# %%
row = [("this is a word", 2, "this is an animal",
        "this is a thing", 64, "this is a filter",)]

# %%
t.create(None, "rows.append", None, "df", None, row)

# %%
fil = (source_df["num"] == 1)

# %%
t.create(None, "rows.select", None, "df", None, fil)

# %%
t.create(None, "rows.select_by_dtypes", None, "df", None, "filter", "integer")

# %%
fil = (source_df["num"] == 2) | (source_df["second"] == 5)
print(str(fil))
# type(fil)

# %%
t.create(None, "rows.drop", None, "df", None, fil)

# %%
t.create(None, "rows.drop_by_dtypes", None, "df", None, "filter", "integer")

# %%
def func_data_type(value, attr):
    return value > 1

# %%
a = audf("num", func_data_type, "boolean")

# %%
t.create(None, "rows.drop", "audf", "df", None, a)

# %%
t.create(None, "rows.sort", None, "df", None, "num", "desc")

# %%
t.create(None, "rows.is_in", None, "df", None, "num", 2)

# %%
t.create(None, "rows.between", None, "df", None, "second", 6, 8)

# %%
t.create(None, "rows.between", "equal", "df", None, "second", 6, 8, equal=True)

# %%
t.create(None, "rows.between", "invert_equal", "df", None, "second", 6, 8, invert=True, equal=True)

# %%
t.create(None, "rows.between", "bounds", "df", None, "second", bounds=[(6, 7), (7, 8)], invert=True, equal=True)

# %%
t.run()
